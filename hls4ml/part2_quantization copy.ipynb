# %% [markdown]
# # Tensorflow to Qkeras to Hls4ml

# %%
import numpy as np

seed = 0
np.random.seed(seed)

import tensorflow as tf

tf.random.set_seed(seed)


import sys

sys.path.append("/home/webphy/Desktop/dnn_processor/")  # just to enable `dataset`
sys.path.append(
    "/home/webphy/Desktop/dnn_processor/dataset/"
)  # just to enable `dataset`

import dataset
import plotting
import qkeras
import keras
# Out:
# 2024-02-06 11:50:50.098791: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-02-06 11:50:50.123178: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-06 11:50:50.123210: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-06 11:50:50.124062: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-02-06 11:50:50.128423: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-02-06 11:50:50.578896: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# # fetch dataset

# %%
BATCH_SIZE = 64
train_images_rgx = "../dataset/train_set_4x/*/*.jpeg"
valid_images_rgx = "../dataset/test_set_4x/*/*.jpeg"

train_ds, val_ds, nclasses = dataset.create_datasets(
    train_images_rgx, valid_images_rgx, BATCH_SIZE, 128
)
# Out:
# 2024-02-06 11:50:51.462373: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-06 11:50:51.487561: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-06 11:50:51.487698: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-06 11:50:51.488912: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-06 11:50:51.488999: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-06 11:50:51.489048: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-06 11:50:52.162070: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-06 11:50:52.162179: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-06 11:50:52.162239: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-06 11:50:52.162289: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9535 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060, pci bus id: 0000:01:00.0, compute capability: 8.6

# %% [markdown]
# # load the model

# %%
exp_id = "manual_test_4x"


model = keras.models.load_model(
    f"../neural_network/handmade/saved_models/manual_test_4x/model.h5",
    compile=False,
)
model.compile(
    "adam", loss=tf.keras.losses.CategoricalCrossentropy(True), metrics=["accuracy"]
)

score = model.evaluate(val_ds)
print("Accuracy: {}".format(score[1]))
# Out:
# 2024-02-06 11:50:54.052710: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8904
# 5/5 [==============================] - 2s 21ms/step - loss: 0.3979 - accuracy: 0.8697
# Accuracy: 0.8697317838668823

# %% [markdown]
# # quantize model

# %%
import qkeras
from qkeras import *
from keras.layers import (
    Conv2D,
    DepthwiseConv2D,
    Activation,
    Dense,
    Flatten,
    MaxPooling2D,
    GlobalAveragePooling2D,
)


BIT_WIDTH = 8


def create_qkeras_model_from_keras_model(keras_model):
    x = x_in = keras.Input(shape=keras_model.layers[0].output.shape[1:])

    x = QActivation(quantized_relu(BIT_WIDTH, 0))(x)

    for l in keras_model.layers:
        if isinstance(l, Conv2D):
            qconv2d = QConv2D(
                l.filters,
                l.kernel_size,
                l.strides,
                l.padding,
                kernel_quantizer=quantized_bits(BIT_WIDTH, 0, 1),
                bias_quantizer=quantized_bits(BIT_WIDTH, 0, 1),
            )
            x = qconv2d(x)
            qconv2d.set_weights(l.get_weights())

        elif isinstance(l, DepthwiseConv2D):
            qDepthwiseConv2D = QDepthwiseConv2D(
                l.kernel_size,
                l.strides,
                l.padding,
                depthwise_quantizer=quantized_bits(BIT_WIDTH, 0, 1),
                bias_quantizer=quantized_bits(BIT_WIDTH, 0, 1),
            )
            x = qDepthwiseConv2D(x)
            qDepthwiseConv2D.set_weights(l.get_weights())

        elif isinstance(l, Activation):
            activation_name = l.get_config()["activation"]
            print(activation_name)
            if activation_name == "tanh":
                x = QActivation(quantized_tanh(BIT_WIDTH, True))(x)
            elif activation_name == "relu":
                x = QActivation(quantized_relu(BIT_WIDTH, 0))(x)
            elif activation_name == "linear":
                x = QActivation(quantized_bits(BIT_WIDTH, 0, 1))(x)
            else:
                print(f"{l.name} was not quantized")

        elif isinstance(l, Flatten):
            # necessary because the layer before Flatten doesnt have avtivation
            x = QActivation(quantized_bits(BIT_WIDTH - 4, 0, 1))(x)
            x = Flatten()(x)

        elif isinstance(l, Dense):
            qdense = QDense(
                l.units,
                kernel_quantizer=quantized_bits(BIT_WIDTH, 0, 1),
                bias_quantizer=quantized_bits(BIT_WIDTH, 0, 1),
            )
            # just for testing the latency
            x = qdense(x)
            qdense.set_weights(l.get_weights())


        elif isinstance(l, MaxPooling2D):
            x = MaxPooling2D()(x)

        elif isinstance(l, GlobalAveragePooling2D):
            globalAveragePooling2D = GlobalAveragePooling2D()
            x = globalAveragePooling2D(x)
            x = QActivation(quantized_bits(BIT_WIDTH, 0, 1))(x)
        else:
            print(f"{l.name} layer was not quantized...")

    qkeras_model = keras.models.Model(x_in, x)

    return qkeras_model


qkeras_model = create_qkeras_model_from_keras_model(model)
qkeras_model.compile(
    keras.optimizers.Adam(0.0005),
    loss=keras.losses.CategoricalCrossentropy(True),
    metrics=["accuracy"],
)
qkeras_model.summary()
# Out:
# input_2 layer was not quantized...
# relu
# relu
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 128, 128, 3)]     0
#
#  q_activation (QActivation)  (None, 128, 128, 3)       0
#
#  q_conv2d (QConv2D)          (None, 32, 32, 4)         196
#
#  q_activation_1 (QActivatio  (None, 32, 32, 4)         0
#  n)
#
#  q_conv2d_1 (QConv2D)        (None, 15, 15, 16)        592
#
#  q_activation_2 (QActivatio  (None, 15, 15, 16)        0
#  n)
#
#  q_conv2d_2 (QConv2D)        (None, 15, 15, 5)         85
#
#  q_activation_3 (QActivatio  (None, 15, 15, 5)         0
#  n)
#
#  flatten (Flatten)           (None, 1125)              0
#
#  q_dense (QDense)            (None, 5)                 5630
#
# =================================================================
# Total params: 6503 (25.40 KB)
# Trainable params: 6503 (25.40 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# # evaluate quantized model

# %%
from qkeras.estimate import print_qstats

qkeras_model.evaluate(val_ds)
print_qstats(qkeras_model)
# free memory
del model
# Out:
# 5/5 [==============================] - 2s 32ms/step - loss: 0.6407 - accuracy: 0.7203
# /home/webphy/Desktop/dnn_processor/.venv/lib/python3.10/site-packages/keras/src/constraints.py:365: UserWarning: The `keras.constraints.serialize()` API should only be used for objects of type `keras.constraints.Constraint`. Found an instance of type <class 'qkeras.quantizers.quantized_bits'>, which may lead to improper serialization.
#   warnings.warn(
# WARNING:tensorflow:From /home/webphy/Desktop/dnn_processor/.venv/lib/python3.10/site-packages/qkeras/estimate.py:345: Tensor.experimental_ref (from tensorflow.python.framework.tensor) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use ref() instead.
# WARNING:tensorflow:From /home/webphy/Desktop/dnn_processor/.venv/lib/python3.10/site-packages/qkeras/estimate.py:345: Tensor.experimental_ref (from tensorflow.python.framework.tensor) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use ref() instead.
# Number of operations in model:
#     q_conv2d                      : 196608 (smult_8_8)
#     q_conv2d_1                    : 129600 (smult_8_8)
#     q_conv2d_2                    : 18000 (smult_8_8)
#     q_dense                       : 5625  (smult_8_4)
#
# Number of operation types in model:
#     smult_8_4                     : 5625
#     smult_8_8                     : 344208
#
# Weight profiling:
#     q_conv2d_weights               : 192   (8-bit unit)
#     q_conv2d_bias                  : 4     (8-bit unit)
#     q_conv2d_1_weights             : 576   (8-bit unit)
#     q_conv2d_1_bias                : 16    (8-bit unit)
#     q_conv2d_2_weights             : 80    (8-bit unit)
#     q_conv2d_2_bias                : 5     (8-bit unit)
#     q_dense_weights                : 5625  (8-bit unit)
#     q_dense_bias                   : 5     (8-bit unit)
#
# Weight sparsity:
# ... quantizing model
#     q_conv2d                       : 0.0051
#     q_conv2d_1                     : 0.0101
#     q_conv2d_2                     : 0.0235
#     q_dense                        : 0.0101
#     ----------------------------------------
#     Total Sparsity                 : 0.0101

# %% [markdown]
# # fine tune quantized model

# %%
qkeras_model.fit(train_ds, batch_size=256, epochs=5, validation_data=val_ds)
trial_id = "handmade_model"
qkeras_model.save(f"saved_qmodels/{trial_id}.h5")
# Out:
# Epoch 1/5
# 2024-02-06 11:50:58.544761: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape ingradient_tape/model/q_activation_2/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2024-02-06 11:50:58.707942: I external/local_xla/xla/service/service.cc:168] XLA service 0x7f8150a5aab0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-02-06 11:50:58.707985: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 3060, Compute Capability 8.6
# 2024-02-06 11:50:58.712002: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1707231058.771030  811924 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 55/55 [==============================] - 2s 6ms/step - loss: 0.3307 - accuracy: 0.8710 - val_loss: 0.4664 - val_accuracy: 0.8046
# Epoch 2/5
# 55/55 [==============================] - 0s 6ms/step - loss: 0.2603 - accuracy: 0.9031 - val_loss: 0.4121 - val_accuracy: 0.8391
# Epoch 3/5
# 55/55 [==============================] - 0s 6ms/step - loss: 0.2576 - accuracy: 0.9011 - val_loss: 0.3853 - val_accuracy: 0.8544
# Epoch 4/5
# 55/55 [==============================] - 0s 6ms/step - loss: 0.2728 - accuracy: 0.8963 - val_loss: 0.3675 - val_accuracy: 0.8582
# Epoch 5/5
# 55/55 [==============================] - 0s 6ms/step - loss: 0.2611 - accuracy: 0.9009 - val_loss: 0.3886 - val_accuracy: 0.8544
# /home/webphy/Desktop/dnn_processor/.venv/lib/python3.10/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
from qkeras.utils import _add_supported_quantized_objects

co = {}
_add_supported_quantized_objects(co)

loaded_qkeras_model = keras.models.load_model(f"saved_qmodels/{trial_id}.h5", co)
loaded_qkeras_model.evaluate(val_ds)

# free memory
del loaded_qkeras_model
# Out:
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3886 - accuracy: 0.8544

# %% [markdown]
# # convert quantized model to HLS4ml

# %%
import hls4ml

config = hls4ml.utils.config_from_keras_model(
    qkeras_model,
    granularity="name",
    default_precision="fixed<8,1>",
    default_reuse_factor=9000,
)

config["Model"]["Strategy"] = "Resource"

for layer in config["LayerName"].keys():
    config["LayerName"][layer]["Strategy"] = "Resource"

#config["LayerName"]["q_dense"]["Strategy"] = "Resource"
#config["LayerName"]["q_dense"]["Precision"] = "fixed<4,1>"
# Out:
# WARNING: Failed to import handlers from reshape.py: No module named 'torch'.
# WARNING: Failed to import handlers from merge.py: No module named 'torch'.
# WARNING: Failed to import handlers from convolution.py: No module named 'torch'.
# WARNING: Failed to import handlers from core.py: No module named 'torch'.
# WARNING: Failed to import handlers from pooling.py: No module named 'torch'.
# Interpreting Model
# Topology:
# Layer name: input_1, layer type: InputLayer, input shapes: [[None, 128, 128, 3]], output shape: [None, 128, 128, 3]
# Layer name: q_activation, layer type: Activation, input shapes: [[None, 128, 128, 3]], output shape: [None, 128, 128, 3]
# Layer name: q_conv2d, layer type: QConv2D, input shapes: [[None, 128, 128, 3]], output shape: [None, 32, 32, 4]
# Layer name: q_activation_1, layer type: Activation, input shapes: [[None, 32, 32, 4]], output shape: [None, 32, 32, 4]
# Layer name: q_conv2d_1, layer type: QConv2D, input shapes: [[None, 32, 32, 4]], output shape: [None, 15, 15, 16]
# Layer name: q_activation_2, layer type: Activation, input shapes: [[None, 15, 15, 16]], output shape: [None, 15, 15, 16]
# Layer name: q_conv2d_2, layer type: QConv2D, input shapes: [[None, 15, 15, 16]], output shape: [None, 15, 15, 5]
# Layer name: q_activation_3, layer type: Activation, input shapes: [[None, 15, 15, 5]], output shape: [None, 15, 15, 5]
# Layer name: flatten, layer type: Reshape, input shapes: [[None, 15, 15, 5]], output shape: [None, 1125]
# Layer name: q_dense, layer type: QDense, input shapes: [[None, 1125]], output shape: [None, 5]
# /home/webphy/Desktop/dnn_processor/.venv/lib/python3.10/site-packages/hls4ml/converters/__init__.py:27: UserWarning: WARNING: Pytorch converter is not enabled!
#   warnings.warn("WARNING: Pytorch converter is not enabled!", stacklevel=1)
# /home/webphy/Desktop/dnn_processor/.venv/lib/python3.10/site-packages/keras/src/constraints.py:365: UserWarning: The `keras.constraints.serialize()` API should only be used for objects of type `keras.constraints.Constraint`. Found an instance of type <class 'qkeras.quantizers.quantized_bits'>, which may lead to improper serialization.
#   warnings.warn(

# %%
plotting.print_dict(config)
# Out:
# Model
#   Precision:         fixed<8,1>
#   ReuseFactor:       9000
#   Strategy:          Resource
#   BramFactor:        1000000000
#   TraceOutput:       False
# LayerName
#   input_1
#     Trace:           False
#     Precision
#       result:        fixed<8,1>
#     Strategy:        Resource
#   q_activation
#     Trace:           False
#     Precision
#       result:        ufixed<8,0,RND_CONV,SAT>
#     Strategy:        Resource
#   q_conv2d
#     Trace:           False
#     Precision
#       result:        fixed<8,1>
#       weight:        fixed<8,1>
#       bias:          fixed<8,1>
#     Strategy:        Resource
#   q_conv2d_linear
#     Trace:           False
#     Precision
#       result:        fixed<8,1>
#     Strategy:        Resource
#   q_activation_1
#     Trace:           False
#     Precision
#       result:        ufixed<8,0,RND_CONV,SAT>
#     Strategy:        Resource
#   q_conv2d_1
#     Trace:           False
#     Precision
#       result:        fixed<8,1>
#       weight:        fixed<8,1>
#       bias:          fixed<8,1>
#     Strategy:        Resource
#   q_conv2d_1_linear
#     Trace:           False
#     Precision
#       result:        fixed<8,1>
#     Strategy:        Resource
#   q_activation_2
#     Trace:           False
#     Precision
#       result:        ufixed<8,0,RND_CONV,SAT>
#     Strategy:        Resource
#   q_conv2d_2
#     Trace:           False
#     Precision
#       result:        fixed<8,1>
#       weight:        fixed<8,1>
#       bias:          fixed<8,1>
#     Strategy:        Resource
#   q_conv2d_2_linear
#     Trace:           False
#     Precision
#       result:        fixed<8,1>
#     Strategy:        Resource
#   q_activation_3
#     Trace:           False
#     Precision
#       result:        fixed<4,1,RND_CONV,SAT>
#     Strategy:        Resource
#   flatten
#     Trace:           False
#     Precision
#       result:        fixed<8,1>
#     Strategy:        Resource
#   q_dense
#     Trace:           False
#     Precision
#       result:        fixed<8,1>
#       weight:        fixed<8,1>
#       bias:          fixed<8,1>
#     Strategy:        Resource
#   q_dense_linear
#     Trace:           False
#     Precision
#       result:        fixed<8,1>
#     Strategy:        Resource

# %% [markdown]
# # build for pynq without DMA

# %%
hls_model = hls4ml.converters.convert_from_keras_model(
    qkeras_model,
    hls_config=config,
    output_dir=f"model_qqqq/hls4ml_prj",
    part="xc7z020-clg400-1",
    io_type="io_stream",
)
# Out:
# Interpreting Model
# Topology:
# Layer name: input_1, layer type: InputLayer, input shapes: [[None, 128, 128, 3]], output shape: [None, 128, 128, 3]
# Layer name: q_activation, layer type: Activation, input shapes: [[None, 128, 128, 3]], output shape: [None, 128, 128, 3]
# Layer name: q_conv2d, layer type: QConv2D, input shapes: [[None, 128, 128, 3]], output shape: [None, 32, 32, 4]
# Layer name: q_activation_1, layer type: Activation, input shapes: [[None, 32, 32, 4]], output shape: [None, 32, 32, 4]
# Layer name: q_conv2d_1, layer type: QConv2D, input shapes: [[None, 32, 32, 4]], output shape: [None, 15, 15, 16]
# Layer name: q_activation_2, layer type: Activation, input shapes: [[None, 15, 15, 16]], output shape: [None, 15, 15, 16]
# Layer name: q_conv2d_2, layer type: QConv2D, input shapes: [[None, 15, 15, 16]], output shape: [None, 15, 15, 5]
# Layer name: q_activation_3, layer type: Activation, input shapes: [[None, 15, 15, 5]], output shape: [None, 15, 15, 5]
# Layer name: flatten, layer type: Reshape, input shapes: [[None, 15, 15, 5]], output shape: [None, 1125]
# Layer name: q_dense, layer type: QDense, input shapes: [[None, 1125]], output shape: [None, 5]
# Creating HLS model
# WARNING: Strategy for layer input_1 set to "Resource", while pipeline style set to "pipeline".
# WARNING: Strategy for layer q_activation set to "Resource", while pipeline style set to "pipeline".
# WARNING: Strategy for layer q_conv2d set to "Resource", while pipeline style set to "pipeline".
# WARNING: Strategy for layer q_conv2d_linear set to "Resource", while pipeline style set to "pipeline".
# WARNING: Strategy for layer q_activation_1 set to "Resource", while pipeline style set to "pipeline".
# WARNING: Strategy for layer q_conv2d_1 set to "Resource", while pipeline style set to "pipeline".
# WARNING: Strategy for layer q_conv2d_1_linear set to "Resource", while pipeline style set to "pipeline".
# WARNING: Strategy for layer q_activation_2 set to "Resource", while pipeline style set to "pipeline".
# WARNING: Strategy for layer q_conv2d_2 set to "Resource", while pipeline style set to "pipeline".
# WARNING: Strategy for layer q_conv2d_2_linear set to "Resource", while pipeline style set to "pipeline".
# WARNING: Strategy for layer q_activation_3 set to "Resource", while pipeline style set to "pipeline".
# WARNING: Strategy for layer flatten set to "Resource", while pipeline style set to "pipeline".
# WARNING: Strategy for layer q_dense set to "Resource", while pipeline style set to "pipeline".
# WARNING: Strategy for layer q_dense_linear set to "Resource", while pipeline style set to "pipeline".
# WARNING: Changing pipeline style to "dataflow".
# WARNING: Invalid ReuseFactor=9000 in layer "q_conv2d".Using ReuseFactor=192 instead. Valid ReuseFactor(s): 1,2,3,4,6,8,12,16,24,48,96,192.
# WARNING: Invalid ReuseFactor=9000 in layer "q_conv2d_1".Using ReuseFactor=576 instead. Valid ReuseFactor(s): 1,2,3,4,6,9,12,18,36,72,144,288,576.
# WARNING: Invalid ReuseFactor=9000 in layer "q_conv2d_2".Using ReuseFactor=80 instead. Valid ReuseFactor(s): 1,2,4,8,16,80.
# WARNING: Invalid ReuseFactor=9000 in layer "q_dense".Using ReuseFactor=5625 instead. Valid ReuseFactor(s): 1,3,5,9,15,25,45,75,125,225,375,1125,5625.
# WARNING: Config parameter "trace" overwrites an existing attribute in layer "q_conv2d_2" (PointwiseConv2D)
# WARNING: Config parameter "precision" overwrites an existing attribute in layer "q_conv2d_2" (PointwiseConv2D)
# WARNING: Config parameter "strategy" overwrites an existing attribute in layer "q_conv2d_2" (PointwiseConv2D)

# %%
hls4ml.utils.plot_model(hls_model, show_shapes=True, show_precision=True, to_file=None)

# %%
hls_model.compile()
# Out:
# Writing HLS project
# Done
# /home/webphy/Desktop/dnn_processor/.venv/lib/python3.10/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# /home/webphy/Desktop/dnn_processor/.venv/lib/python3.10/site-packages/keras/src/constraints.py:365: UserWarning: The `keras.constraints.serialize()` API should only be used for objects of type `keras.constraints.Constraint`. Found an instance of type <class 'qkeras.quantizers.quantized_bits'>, which may lead to improper serialization.
#   warnings.warn(

# %%
hls_model.build(csim=False)
# Out:
# ****** Vivado(TM) HLS - High-Level Synthesis from C, C++ and SystemC v2020.1 (64-bit)
#   **** SW Build 2902540 on Wed May 27 19:54:35 MDT 2020
#   **** IP Build 2902112 on Wed May 27 22:43:36 MDT 2020
#     ** Copyright 1986-2020 Xilinx, Inc. All Rights Reserved.
#
# source /opt/Xilinx/Vivado/2020.1/scripts/vivado_hls/hls.tcl -notrace
# INFO: [HLS 200-10] Running '/opt/Xilinx/Vivado/2020.1/bin/unwrapped/lnx64.o/vivado_hls'
# INFO: [HLS 200-10] For user 'webphy' on host 'wesley-XPS-8950' (Linux_x86_64 version 6.5.0-15-generic) on Tue Feb 06 11:51:06 -03 2024
# INFO: [HLS 200-10] On os Ubuntu 22.04.3 LTS
# INFO: [HLS 200-10] In directory '/home/webphy/Desktop/dnn_processor/hls4ml/model_qqqq/hls4ml_prj'
# Sourcing Tcl script 'build_prj.tcl'
# INFO: [HLS 200-10] Creating and opening project '/home/webphy/Desktop/dnn_processor/hls4ml/model_qqqq/hls4ml_prj/myproject_prj'.
# INFO: [HLS 200-10] Adding design file 'firmware/myproject.cpp' to the project
# INFO: [HLS 200-10] Adding test bench file 'myproject_test.cpp' to the project
# INFO: [HLS 200-10] Adding test bench file 'firmware/weights' to the project
# INFO: [HLS 200-10] Adding test bench file 'tb_data' to the project
# INFO: [HLS 200-10] Creating and opening solution '/home/webphy/Desktop/dnn_processor/hls4ml/model_qqqq/hls4ml_prj/myproject_prj/solution1'.
# INFO: [XFORM 203-101] Allowed max sub elements number after partition is 4096.
# INFO: [XFORM 203-1161] The maximum of name length is set into 80.
# INFO: [HLS 200-10] Setting target device to 'xc7z020-clg400-1'
# INFO: [SYN 201-201] Setting up clock 'default' with a period of 5ns.
# INFO: [SYN 201-201] Setting up clock 'default' with an uncertainty of 0.625ns.
# ***** C/RTL SYNTHESIS *****
# INFO: [SCHED 204-61] Option 'relax_ii_for_timing' is enabled, will increase II to preserve clock frequency constraints.
# INFO: [HLS 200-10] Analyzing design file 'firmware/myproject.cpp' ...
# WARNING: [HLS 200-40] In file included from firmware/myproject.cpp:1:
# In file included from firmware/myproject.cpp:4:
# In file included from firmware/parameters.h:15:
# In file included from firmware/nnet_utils/nnet_conv2d_stream.h:7:
# firmware/nnet_utils/nnet_conv_stream.h:19:10: warning: comparison of unsigned expression < 0 is always false [-Wtautological-compare]
#  if (idx < K - S) {
#      ~~~ ^ ~~~~~
# firmware/nnet_utils/nnet_conv_stream.h:64:20: note: in instantiation of function template specialization 'nnet::scale_index_K_gte_S<4, 4, 128>' requested here
#             return scale_index_K_gte_S<K, S, W>(idx);
#                    ^
# firmware/nnet_utils/nnet_conv2d_stream.h:15:89: note: in instantiation of member function 'nnet::scale_index_regular<4, 4, 128>::scale_index' requested here
#                                                                   CONFIG_T::in_height>::scale_index(h_idx);
#                                                                                         ^
# firmware/nnet_utils/nnet_conv2d_stream.h:59:13: note: in instantiation of function template specialization 'nnet::compute_scaled_indices_2d<nnet::array<ap_ufixed<8, 0, 4, 0, 0>, 3>, config3>' requested here
#             compute_scaled_indices_2d<data_T, CONFIG_T>(i_ih, i_iw, pixel_idx);
#             ^
# firmware/nnet_utils/nnet_conv2d_stream.h:106:9: note: in instantiation of function template specialization 'nnet::conv_2d_encoded_cl<nnet::array<ap_ufixed<8, 0, 4, 0, 0>, 3>, nnet::array<ap_fixed<8, 1, 5, 3, 0>, 4>, config3>' requested here
#         conv_2d_encoded_cl<data_T, res_T, CONFIG_T>(data, res, weights, biases);
#         ^
# firmware/myproject.cpp:51:2: note: in instantiation of function template specialization 'nnet::conv_2d_cl<nnet::array<ap_ufixed<8, 0, 4, 0, 0>, 3>, nnet::array<ap_fixed<8, 1, 5, 3, 0>, 4>, config3>' requested here
#  nnet::conv_2d_cl<layer2_t, layer3_t, config3>(layer2_out, layer3_out, w3, b3);
#  ^
# In file included from firmware/myproject.cpp:1:
# In file included from firmware/myproject.cpp:4:
# In file included from firmware/parameters.h:15:
# In file included from firmware/nnet_utils/nnet_conv2d_stream.h:7:
# firmware/nnet_utils/nnet_conv_stream.h:40:10: warning: comparison of unsigned expression < 0 is always false [-Wtautological-compare]
#  if (idx < S - K) {
#      ~~~ ^ ~~~~~
# firmware/nnet_utils/nnet_conv_stream.h:66:20: note: in instantiation of function template specialization 'nnet::scale_index_K_lt_S<4, 4, 128>' requested here
#             return scale_index_K_lt_S<K, S, W>(idx);
#                    ^
# firmware/nnet_utils/nnet_conv2d_stream.h:15:89: note: in instantiation of member function 'nnet::scale_index_regular<4, 4, 128>::scale_index' requested here
#                                                                   CONFIG_T::in_height>::scale_index(h_idx);
#                                                                                         ^
# firmware/nnet_utils/nnet_conv2d_stream.h:59:13: note: in instantiation of function template specialization 'nnet::compute_scaled_indices_2d<nnet::array<ap_ufixed<8, 0, 4, 0, 0>, 3>, config3>' requested here
#             compute_scaled_indices_2d<data_T, CONFIG_T>(i_ih, i_iw, pixel_idx);
#             ^
# firmware/nnet_utils/nnet_conv2d_stream.h:106:9: note: in instantiation of function template specialization 'nnet::conv_2d_encoded_cl<nnet::array<ap_ufixed<8, 0, 4, 0, 0>, 3>, nnet::array<ap_fixed<8, 1, 5, 3, 0>, 4>, config3>' requested here
#         conv_2d_encoded_cl<data_T, res_T, CONFIG_T>(data, res, weights, biases);
#         ^
# firmware/myproject.cpp:51:2: note: in instantiation of function template specialization 'nnet::conv_2d_cl<nnet::array<ap_ufixed<8, 0, 4, 0, 0>, 3>, nnet::array<ap_fixed<8, 1, 5, 3, 0>, 4>, config3>' requested here
#  nnet::conv_2d_cl<layer2_t, layer3_t, config3>(layer2_out, layer3_out, w3, b3);
#  ^
# 2 warnings generated.
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/myproject.cpp:51:72
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/myproject.cpp:51:76
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/myproject.cpp:55:74
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/myproject.cpp:55:79
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/myproject.cpp:63:72
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/myproject.cpp:63:76
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/myproject.cpp:67:74
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/myproject.cpp:67:79
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/myproject.cpp:75:85
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/myproject.cpp:75:90
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/myproject.cpp:79:76
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/myproject.cpp:79:81
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/myproject.cpp:88:72
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/myproject.cpp:88:77
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/myproject.cpp:90:78
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/myproject.cpp:90:83
# WARNING: [HLS 200-471] Dataflow form checks found 16 issue(s) in file firmware/myproject.cpp
# INFO: [HLS 200-111] Finished Linking Time (s): cpu = 00:00:12 ; elapsed = 00:00:12 . Memory (MB): peak = 1647.832 ; gain = 1193.191 ; free physical = 3121 ; free virtual = 37577
# INFO: [HLS 200-111] Finished Checking Pragmas Time (s): cpu = 00:00:12 ; elapsed = 00:00:12 . Memory (MB): peak = 1647.832 ; gain = 1193.191 ; free physical = 3121 ; free virtual = 37577
# INFO: [HLS 200-10] Starting code transformations ...
# INFO: [HLS 200-489] Unrolling loop 'MultLoop' (firmware/nnet_utils/nnet_dense_resource.h:136) in function 'void nnet::dense_resource_rf_gt_nin_rem0<ap_fixed<4, 1, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config13>(FORWARD_REFERENCE*, FORWARD_REFERENCE*, FORWARD_REFERENCE::weight_t*, FORWARD_REFERENCE::bias_t*)' completely with a factor of 1.
# INFO: [HLS 200-489] Unrolling loop 'MultLoop' (firmware/nnet_utils/nnet_dense_resource.h:136) in function 'void nnet::dense_resource_rf_gt_nin_rem0<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config19_mult>(FORWARD_REFERENCE*, FORWARD_REFERENCE*, FORWARD_REFERENCE::weight_t*, FORWARD_REFERENCE::bias_t*)' completely with a factor of 1.
# INFO: [HLS 200-489] Unrolling loop 'MultLoop' (firmware/nnet_utils/nnet_dense_resource.h:136) in function 'void nnet::dense_resource_rf_gt_nin_rem0<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config6_mult>(FORWARD_REFERENCE*, FORWARD_REFERENCE*, FORWARD_REFERENCE::weight_t*, FORWARD_REFERENCE::bias_t*)' completely with a factor of 1.
# INFO: [HLS 200-489] Unrolling loop 'MultLoop' (firmware/nnet_utils/nnet_dense_resource.h:136) in function 'void nnet::dense_resource_rf_gt_nin_rem0<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config3_mult>(FORWARD_REFERENCE*, FORWARD_REFERENCE*, FORWARD_REFERENCE::weight_t*, FORWARD_REFERENCE::bias_t*)' completely with a factor of 1.
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 3u>::operator[]' into 'nnet::relu<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 3u>, nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 3u>, relu_config2>' (firmware/nnet_utils/nnet_activation_stream.h:52).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 3u>::operator[]' into 'nnet::relu<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 3u>, nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 3u>, relu_config2>' (firmware/nnet_utils/nnet_activation_stream.h:51).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 3u>::operator[].1' into 'nnet::relu<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 3u>, nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 3u>, relu_config2>' (firmware/nnet_utils/nnet_activation_stream.h:54).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 3u>::operator[].1' into 'nnet::relu<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 3u>, nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 3u>, relu_config2>' (firmware/nnet_utils/nnet_activation_stream.h:52).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 3u>::operator[]' into 'nnet::shift_line_buffer<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 3u>, config3>' (firmware/nnet_utils/nnet_conv_stream.h:237).
# INFO: [XFORM 203-603] Inlining function 'nnet::kernel_shift_2d<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 3u>, config3>' into 'nnet::shift_line_buffer<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 3u>, config3>' (firmware/nnet_utils/nnet_conv_stream.h:252).
# INFO: [XFORM 203-603] Inlining function 'nnet::product::mult<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0> >::product' into 'nnet::dense_resource_rf_gt_nin_rem0<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config3_mult>' (firmware/nnet_utils/nnet_dense_resource.h:139).
# INFO: [XFORM 203-603] Inlining function 'nnet::product::mult<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0> >::product' into 'nnet::dense_resource_rf_gt_nin_rem0<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config6_mult>' (firmware/nnet_utils/nnet_dense_resource.h:139).
# INFO: [XFORM 203-603] Inlining function 'nnet::product::mult<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0> >::product' into 'nnet::dense_resource_rf_gt_nin_rem0<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config19_mult>' (firmware/nnet_utils/nnet_dense_resource.h:139).
# INFO: [XFORM 203-603] Inlining function 'nnet::dense_resource_rf_gt_nin_rem0<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config3_mult>' into 'nnet::dense_resource<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config3_mult>' (firmware/nnet_utils/nnet_dense_resource.h:255).
# INFO: [XFORM 203-603] Inlining function 'nnet::cast<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config3_mult>' into 'nnet::dense_resource<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config3_mult>' (firmware/nnet_utils/nnet_dense_resource.h:158->firmware/nnet_utils/nnet_dense_resource.h:255).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 4u>::operator[]' into 'nnet::compute_output_buffer_2d<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 3u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 4u>, config3>' (firmware/nnet_utils/nnet_conv_stream.h:305).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 4u>::operator[]' into 'nnet::relu<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 4u>, nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 4u>, relu_config5>' (firmware/nnet_utils/nnet_activation_stream.h:52).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 4u>::operator[]' into 'nnet::relu<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 4u>, nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 4u>, relu_config5>' (firmware/nnet_utils/nnet_activation_stream.h:51).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 4u>::operator[]' into 'nnet::normalize<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 4u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 4u>, config15>' (firmware/nnet_utils/nnet_batchnorm_stream.h:42).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 4u>::operator[]' into 'nnet::normalize<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 4u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 4u>, config15>' (firmware/nnet_utils/nnet_batchnorm_stream.h:41).
# INFO: [XFORM 203-603] Inlining function 'nnet::conv_2d_buffer_cl<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 3u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 4u>, config3>' into 'nnet::conv_2d_cl<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 3u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 4u>, config3>' (firmware/nnet_utils/nnet_conv2d_stream.h:103).
# INFO: [XFORM 203-603] Inlining function 'nnet::product::weight_exponential<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, exponent_scale15_t>::product' into 'nnet::normalize<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 4u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 4u>, config15>' (firmware/nnet_utils/nnet_batchnorm_stream.h:42).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 4u>::operator[].1' into 'nnet::relu<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 4u>, nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 4u>, relu_config5>' (firmware/nnet_utils/nnet_activation_stream.h:54).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 4u>::operator[].1' into 'nnet::relu<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 4u>, nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 4u>, relu_config5>' (firmware/nnet_utils/nnet_activation_stream.h:52).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 4u>::operator[]' into 'nnet::shift_line_buffer<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 4u>, config6>' (firmware/nnet_utils/nnet_conv_stream.h:237).
# INFO: [XFORM 203-603] Inlining function 'nnet::kernel_shift_2d<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 4u>, config6>' into 'nnet::shift_line_buffer<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 4u>, config6>' (firmware/nnet_utils/nnet_conv_stream.h:252).
# INFO: [XFORM 203-603] Inlining function 'nnet::dense_resource_rf_gt_nin_rem0<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config6_mult>' into 'nnet::dense_resource<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config6_mult>' (firmware/nnet_utils/nnet_dense_resource.h:255).
# INFO: [XFORM 203-603] Inlining function 'nnet::cast<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config6_mult>' into 'nnet::dense_resource<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config6_mult>' (firmware/nnet_utils/nnet_dense_resource.h:158->firmware/nnet_utils/nnet_dense_resource.h:255).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>::operator[]' into 'nnet::compute_output_buffer_2d<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 4u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config6>' (firmware/nnet_utils/nnet_conv_stream.h:305).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>::operator[]' into 'nnet::relu<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>, relu_config8>' (firmware/nnet_utils/nnet_activation_stream.h:52).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>::operator[]' into 'nnet::relu<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>, relu_config8>' (firmware/nnet_utils/nnet_activation_stream.h:51).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>::operator[]' into 'nnet::normalize<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config16>' (firmware/nnet_utils/nnet_batchnorm_stream.h:42).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>::operator[]' into 'nnet::normalize<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config16>' (firmware/nnet_utils/nnet_batchnorm_stream.h:41).
# INFO: [XFORM 203-603] Inlining function 'nnet::conv_2d_buffer_cl<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 4u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config6>' into 'nnet::conv_2d_cl<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 4u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config6>' (firmware/nnet_utils/nnet_conv2d_stream.h:103).
# INFO: [XFORM 203-603] Inlining function 'nnet::product::weight_exponential<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, exponent_scale16_t>::product' into 'nnet::normalize<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config16>' (firmware/nnet_utils/nnet_batchnorm_stream.h:42).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>::operator[].1' into 'nnet::relu<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>, relu_config8>' (firmware/nnet_utils/nnet_activation_stream.h:54).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>::operator[].1' into 'nnet::relu<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>, relu_config8>' (firmware/nnet_utils/nnet_activation_stream.h:52).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>::operator[]' into 'nnet::pointwise_mult_buffer<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config19>' (firmware/nnet_utils/nnet_sepconv_stream.h:153).
# INFO: [XFORM 203-603] Inlining function 'nnet::dense_resource_rf_gt_nin_rem0<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config19_mult>' into 'nnet::dense_resource<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config19_mult>' (firmware/nnet_utils/nnet_dense_resource.h:255).
# INFO: [XFORM 203-603] Inlining function 'nnet::cast<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config19_mult>' into 'nnet::dense_resource<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config19_mult>' (firmware/nnet_utils/nnet_dense_resource.h:158->firmware/nnet_utils/nnet_dense_resource.h:255).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>::operator[]' into 'nnet::pointwise_mult_buffer<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config19>' (firmware/nnet_utils/nnet_sepconv_stream.h:168).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>::operator[]' into 'nnet::normalize<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config18>' (firmware/nnet_utils/nnet_batchnorm_stream.h:42).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>::operator[]' into 'nnet::normalize<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config18>' (firmware/nnet_utils/nnet_batchnorm_stream.h:41).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>::operator[]' into 'nnet::dense<nnet::array<ap_fixed<4, 1, (ap_q_mode)4, (ap_o_mode)0, 0>, 5u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config13>' (firmware/nnet_utils/nnet_dense_stream.h:60).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>::operator[]' into 'nnet::linear<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, nnet::array<ap_fixed<4, 1, (ap_q_mode)4, (ap_o_mode)0, 0>, 5u>, linear_config11>' (firmware/nnet_utils/nnet_activation_stream.h:29).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>::operator[]' into 'nnet::normalize<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config17>' (firmware/nnet_utils/nnet_batchnorm_stream.h:42).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>::operator[]' into 'nnet::normalize<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config17>' (firmware/nnet_utils/nnet_batchnorm_stream.h:41).
# INFO: [XFORM 203-603] Inlining function 'nnet::dense_resource<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config19_mult>' into 'nnet::pointwise_mult_buffer<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config19>' (firmware/nnet_utils/nnet_sepconv_stream.h:161).
# INFO: [XFORM 203-603] Inlining function 'nnet::pointwise_mult_buffer<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config19>' into 'nnet::pointwise_conv_2d_cl<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config19>' (firmware/nnet_utils/nnet_sepconv2d_stream.h:113).
# INFO: [XFORM 203-603] Inlining function 'nnet::product::weight_exponential<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, exponent_scale17_t>::product' into 'nnet::normalize<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config17>' (firmware/nnet_utils/nnet_batchnorm_stream.h:42).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<4, 1, (ap_q_mode)4, (ap_o_mode)0, 0>, 5u>::operator[]' into 'nnet::dense<nnet::array<ap_fixed<4, 1, (ap_q_mode)4, (ap_o_mode)0, 0>, 5u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config13>' (firmware/nnet_utils/nnet_dense_stream.h:44).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<4, 1, (ap_q_mode)4, (ap_o_mode)0, 0>, 5u>::operator[]' into 'nnet::linear<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, nnet::array<ap_fixed<4, 1, (ap_q_mode)4, (ap_o_mode)0, 0>, 5u>, linear_config11>' (firmware/nnet_utils/nnet_activation_stream.h:29).
# INFO: [XFORM 203-603] Inlining function 'nnet::product::mult<ap_fixed<4, 1, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0> >::product' into 'nnet::dense_resource_rf_gt_nin_rem0<ap_fixed<4, 1, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config13>' (firmware/nnet_utils/nnet_dense_resource.h:139).
# INFO: [XFORM 203-603] Inlining function 'nnet::dense_resource_rf_gt_nin_rem0<ap_fixed<4, 1, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config13>' into 'nnet::dense_resource<ap_fixed<4, 1, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config13>' (firmware/nnet_utils/nnet_dense_resource.h:255).
# INFO: [XFORM 203-603] Inlining function 'nnet::cast<ap_fixed<4, 1, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config13>' into 'nnet::dense_resource<ap_fixed<4, 1, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config13>' (firmware/nnet_utils/nnet_dense_resource.h:158->firmware/nnet_utils/nnet_dense_resource.h:255).
# INFO: [XFORM 203-603] Inlining function 'nnet::dense_resource<ap_fixed<4, 1, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config13>' into 'nnet::dense_wrapper<ap_fixed<4, 1, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config13>' (firmware/nnet_utils/nnet_dense_stream.h:21).
# INFO: [XFORM 203-603] Inlining function 'nnet::product::weight_exponential<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, exponent_scale18_t>::product' into 'nnet::normalize<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config18>' (firmware/nnet_utils/nnet_batchnorm_stream.h:42).
# INFO: [HLS 200-111] Finished Standard Transforms Time (s): cpu = 00:00:14 ; elapsed = 00:00:15 . Memory (MB): peak = 1647.832 ; gain = 1193.191 ; free physical = 2900 ; free virtual = 37360
# INFO: [HLS 200-10] Checking synthesizability ...
# INFO: [HLS 200-111] Finished Checking Synthesizability Time (s): cpu = 00:00:15 ; elapsed = 00:00:15 . Memory (MB): peak = 1647.832 ; gain = 1193.191 ; free physical = 2902 ; free virtual = 37363
# INFO: [XFORM 203-1101] Packing variable 'out_data.data.V' (firmware/nnet_utils/nnet_activation_stream.h:45) into a 32-bit variable.
# INFO: [XFORM 203-1101] Packing variable 'out_data.data.V' (firmware/nnet_utils/nnet_activation_stream.h:45) into a 24-bit variable.
# INFO: [XFORM 203-1101] Packing variable 'out_data.data.V' (firmware/nnet_utils/nnet_activation_stream.h:45) into a 128-bit variable.
# INFO: [XFORM 203-1101] Packing variable 'res_pack.data.V' (firmware/nnet_utils/nnet_sepconv_stream.h:147) into a 40-bit variable.
# INFO: [XFORM 203-1101] Packing variable 'out_data.data.V' (firmware/nnet_utils/nnet_batchnorm_stream.h:29) into a 40-bit variable.
# INFO: [XFORM 203-1101] Packing variable 'out_data.data.V' (firmware/nnet_utils/nnet_batchnorm_stream.h:29) into a 40-bit variable.
# INFO: [XFORM 203-1101] Packing variable 'out_data.data.V' (firmware/nnet_utils/nnet_batchnorm_stream.h:29) into a 32-bit variable.
# INFO: [XFORM 203-1101] Packing variable 'out_data.data.V' (firmware/nnet_utils/nnet_batchnorm_stream.h:29) into a 128-bit variable.
# INFO: [XFORM 203-1101] Packing variable 'out_data.data.V' (firmware/nnet_utils/nnet_activation_stream.h:23) into a 20-bit variable.
# INFO: [XFORM 203-1101] Packing variable 'res_pack.data.V' (firmware/nnet_utils/nnet_dense_stream.h:55) into a 40-bit variable.
# INFO: [XFORM 203-1101] Packing variable 'res_pack.data.V' (firmware/nnet_utils/nnet_conv_stream.h:282) into a 128-bit variable.
# INFO: [XFORM 203-1101] Packing variable 'res_pack.data.V' (firmware/nnet_utils/nnet_conv_stream.h:282) into a 32-bit variable.
# INFO: [XFORM 203-502] Unrolling all sub-loops inside loop 'ReLUActLoop' (firmware/nnet_utils/nnet_activation_stream.h:41) in function 'nnet::relu<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 4u>, nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 4u>, relu_config5>' for pipelining.
# INFO: [XFORM 203-502] Unrolling all sub-loops inside loop 'ReLUActLoop' (firmware/nnet_utils/nnet_activation_stream.h:41) in function 'nnet::relu<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 3u>, nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 3u>, relu_config2>' for pipelining.
# INFO: [XFORM 203-502] Unrolling all sub-loops inside loop 'ReLUActLoop' (firmware/nnet_utils/nnet_activation_stream.h:41) in function 'nnet::relu<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>, relu_config8>' for pipelining.
# INFO: [XFORM 203-502] Unrolling all loops for pipelining in function 'nnet::normalize<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config18>' (firmware/nnet_utils/nnet_batchnorm_stream.h:18:43).
# INFO: [XFORM 203-502] Unrolling all sub-loops inside loop 'BatchNormLoop' (firmware/nnet_utils/nnet_batchnorm_stream.h:25) in function 'nnet::normalize<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config17>' for pipelining.
# INFO: [XFORM 203-502] Unrolling all sub-loops inside loop 'BatchNormLoop' (firmware/nnet_utils/nnet_batchnorm_stream.h:25) in function 'nnet::normalize<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 4u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 4u>, config15>' for pipelining.
# INFO: [XFORM 203-502] Unrolling all sub-loops inside loop 'BatchNormLoop' (firmware/nnet_utils/nnet_batchnorm_stream.h:25) in function 'nnet::normalize<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config16>' for pipelining.
# INFO: [XFORM 203-502] Unrolling all sub-loops inside loop 'LinearActLoop' (firmware/nnet_utils/nnet_activation_stream.h:19) in function 'nnet::linear<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, nnet::array<ap_fixed<4, 1, (ap_q_mode)4, (ap_o_mode)0, 0>, 5u>, linear_config11>' for pipelining.
# INFO: [XFORM 203-502] Unrolling all sub-loops inside loop 'DataPrepare' (firmware/nnet_utils/nnet_dense_stream.h:36) in function 'nnet::dense<nnet::array<ap_fixed<4, 1, (ap_q_mode)4, (ap_o_mode)0, 0>, 5u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config13>' for pipelining.
# INFO: [XFORM 203-502] Unrolling all loops for pipelining in function 'nnet::shift_line_buffer<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 4u>, config6>' (firmware/nnet_utils/nnet_conv_stream.h:194:62).
# WARNING: [XFORM 203-505] Ignored pipeline directive for loop 'KernelShiftWidth' (firmware/nnet_utils/nnet_conv_stream.h:194) because its parent loop or function is pipelined.
# INFO: [XFORM 203-502] Unrolling all loops for pipelining in function 'nnet::shift_line_buffer<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 3u>, config3>' (firmware/nnet_utils/nnet_conv_stream.h:194:62).
# WARNING: [XFORM 203-505] Ignored pipeline directive for loop 'KernelShiftWidth' (firmware/nnet_utils/nnet_conv_stream.h:194) because its parent loop or function is pipelined.
# INFO: [HLS 200-489] Unrolling loop 'ReLUPackLoop' (firmware/nnet_utils/nnet_activation_stream.h:49) in function 'nnet::relu<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 4u>, nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 4u>, relu_config5>' completely with a factor of 4.
# INFO: [HLS 200-489] Unrolling loop 'ReLUPackLoop' (firmware/nnet_utils/nnet_activation_stream.h:49) in function 'nnet::relu<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 3u>, nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 3u>, relu_config2>' completely with a factor of 3.
# INFO: [HLS 200-489] Unrolling loop 'ReLUPackLoop' (firmware/nnet_utils/nnet_activation_stream.h:49) in function 'nnet::relu<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>, relu_config8>' completely with a factor of 16.
# INFO: [HLS 200-489] Unrolling loop 'InitData' (firmware/nnet_utils/nnet_sepconv_stream.h:151) in function 'nnet::pointwise_conv_2d_cl<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config19>' completely with a factor of 16.
# INFO: [HLS 200-489] Unrolling loop 'InitAccum' (firmware/nnet_utils/nnet_dense_resource.h:108) in function 'nnet::pointwise_conv_2d_cl<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config19>' completely with a factor of 5.
# INFO: [HLS 200-489] Unrolling loop 'Result' (firmware/nnet_utils/nnet_dense_resource.h:156) in function 'nnet::pointwise_conv_2d_cl<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config19>' completely with a factor of 5.
# INFO: [HLS 200-489] Unrolling loop 'CastLoop' (firmware/nnet_utils/nnet_sepconv_stream.h:166) in function 'nnet::pointwise_conv_2d_cl<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config19>' completely with a factor of 5.
# INFO: [HLS 200-489] Unrolling loop 'BatchNormpack' (firmware/nnet_utils/nnet_batchnorm_stream.h:33) in function 'nnet::normalize<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config18>' completely with a factor of 5.
# INFO: [HLS 200-489] Unrolling loop 'BatchNormpack' (firmware/nnet_utils/nnet_batchnorm_stream.h:33) in function 'nnet::normalize<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config17>' completely with a factor of 5.
# INFO: [HLS 200-489] Unrolling loop 'BatchNormpack' (firmware/nnet_utils/nnet_batchnorm_stream.h:33) in function 'nnet::normalize<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 4u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 4u>, config15>' completely with a factor of 4.
# INFO: [HLS 200-489] Unrolling loop 'BatchNormpack' (firmware/nnet_utils/nnet_batchnorm_stream.h:33) in function 'nnet::normalize<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config16>' completely with a factor of 16.
# INFO: [HLS 200-489] Unrolling loop 'LinearPackLoop' (firmware/nnet_utils/nnet_activation_stream.h:27) in function 'nnet::linear<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, nnet::array<ap_fixed<4, 1, (ap_q_mode)4, (ap_o_mode)0, 0>, 5u>, linear_config11>' completely with a factor of 5.
# INFO: [HLS 200-489] Unrolling loop 'DataPack' (firmware/nnet_utils/nnet_dense_stream.h:42) in function 'nnet::dense<nnet::array<ap_fixed<4, 1, (ap_q_mode)4, (ap_o_mode)0, 0>, 5u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config13>' completely with a factor of 5.
# INFO: [HLS 200-489] Unrolling loop 'ResPack' (firmware/nnet_utils/nnet_dense_stream.h:58) in function 'nnet::dense<nnet::array<ap_fixed<4, 1, (ap_q_mode)4, (ap_o_mode)0, 0>, 5u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config13>' completely with a factor of 5.
# INFO: [HLS 200-489] Unrolling loop 'InitAccum' (firmware/nnet_utils/nnet_dense_resource.h:108) in function 'nnet::dense_wrapper<ap_fixed<4, 1, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config13>' completely with a factor of 5.
# INFO: [HLS 200-489] Unrolling loop 'Result' (firmware/nnet_utils/nnet_dense_resource.h:156) in function 'nnet::dense_wrapper<ap_fixed<4, 1, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config13>' completely with a factor of 5.
# INFO: [HLS 200-489] Unrolling loop 'CastLoop' (firmware/nnet_utils/nnet_conv_stream.h:303) in function 'nnet::compute_output_buffer_2d<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 4u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config6>' completely with a factor of 16.
# INFO: [HLS 200-489] Unrolling loop 'InitAccum' (firmware/nnet_utils/nnet_dense_resource.h:108) in function 'nnet::dense_resource<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config6_mult>' completely with a factor of 16.
# INFO: [HLS 200-489] Unrolling loop 'Result' (firmware/nnet_utils/nnet_dense_resource.h:156) in function 'nnet::dense_resource<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config6_mult>' completely with a factor of 16.
# INFO: [HLS 200-489] Unrolling loop 'UpdateBuffer' (firmware/nnet_utils/nnet_conv_stream.h:233) in function 'nnet::shift_line_buffer<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 4u>, config6>' completely with a factor of 4.
# INFO: [HLS 200-489] Unrolling loop 'LineBufferDataIn' (firmware/nnet_utils/nnet_conv_stream.h:241) in function 'nnet::shift_line_buffer<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 4u>, config6>' completely with a factor of 4.
# INFO: [HLS 200-489] Unrolling loop 'LineBufferShift' (firmware/nnet_utils/nnet_conv_stream.h:244) in function 'nnet::shift_line_buffer<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 4u>, config6>' completely with a factor of 2.
# INFO: [HLS 200-489] Unrolling loop 'KernelShiftWidth' (firmware/nnet_utils/nnet_conv_stream.h:194) in function 'nnet::shift_line_buffer<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 4u>, config6>' completely with a factor of 2.
# INFO: [HLS 200-489] Unrolling loop 'KernelShiftHeight' (firmware/nnet_utils/nnet_conv_stream.h:197) in function 'nnet::shift_line_buffer<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 4u>, config6>' completely with a factor of 3.
# INFO: [HLS 200-489] Unrolling loop 'KernelShiftChannel' (firmware/nnet_utils/nnet_conv_stream.h:199) in function 'nnet::shift_line_buffer<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 4u>, config6>' completely with a factor of 4.
# INFO: [HLS 200-489] Unrolling loop 'KernelPushHeight' (firmware/nnet_utils/nnet_conv_stream.h:210) in function 'nnet::shift_line_buffer<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 4u>, config6>' completely with a factor of 3.
# INFO: [HLS 200-489] Unrolling loop 'KernelPushChannel' (firmware/nnet_utils/nnet_conv_stream.h:213) in function 'nnet::shift_line_buffer<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 4u>, config6>' completely with a factor of 4.
# INFO: [HLS 200-489] Unrolling loop 'CastLoop' (firmware/nnet_utils/nnet_conv_stream.h:303) in function 'nnet::compute_output_buffer_2d<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 3u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 4u>, config3>' completely with a factor of 4.
# INFO: [HLS 200-489] Unrolling loop 'InitAccum' (firmware/nnet_utils/nnet_dense_resource.h:108) in function 'nnet::dense_resource<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config3_mult>' completely with a factor of 4.
# INFO: [HLS 200-489] Unrolling loop 'Result' (firmware/nnet_utils/nnet_dense_resource.h:156) in function 'nnet::dense_resource<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config3_mult>' completely with a factor of 4.
# INFO: [HLS 200-489] Unrolling loop 'UpdateBuffer' (firmware/nnet_utils/nnet_conv_stream.h:233) in function 'nnet::shift_line_buffer<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 3u>, config3>' completely with a factor of 3.
# INFO: [HLS 200-489] Unrolling loop 'LineBufferDataIn' (firmware/nnet_utils/nnet_conv_stream.h:241) in function 'nnet::shift_line_buffer<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 3u>, config3>' completely with a factor of 3.
# INFO: [HLS 200-489] Unrolling loop 'LineBufferShift' (firmware/nnet_utils/nnet_conv_stream.h:244) in function 'nnet::shift_line_buffer<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 3u>, config3>' completely with a factor of 3.
# INFO: [HLS 200-489] Unrolling loop 'KernelShiftWidth' (firmware/nnet_utils/nnet_conv_stream.h:194) in function 'nnet::shift_line_buffer<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 3u>, config3>' completely with a factor of 3.
# INFO: [HLS 200-489] Unrolling loop 'KernelShiftHeight' (firmware/nnet_utils/nnet_conv_stream.h:197) in function 'nnet::shift_line_buffer<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 3u>, config3>' completely with a factor of 4.
# INFO: [HLS 200-489] Unrolling loop 'KernelShiftChannel' (firmware/nnet_utils/nnet_conv_stream.h:199) in function 'nnet::shift_line_buffer<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 3u>, config3>' completely with a factor of 3.
# INFO: [HLS 200-489] Unrolling loop 'KernelPushHeight' (firmware/nnet_utils/nnet_conv_stream.h:210) in function 'nnet::shift_line_buffer<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 3u>, config3>' completely with a factor of 4.
# INFO: [HLS 200-489] Unrolling loop 'KernelPushChannel' (firmware/nnet_utils/nnet_conv_stream.h:213) in function 'nnet::shift_line_buffer<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 3u>, config3>' completely with a factor of 3.
# WARNING: [XFORM 203-135] Cannot reshape array 'w19.V' : incorrect reshape factor 1.
# WARNING: [XFORM 203-135] Cannot reshape array 'w13.V' : incorrect reshape factor 1.
# WARNING: [XFORM 203-135] Cannot reshape array 'w6.V' : incorrect reshape factor 1.
# WARNING: [XFORM 203-135] Cannot reshape array 'w3.V' : incorrect reshape factor 1.
# WARNING: [XFORM 203-135] Cannot reshape array 'w19.V' : incorrect reshape factor 1.
# WARNING: [XFORM 203-135] Cannot reshape array 'w13.V' : incorrect reshape factor 1.
# WARNING: [XFORM 203-135] Cannot reshape array 'w6.V' : incorrect reshape factor 1.
# WARNING: [XFORM 203-135] Cannot reshape array 'w3.V' : incorrect reshape factor 1.
# INFO: [XFORM 203-102] Automatically partitioning shift register array 'line_buffer.Array.V.1' .
# INFO: [XFORM 203-102] Automatically partitioning shift register array 'line_buffer.Array.V' .
# INFO: [XFORM 203-102] Automatically partitioning streamed array 'layer15_out.V.data.V' (firmware/myproject.cpp:53) .
# INFO: [XFORM 203-102] Automatically partitioning streamed array 'layer5_out.V.data.V' (firmware/myproject.cpp:57) .
# INFO: [XFORM 203-102] Automatically partitioning streamed array 'input_1.V.data.V' (firmware/myproject.cpp:7) .
# INFO: [XFORM 203-102] Automatically partitioning streamed array 'layer2_out.V.data.V' (firmware/myproject.cpp:45) .
# INFO: [XFORM 203-102] Automatically partitioning streamed array 'layer16_out.V.data.V' (firmware/myproject.cpp:65) .
# INFO: [XFORM 203-102] Automatically partitioning streamed array 'layer8_out.V.data.V' (firmware/myproject.cpp:69) .
# INFO: [XFORM 203-102] Automatically partitioning streamed array 'layer19_out.V.data.V' (firmware/myproject.cpp:73) .
# INFO: [XFORM 203-102] Automatically partitioning streamed array 'layer13_out.V.data.V' (firmware/myproject.cpp:86) .
# INFO: [XFORM 203-102] Automatically partitioning streamed array 'layer18_out.V.data.V' (firmware/myproject.cpp:8) .
# INFO: [XFORM 203-102] Automatically partitioning streamed array 'layer17_out.V.data.V' (firmware/myproject.cpp:77) .
# INFO: [XFORM 203-102] Automatically partitioning streamed array 'layer3_out.V.data.V' (firmware/myproject.cpp:49) .
# INFO: [XFORM 203-102] Automatically partitioning streamed array 'layer6_out.V.data.V' (firmware/myproject.cpp:61) .
# INFO: [XFORM 203-102] Automatically partitioning streamed array 'layer11_out.V.data.V' (firmware/myproject.cpp:81) .
# INFO: [XFORM 203-101] Partitioning array 'tmp.data.V' in dimension 1 completely.
# WARNING: [XFORM 203-104] Completely partitioning array 'w19.V'  accessed through non-constant indices on dimension 1 (firmware/nnet_utils/nnet_dense_resource.h:139:17), which may result in long runtime and suboptimal QoR due to large multiplexers. Please consider wrapping the array access into a function or using a register file core instead.
# INFO: [XFORM 203-101] Partitioning array 'w19.V'  in dimension 1 completely.
# INFO: [XFORM 203-101] Partitioning array 'b19.V'  in dimension 1 completely.
# INFO: [XFORM 203-101] Partitioning array 'tmp.data.V.4' in dimension 1 completely.
# INFO: [XFORM 203-101] Partitioning array 'data.V' (firmware/nnet_utils/nnet_sepconv_stream.h:141) in dimension 1 completely.
# INFO: [XFORM 203-101] Partitioning array 'res.i'  in dimension 1 completely.
# INFO: [XFORM 203-101] Partitioning array 'acc.V' (firmware/nnet_utils/nnet_dense_resource.h:104) in dimension 1 completely.
# INFO: [XFORM 203-101] Partitioning array 's18.sign.V'  in dimension 1 completely.
# INFO: [XFORM 203-101] Partitioning array 's18.weight.V'  in dimension 1 completely.
# INFO: [XFORM 203-101] Partitioning array 'b18.V'  in dimension 1 completely.
# INFO: [XFORM 203-101] Partitioning array 'tmp.data.V' in dimension 1 completely.
# ...
# INFO: [HLS 200-111]  Elapsed time: 0.11 seconds; current allocated memory: 638.647 MB.
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [HLS 200-10] -- Generating RTL for module 'dense_wrapper_ap_fixed_4_1_4_0_0_ap_fixed_8_1_5_3_0_config13_s'
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [RTGEN 206-100] Generating core module 'myproject_mux_112511_4_2_1': 1 instance(s).
# INFO: [RTGEN 206-100] Generating core module 'myproject_mux_53_8_1_1': 1 instance(s).
# INFO: [RTGEN 206-100] Finished creating RTL model for 'dense_wrapper_ap_fixed_4_1_4_0_0_ap_fixed_8_1_5_3_0_config13_s'.
# INFO: [HLS 200-111]  Elapsed time: 0.55 seconds; current allocated memory: 661.881 MB.
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [HLS 200-10] -- Generating RTL for module 'dense_array_ap_fixed_5u_array_ap_fixed_8_1_5_3_0_5u_config13_s'
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [RTGEN 206-100] Finished creating RTL model for 'dense_array_ap_fixed_5u_array_ap_fixed_8_1_5_3_0_5u_config13_s'.
# INFO: [HLS 200-111]  Elapsed time: 4.65 seconds; current allocated memory: 753.842 MB.
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [HLS 200-10] -- Generating RTL for module 'normalize_array_ap_fixed_5u_array_ap_fixed_8_1_5_3_0_5u_config18_s'
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [RTGEN 206-100] Finished creating RTL model for 'normalize_array_ap_fixed_5u_array_ap_fixed_8_1_5_3_0_5u_config18_s'.
# INFO: [HLS 200-111]  Elapsed time: 2.63 seconds; current allocated memory: 799.850 MB.
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [HLS 200-10] -- Generating RTL for module 'myproject'
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [RTGEN 206-500] Setting interface mode on port 'myproject/input_1_V_data_0_V' to 'axis' (register, both mode).
# INFO: [RTGEN 206-500] Setting interface mode on port 'myproject/input_1_V_data_1_V' to 'axis' (register, both mode).
# INFO: [RTGEN 206-500] Setting interface mode on port 'myproject/input_1_V_data_2_V' to 'axis' (register, both mode).
# INFO: [RTGEN 206-500] Setting interface mode on port 'myproject/layer18_out_V_data_0_V' to 'axis' (register, both mode).
# INFO: [RTGEN 206-500] Setting interface mode on port 'myproject/layer18_out_V_data_1_V' to 'axis' (register, both mode).
# INFO: [RTGEN 206-500] Setting interface mode on port 'myproject/layer18_out_V_data_2_V' to 'axis' (register, both mode).
# INFO: [RTGEN 206-500] Setting interface mode on port 'myproject/layer18_out_V_data_3_V' to 'axis' (register, both mode).
# INFO: [RTGEN 206-500] Setting interface mode on port 'myproject/layer18_out_V_data_4_V' to 'axis' (register, both mode).
# INFO: [RTGEN 206-500] Setting interface mode on function 'myproject' to 'ap_ctrl_hs'.
# INFO: [SYN 201-210] Renamed object name 'start_for_linear_array_ap_fixed_5u_array_ap_fixed_4_1_4_0_0_5u_linear_config11_U0' to 'start_for_linear_array_ap_fixed_5u_array_ap_fixed_4_1_4_0_0_5u_linear_config1sc4' due to the length limit 80
# INFO: [RTGEN 206-100] Finished creating RTL model for 'myproject'.
# INFO: [HLS 200-111]  Elapsed time: 0.21 seconds; current allocated memory: 804.590 MB.
# INFO: [HLS 200-790] **** Loop Constraint Status: All loop constraints were satisfied.
# INFO: [HLS 200-789] **** Estimated Fmax: 171.61 MHz
# INFO: [RTMG 210-279] Implementing memory 'dense_resource_ap_ufixed_8_0_4_0_0_ap_fixed_8_1_5_3_0_config3_mult_s_outidx5_rom' using distributed ROMs.
# INFO: [RTMG 210-279] Implementing memory 'dense_resource_ap_ufixed_8_0_4_0_0_ap_fixed_8_1_5_3_0_config3_mult_s_w3_V_rom' using auto ROMs.
# INFO: [RTMG 210-279] Implementing memory 'dense_resource_ap_ufixed_8_0_4_0_0_ap_fixed_8_1_5_3_0_config6_mult_s_outidx4_rom' using auto ROMs.
# INFO: [RTMG 210-279] Implementing memory 'dense_resource_ap_ufixed_8_0_4_0_0_ap_fixed_8_1_5_3_0_config6_mult_s_w6_V_rom' using auto ROMs.
# INFO: [RTMG 210-279] Implementing memory 'pointwise_conv_2d_cl_array_array_ap_fixed_8_1_5_3_0_5u_config19_s_outidx3_rom' using distributed ROMs.
# INFO: [RTMG 210-288] Generating pipelined multiplexer : 'myproject_mux_112511_4_2_1'
# INFO: [RTMG 210-279] Implementing memory 'dense_wrapper_ap_fixed_4_1_4_0_0_ap_fixed_8_1_5_3_0_config13_s_outidx_rom' using auto ROMs.
# INFO: [RTMG 210-279] Implementing memory 'dense_wrapper_ap_fixed_4_1_4_0_0_ap_fixed_8_1_5_3_0_config13_s_w13_V_rom' using auto ROMs.
# INFO: [RTMG 210-285] Implementing FIFO 'layer2_out_V_data_0_V_U(fifo_w8_d16384_A)' using Block RAMs.
# INFO: [RTMG 210-285] Implementing FIFO 'layer2_out_V_data_1_V_U(fifo_w8_d16384_A)' using Block RAMs.
# INFO: [RTMG 210-285] Implementing FIFO 'layer2_out_V_data_2_V_U(fifo_w8_d16384_A)' using Block RAMs.
# INFO: [RTMG 210-285] Implementing FIFO 'layer3_out_V_data_0_V_U(fifo_w8_d1024_A)' using Block RAMs.
# INFO: [RTMG 210-285] Implementing FIFO 'layer3_out_V_data_1_V_U(fifo_w8_d1024_A)' using Block RAMs.
# INFO: [RTMG 210-285] Implementing FIFO 'layer3_out_V_data_2_V_U(fifo_w8_d1024_A)' using Block RAMs.
# INFO: [RTMG 210-285] Implementing FIFO 'layer3_out_V_data_3_V_U(fifo_w8_d1024_A)' using Block RAMs.
# INFO: [RTMG 210-285] Implementing FIFO 'layer15_out_V_data_0_V_U(fifo_w8_d1024_A)' using Block RAMs.
# INFO: [RTMG 210-285] Implementing FIFO 'layer15_out_V_data_1_V_U(fifo_w8_d1024_A)' using Block RAMs.
# INFO: [RTMG 210-285] Implementing FIFO 'layer15_out_V_data_2_V_U(fifo_w8_d1024_A)' using Block RAMs.
# INFO: [RTMG 210-285] Implementing FIFO 'layer15_out_V_data_3_V_U(fifo_w8_d1024_A)' using Block RAMs.
# INFO: [RTMG 210-285] Implementing FIFO 'layer5_out_V_data_0_V_U(fifo_w8_d1024_A)' using Block RAMs.
# INFO: [RTMG 210-285] Implementing FIFO 'layer5_out_V_data_1_V_U(fifo_w8_d1024_A)' using Block RAMs.
# INFO: [RTMG 210-285] Implementing FIFO 'layer5_out_V_data_2_V_U(fifo_w8_d1024_A)' using Block RAMs.
# INFO: [RTMG 210-285] Implementing FIFO 'layer5_out_V_data_3_V_U(fifo_w8_d1024_A)' using Block RAMs.
# INFO: [RTMG 210-285] Implementing FIFO 'layer6_out_V_data_0_V_U(fifo_w8_d225_A)' using Block RAMs.
# INFO: [RTMG 210-285] Implementing FIFO 'layer6_out_V_data_1_V_U(fifo_w8_d225_A)' using Block RAMs.
# INFO: [RTMG 210-285] Implementing FIFO 'layer6_out_V_data_2_V_U(fifo_w8_d225_A)' using Block RAMs.
# INFO: [RTMG 210-285] Implementing FIFO 'layer6_out_V_data_3_V_U(fifo_w8_d225_A)' using Block RAMs.
# INFO: [RTMG 210-285] Implementing FIFO 'layer6_out_V_data_4_V_U(fifo_w8_d225_A)' using Block RAMs.
# INFO: [RTMG 210-285] Implementing FIFO 'layer6_out_V_data_5_V_U(fifo_w8_d225_A)' using Block RAMs.
# INFO: [RTMG 210-285] Implementing FIFO 'layer6_out_V_data_6_V_U(fifo_w8_d225_A)' using Block RAMs.
# INFO: [RTMG 210-285] Implementing FIFO 'layer6_out_V_data_7_V_U(fifo_w8_d225_A)' using Block RAMs.
# INFO: [RTMG 210-285] Implementing FIFO 'layer6_out_V_data_8_V_U(fifo_w8_d225_A)' using Block RAMs.
# INFO: [RTMG 210-285] Implementing FIFO 'layer6_out_V_data_9_V_U(fifo_w8_d225_A)' using Block RAMs.
# INFO: [RTMG 210-285] Implementing FIFO 'layer6_out_V_data_10_V_U(fifo_w8_d225_A)' using Block RAMs.
# INFO: [RTMG 210-285] Implementing FIFO 'layer6_out_V_data_11_V_U(fifo_w8_d225_A)' using Block RAMs.
# INFO: [RTMG 210-285] Implementing FIFO 'layer6_out_V_data_12_V_U(fifo_w8_d225_A)' using Block RAMs.
# INFO: [RTMG 210-285] Implementing FIFO 'layer6_out_V_data_13_V_U(fifo_w8_d225_A)' using Block RAMs.
# INFO: [RTMG 210-285] Implementing FIFO 'layer6_out_V_data_14_V_U(fifo_w8_d225_A)' using Block RAMs.
# INFO: [RTMG 210-285] Implementing FIFO 'layer6_out_V_data_15_V_U(fifo_w8_d225_A)' using Block RAMs.
# INFO: [RTMG 210-285] Implementing FIFO 'layer16_out_V_data_0_V_U(fifo_w8_d225_A)' using Block RAMs.
# INFO: [RTMG 210-285] Implementing FIFO 'layer16_out_V_data_1_V_U(fifo_w8_d225_A)' using Block RAMs.
# INFO: [RTMG 210-285] Implementing FIFO 'layer16_out_V_data_2_V_U(fifo_w8_d225_A)' using Block RAMs.
# INFO: [RTMG 210-285] Implementing FIFO 'layer16_out_V_data_3_V_U(fifo_w8_d225_A)' using Block RAMs.
# INFO: [RTMG 210-285] Implementing FIFO 'layer16_out_V_data_4_V_U(fifo_w8_d225_A)' using Block RAMs.
# INFO: [RTMG 210-285] Implementing FIFO 'layer16_out_V_data_5_V_U(fifo_w8_d225_A)' using Block RAMs.
# INFO: [RTMG 210-285] Implementing FIFO 'layer16_out_V_data_6_V_U(fifo_w8_d225_A)' using Block RAMs.
# INFO: [RTMG 210-285] Implementing FIFO 'layer16_out_V_data_7_V_U(fifo_w8_d225_A)' using Block RAMs.
# INFO: [RTMG 210-285] Implementing FIFO 'layer16_out_V_data_8_V_U(fifo_w8_d225_A)' using Block RAMs.
# INFO: [RTMG 210-285] Implementing FIFO 'layer16_out_V_data_9_V_U(fifo_w8_d225_A)' using Block RAMs.
# INFO: [RTMG 210-285] Implementing FIFO 'layer16_out_V_data_10_V_U(fifo_w8_d225_A)' using Block RAMs.
# INFO: [RTMG 210-285] Implementing FIFO 'layer16_out_V_data_11_V_U(fifo_w8_d225_A)' using Block RAMs.
# INFO: [RTMG 210-285] Implementing FIFO 'layer16_out_V_data_12_V_U(fifo_w8_d225_A)' using Block RAMs.
# INFO: [RTMG 210-285] Implementing FIFO 'layer16_out_V_data_13_V_U(fifo_w8_d225_A)' using Block RAMs.
# INFO: [RTMG 210-285] Implementing FIFO 'layer16_out_V_data_14_V_U(fifo_w8_d225_A)' using Block RAMs.
# INFO: [RTMG 210-285] Implementing FIFO 'layer16_out_V_data_15_V_U(fifo_w8_d225_A)' using Block RAMs.
# INFO: [RTMG 210-285] Implementing FIFO 'layer8_out_V_data_0_V_U(fifo_w8_d225_A)' using Block RAMs.
# INFO: [RTMG 210-285] Implementing FIFO 'layer8_out_V_data_1_V_U(fifo_w8_d225_A)' using Block RAMs.
# INFO: [RTMG 210-285] Implementing FIFO 'layer8_out_V_data_2_V_U(fifo_w8_d225_A)' using Block RAMs.
# INFO: [RTMG 210-285] Implementing FIFO 'layer8_out_V_data_3_V_U(fifo_w8_d225_A)' using Block RAMs.
# INFO: [RTMG 210-285] Implementing FIFO 'layer8_out_V_data_4_V_U(fifo_w8_d225_A)' using Block RAMs.
# INFO: [RTMG 210-285] Implementing FIFO 'layer8_out_V_data_5_V_U(fifo_w8_d225_A)' using Block RAMs.
# INFO: [RTMG 210-285] Implementing FIFO 'layer8_out_V_data_6_V_U(fifo_w8_d225_A)' using Block RAMs.
# INFO: [RTMG 210-285] Implementing FIFO 'layer8_out_V_data_7_V_U(fifo_w8_d225_A)' using Block RAMs.
# INFO: [RTMG 210-285] Implementing FIFO 'layer8_out_V_data_8_V_U(fifo_w8_d225_A)' using Block RAMs.
# INFO: [RTMG 210-285] Implementing FIFO 'layer8_out_V_data_9_V_U(fifo_w8_d225_A)' using Block RAMs.
# INFO: [RTMG 210-285] Implementing FIFO 'layer8_out_V_data_10_V_U(fifo_w8_d225_A)' using Block RAMs.
# INFO: [RTMG 210-285] Implementing FIFO 'layer8_out_V_data_11_V_U(fifo_w8_d225_A)' using Block RAMs.
# INFO: [RTMG 210-285] Implementing FIFO 'layer8_out_V_data_12_V_U(fifo_w8_d225_A)' using Block RAMs.
# INFO: [RTMG 210-285] Implementing FIFO 'layer8_out_V_data_13_V_U(fifo_w8_d225_A)' using Block RAMs.
# INFO: [RTMG 210-285] Implementing FIFO 'layer8_out_V_data_14_V_U(fifo_w8_d225_A)' using Block RAMs.
# INFO: [RTMG 210-285] Implementing FIFO 'layer8_out_V_data_15_V_U(fifo_w8_d225_A)' using Block RAMs.
# INFO: [RTMG 210-285] Implementing FIFO 'layer19_out_V_data_0_V_U(fifo_w8_d225_A)' using Block RAMs.
# INFO: [RTMG 210-285] Implementing FIFO 'layer19_out_V_data_1_V_U(fifo_w8_d225_A)' using Block RAMs.
# INFO: [RTMG 210-285] Implementing FIFO 'layer19_out_V_data_2_V_U(fifo_w8_d225_A)' using Block RAMs.
# INFO: [RTMG 210-285] Implementing FIFO 'layer19_out_V_data_3_V_U(fifo_w8_d225_A)' using Block RAMs.
# INFO: [RTMG 210-285] Implementing FIFO 'layer19_out_V_data_4_V_U(fifo_w8_d225_A)' using Block RAMs.
# INFO: [RTMG 210-285] Implementing FIFO 'layer17_out_V_data_0_V_U(fifo_w8_d225_A)' using Block RAMs.
# INFO: [RTMG 210-285] Implementing FIFO 'layer17_out_V_data_1_V_U(fifo_w8_d225_A)' using Block RAMs.
# INFO: [RTMG 210-285] Implementing FIFO 'layer17_out_V_data_2_V_U(fifo_w8_d225_A)' using Block RAMs.
# INFO: [RTMG 210-285] Implementing FIFO 'layer17_out_V_data_3_V_U(fifo_w8_d225_A)' using Block RAMs.
# INFO: [RTMG 210-285] Implementing FIFO 'layer17_out_V_data_4_V_U(fifo_w8_d225_A)' using Block RAMs.
# INFO: [RTMG 210-285] Implementing FIFO 'layer11_out_V_data_0_V_U(fifo_w4_d225_A)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer11_out_V_data_1_V_U(fifo_w4_d225_A)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer11_out_V_data_2_V_U(fifo_w4_d225_A)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer11_out_V_data_3_V_U(fifo_w4_d225_A)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'layer11_out_V_data_4_V_U(fifo_w4_d225_A)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'start_for_conv_2d_cl_array_ap_ufixed_3u_array_ap_fixed_8_1_5_3_0_4u_config3_U0_U(start_for_conv_2d_cl_array_ap_ufixed_3u_array_ap_fixed_8_1_5_3_0_4u_config3_U0)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'start_for_normalize_array_ap_fixed_4u_array_ap_fixed_8_1_5_3_0_4u_config15_U0_U(start_for_normalize_array_ap_fixed_4u_array_ap_fixed_8_1_5_3_0_4u_config15_U0)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'start_for_relu_array_ap_fixed_4u_array_ap_ufixed_8_0_4_0_0_4u_relu_config5_U0_U(start_for_relu_array_ap_fixed_4u_array_ap_ufixed_8_0_4_0_0_4u_relu_config5_U0)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'start_for_conv_2d_cl_array_ap_ufixed_4u_array_ap_fixed_8_1_5_3_0_16u_config6_U0_U(start_for_conv_2d_cl_array_ap_ufixed_4u_array_ap_fixed_8_1_5_3_0_16u_config6_U0)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'start_for_normalize_array_ap_fixed_16u_array_ap_fixed_8_1_5_3_0_16u_config16_U0_U(start_for_normalize_array_ap_fixed_16u_array_ap_fixed_8_1_5_3_0_16u_config16_U0)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'start_for_relu_array_ap_fixed_16u_array_ap_ufixed_8_0_4_0_0_16u_relu_config8_U0_U(start_for_relu_array_ap_fixed_16u_array_ap_ufixed_8_0_4_0_0_16u_relu_config8_U0)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'start_for_pointwise_conv_2d_cl_array_array_ap_fixed_8_1_5_3_0_5u_config19_U0_U(start_for_pointwise_conv_2d_cl_array_array_ap_fixed_8_1_5_3_0_5u_config19_U0)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'start_for_normalize_array_ap_fixed_5u_array_ap_fixed_8_1_5_3_0_5u_config17_U0_U(start_for_normalize_array_ap_fixed_5u_array_ap_fixed_8_1_5_3_0_5u_config17_U0)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'start_for_linear_array_ap_fixed_5u_array_ap_fixed_4_1_4_0_0_5u_linear_config1sc4_U(start_for_linear_array_ap_fixed_5u_array_ap_fixed_4_1_4_0_0_5u_linear_config1sc4)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'start_for_dense_array_ap_fixed_5u_array_ap_fixed_8_1_5_3_0_5u_config13_U0_U(start_for_dense_array_ap_fixed_5u_array_ap_fixed_8_1_5_3_0_5u_config13_U0)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'start_for_normalize_array_ap_fixed_5u_array_ap_fixed_8_1_5_3_0_5u_config18_U0_U(start_for_normalize_array_ap_fixed_5u_array_ap_fixed_8_1_5_3_0_5u_config18_U0)' using Shift Registers.
# INFO: [HLS 200-111] Finished generating all RTL models Time (s): cpu = 00:01:17 ; elapsed = 00:01:20 . Memory (MB): peak = 1732.684 ; gain = 1278.043 ; free physical = 2284 ; free virtual = 36916
# INFO: [VHDL 208-304] Generating VHDL RTL for myproject.
# INFO: [VLOG 209-307] Generating Verilog RTL for myproject.
# ***** C/RTL SYNTHESIS COMPLETED IN 0h1m18s *****
# INFO: [HLS 200-112] Total elapsed time: 79.89 seconds; peak allocated memory: 804.590 MB.
# INFO: [Common 17-206] Exiting vivado_hls at Tue Feb  6 11:52:26 2024...
# Vivado synthesis report not found.
# Cosim report not found.
# Timing report not found.
# {'CSynthesisReport': {'TargetClockPeriod': '5.00',
#   'EstimatedClockPeriod': '5.827',
#   'BestLatency': '3293171',
#   'WorstLatency': '3293578',
#   'IntervalMin': '81922',
#   'IntervalMax': '3293186',
#   'BRAM_18K': '108',
#   'DSP': '0',
#   'FF': '22327',
#   'LUT': '43072',
#   'URAM': '0',
#   'AvailableBRAM_18K': '280',
#   'AvailableDSP': '220',
#   'AvailableFF': '106400',
#   'AvailableLUT': '53200',
#   'AvailableURAM': '0'}}

# %%
hls4ml.report.read_vivado_report(f"model_qqqq/hls4ml_prj")
# Out:
# Found 1 solution(s) in model_qqqq/hls4ml_prj/myproject_prj.
# Reports for solution "solution1":
#
# C simulation report not found.
# SYNTHESIS REPORT:
# ================================================================
# == Vivado HLS Report for 'myproject'
# ================================================================
# * Date:           Tue Feb  6 11:52:22 2024
#
# * Version:        2020.1 (Build 2897737 on Wed May 27 20:21:37 MDT 2020)
# * Project:        myproject_prj
# * Solution:       solution1
# * Product family: zynq
# * Target device:  xc7z020-clg400-1
#
#
# ================================================================
# == Performance Estimates
# ================================================================
# + Timing:
#     * Summary:
#     +--------+---------+----------+------------+
#     |  Clock |  Target | Estimated| Uncertainty|
#     +--------+---------+----------+------------+
#     |ap_clk  | 5.00 ns | 5.827 ns |   0.62 ns  |
#     +--------+---------+----------+------------+
#
# + Latency:
#     * Summary:
#     +---------+---------+-----------+-----------+-------+---------+----------+
#     |  Latency (cycles) |   Latency (absolute)  |     Interval    | Pipeline |
#     |   min   |   max   |    min    |    max    |  min  |   max   |   Type   |
#     +---------+---------+-----------+-----------+-------+---------+----------+
#     |  3293171|  3293578| 19.189 ms | 19.192 ms |  81922|  3293186| dataflow |
#     +---------+---------+-----------+-----------+-------+---------+----------+
#
#     + Detail:
#         * Instance:
#         +-------------------------------------------------------------------------+------------------------------------------------------------------------+---------+---------+-----------+-----------+-------+---------+----------+
#         |                                                                         |                                                                        |  Latency (cycles) |   Latency (absolute)  |     Interval    | Pipeline |
#         |                                 Instance                                |                                 Module                                 |   min   |   max   |    min    |    max    |  min  |   max   |   Type   |
#         +-------------------------------------------------------------------------+------------------------------------------------------------------------+---------+---------+-----------+-----------+-------+---------+----------+
#         |dense_array_ap_fixed_5u_array_ap_fixed_8_1_5_3_0_5u_config13_U0          |dense_array_ap_fixed_5u_array_ap_fixed_8_1_5_3_0_5u_config13_s          |     5857|     5858| 34.129 us | 34.135 us |   5857|     5858|   none   |
#         |conv_2d_cl_array_ap_ufixed_4u_array_ap_fixed_8_1_5_3_0_16u_config6_U0    |conv_2d_cl_array_ap_ufixed_4u_array_ap_fixed_8_1_5_3_0_16u_config6_s    |     5121|   599041| 29.840 us |  3.491 ms |   5121|   599041|   none   |
#         |conv_2d_cl_array_ap_ufixed_3u_array_ap_fixed_8_1_5_3_0_4u_config3_U0     |conv_2d_cl_array_ap_ufixed_3u_array_ap_fixed_8_1_5_3_0_4u_config3_s     |    81921|  3293185|  0.477 ms | 19.189 ms |  81921|  3293185|   none   |
#         |pointwise_conv_2d_cl_array_array_ap_fixed_8_1_5_3_0_5u_config19_U0       |pointwise_conv_2d_cl_array_array_ap_fixed_8_1_5_3_0_5u_config19_s       |    19350|    19350|  0.113 ms |  0.113 ms |  19350|    19350|   none   |
#         |relu_array_ap_fixed_16u_array_ap_ufixed_8_0_4_0_0_16u_relu_config8_U0    |relu_array_ap_fixed_16u_array_ap_ufixed_8_0_4_0_0_16u_relu_config8_s    |      228|      228|  1.329 us |  1.329 us |    228|      228|   none   |
#         |normalize_array_ap_fixed_16u_array_ap_fixed_8_1_5_3_0_16u_config16_U0    |normalize_array_ap_fixed_16u_array_ap_fixed_8_1_5_3_0_16u_config16_s    |      451|      451|  2.628 us |  2.628 us |    451|      451|   none   |
#         |linear_array_ap_fixed_5u_array_ap_fixed_4_1_4_0_0_5u_linear_config11_U0  |linear_array_ap_fixed_5u_array_ap_fixed_4_1_4_0_0_5u_linear_config11_s  |      229|      229|  1.334 us |  1.334 us |    229|      229|   none   |
#         |relu_array_ap_fixed_4u_array_ap_ufixed_8_0_4_0_0_4u_relu_config5_U0      |relu_array_ap_fixed_4u_array_ap_ufixed_8_0_4_0_0_4u_relu_config5_s      |     1027|     1027|  5.984 us |  5.984 us |   1027|     1027|   none   |
#         |normalize_array_ap_fixed_5u_array_ap_fixed_8_1_5_3_0_5u_config18_U0      |normalize_array_ap_fixed_5u_array_ap_fixed_8_1_5_3_0_5u_config18_s      |        1|        1|  5.827 ns |  5.827 ns |      2|        2| function |
#         |normalize_array_ap_fixed_5u_array_ap_fixed_8_1_5_3_0_5u_config17_U0      |normalize_array_ap_fixed_5u_array_ap_fixed_8_1_5_3_0_5u_config17_s      |      451|      451|  2.628 us |  2.628 us |    451|      451|   none   |
#         |relu_array_ap_fixed_3u_array_ap_ufixed_8_0_4_0_0_3u_relu_config2_U0      |relu_array_ap_fixed_3u_array_ap_ufixed_8_0_4_0_0_3u_relu_config2_s      |    16386|    16386| 95.481 us | 95.481 us |  16386|    16386|   none   |
#         |normalize_array_ap_fixed_4u_array_ap_fixed_8_1_5_3_0_4u_config15_U0      |normalize_array_ap_fixed_4u_array_ap_fixed_8_1_5_3_0_4u_config15_s      |     2049|     2049| 11.940 us | 11.940 us |   2049|     2049|   none   |
#         +-------------------------------------------------------------------------+------------------------------------------------------------------------+---------+---------+-----------+-----------+-------+---------+----------+
#
#         * Loop:
#         N/A
#
#
#
# ================================================================
# == Utilization Estimates
# ================================================================
# * Summary:
# +-----------------+---------+-------+--------+-------+-----+
# |       Name      | BRAM_18K| DSP48E|   FF   |  LUT  | URAM|
# +-----------------+---------+-------+--------+-------+-----+
# |DSP              |        -|      -|       -|      -|    -|
# |Expression       |        -|      -|       0|      2|    -|
# |FIFO             |       99|      -|    3275|   6129|    -|
# |Instance         |        9|      0|   19052|  36941|    -|
# |Memory           |        -|      -|       -|      -|    -|
# |Multiplexer      |        -|      -|       -|      -|    -|
# |Register         |        -|      -|       -|      -|    -|
# +-----------------+---------+-------+--------+-------+-----+
# |Total            |      108|      0|   22327|  43072|    0|
# +-----------------+---------+-------+--------+-------+-----+
# |Available        |      280|    220|  106400|  53200|    0|
# +-----------------+---------+-------+--------+-------+-----+
# |Utilization (%)  |       38|      0|      20|     80|    0|
# +-----------------+---------+-------+--------+-------+-----+
#
# + Detail:
#     * Instance:
#     +-------------------------------------------------------------------------+------------------------------------------------------------------------+---------+-------+-------+-------+-----+
#     |                                 Instance                                |                                 Module                                 | BRAM_18K| DSP48E|   FF  |  LUT  | URAM|
#     +-------------------------------------------------------------------------+------------------------------------------------------------------------+---------+-------+-------+-------+-----+
#     |conv_2d_cl_array_ap_ufixed_3u_array_ap_fixed_8_1_5_3_0_4u_config3_U0     |conv_2d_cl_array_ap_ufixed_3u_array_ap_fixed_8_1_5_3_0_4u_config3_s     |        1|      0|   2076|   2617|    0|
#     |conv_2d_cl_array_ap_ufixed_4u_array_ap_fixed_8_1_5_3_0_16u_config6_U0    |conv_2d_cl_array_ap_ufixed_4u_array_ap_fixed_8_1_5_3_0_16u_config6_s    |        2|      0|   1871|   2745|    0|
#     |dense_array_ap_fixed_5u_array_ap_fixed_8_1_5_3_0_5u_config13_U0          |dense_array_ap_fixed_5u_array_ap_fixed_8_1_5_3_0_5u_config13_s          |        6|      0|  13915|  27965|    0|
#     |linear_array_ap_fixed_5u_array_ap_fixed_4_1_4_0_0_5u_linear_config11_U0  |linear_array_ap_fixed_5u_array_ap_fixed_4_1_4_0_0_5u_linear_config11_s  |        0|      0|    147|    400|    0|
#     |normalize_array_ap_fixed_16u_array_ap_fixed_8_1_5_3_0_16u_config16_U0    |normalize_array_ap_fixed_16u_array_ap_fixed_8_1_5_3_0_16u_config16_s    |        0|      0|    147|    552|    0|
#     |normalize_array_ap_fixed_4u_array_ap_fixed_8_1_5_3_0_4u_config15_U0      |normalize_array_ap_fixed_4u_array_ap_fixed_8_1_5_3_0_4u_config15_s      |        0|      0|     55|    206|    0|
#     |normalize_array_ap_fixed_5u_array_ap_fixed_8_1_5_3_0_5u_config17_U0      |normalize_array_ap_fixed_5u_array_ap_fixed_8_1_5_3_0_5u_config17_s      |        0|      0|     61|    237|    0|
#     |normalize_array_ap_fixed_5u_array_ap_fixed_8_1_5_3_0_5u_config18_U0      |normalize_array_ap_fixed_5u_array_ap_fixed_8_1_5_3_0_5u_config18_s      |        0|      0|      3|    185|    0|
#     |pointwise_conv_2d_cl_array_array_ap_fixed_8_1_5_3_0_5u_config19_U0       |pointwise_conv_2d_cl_array_array_ap_fixed_8_1_5_3_0_5u_config19_s       |        0|      0|    514|    854|    0|
#     |relu_array_ap_fixed_16u_array_ap_ufixed_8_0_4_0_0_16u_relu_config8_U0    |relu_array_ap_fixed_16u_array_ap_ufixed_8_0_4_0_0_16u_relu_config8_s    |        0|      0|    162|    700|    0|
#     |relu_array_ap_fixed_3u_array_ap_ufixed_8_0_4_0_0_3u_relu_config2_U0      |relu_array_ap_fixed_3u_array_ap_ufixed_8_0_4_0_0_3u_relu_config2_s      |        0|      0|     44|    224|    0|
#     |relu_array_ap_fixed_4u_array_ap_ufixed_8_0_4_0_0_4u_relu_config5_U0      |relu_array_ap_fixed_4u_array_ap_ufixed_8_0_4_0_0_4u_relu_config5_s      |        0|      0|     57|    256|    0|
#     +-------------------------------------------------------------------------+------------------------------------------------------------------------+---------+-------+-------+-------+-----+
#     |Total                                                                    |                                                                        |        9|      0|  19052|  36941|    0|
#     +-------------------------------------------------------------------------+------------------------------------------------------------------------+---------+-------+-------+-------+-----+
#
# Co-simulation report not found.

# %% [markdown]
# # build for Pynq

# %%
output_dir=f"deploy/qmodel_test/hls4ml_prj"

hls_model = hls4ml.converters.convert_from_keras_model(
    qkeras_model,
    hls_config=config,
    output_dir=output_dir,
    part="xc7z020-clg400-1",
    io_type="io_stream",
    backend='VivadoAccelerator',
    board='pynq-z2'
)

hls_model.compile()
hls_model.build(csim=False, export=True, bitfile=True)
# Out:
# Interpreting Model
# Topology:
# Layer name: input_1, layer type: InputLayer, input shapes: [[None, 128, 128, 3]], output shape: [None, 128, 128, 3]
# Layer name: q_activation, layer type: Activation, input shapes: [[None, 128, 128, 3]], output shape: [None, 128, 128, 3]
# Layer name: q_conv2d, layer type: QConv2D, input shapes: [[None, 128, 128, 3]], output shape: [None, 32, 32, 4]
# Layer name: q_activation_1, layer type: Activation, input shapes: [[None, 32, 32, 4]], output shape: [None, 32, 32, 4]
# Layer name: q_conv2d_1, layer type: QConv2D, input shapes: [[None, 32, 32, 4]], output shape: [None, 15, 15, 16]
# Layer name: q_activation_2, layer type: Activation, input shapes: [[None, 15, 15, 16]], output shape: [None, 15, 15, 16]
# Layer name: q_conv2d_2, layer type: QConv2D, input shapes: [[None, 15, 15, 16]], output shape: [None, 15, 15, 5]
# Layer name: q_activation_3, layer type: Activation, input shapes: [[None, 15, 15, 5]], output shape: [None, 15, 15, 5]
# Layer name: flatten, layer type: Reshape, input shapes: [[None, 15, 15, 5]], output shape: [None, 1125]
# Layer name: q_dense, layer type: QDense, input shapes: [[None, 1125]], output shape: [None, 5]
# Creating HLS model
# WARNING: Strategy for layer input_1 set to "Resource", while pipeline style set to "pipeline".
# WARNING: Strategy for layer q_activation set to "Resource", while pipeline style set to "pipeline".
# WARNING: Strategy for layer q_conv2d set to "Resource", while pipeline style set to "pipeline".
# WARNING: Strategy for layer q_conv2d_linear set to "Resource", while pipeline style set to "pipeline".
# WARNING: Strategy for layer q_activation_1 set to "Resource", while pipeline style set to "pipeline".
# WARNING: Strategy for layer q_conv2d_1 set to "Resource", while pipeline style set to "pipeline".
# WARNING: Strategy for layer q_conv2d_1_linear set to "Resource", while pipeline style set to "pipeline".
# WARNING: Strategy for layer q_activation_2 set to "Resource", while pipeline style set to "pipeline".
# WARNING: Strategy for layer q_conv2d_2 set to "Resource", while pipeline style set to "pipeline".
# WARNING: Strategy for layer q_conv2d_2_linear set to "Resource", while pipeline style set to "pipeline".
# WARNING: Strategy for layer q_activation_3 set to "Resource", while pipeline style set to "pipeline".
# WARNING: Strategy for layer flatten set to "Resource", while pipeline style set to "pipeline".
# WARNING: Strategy for layer q_dense set to "Resource", while pipeline style set to "pipeline".
# WARNING: Strategy for layer q_dense_linear set to "Resource", while pipeline style set to "pipeline".
# WARNING: Changing pipeline style to "dataflow".
# WARNING: Invalid ReuseFactor=9000 in layer "q_conv2d".Using ReuseFactor=192 instead. Valid ReuseFactor(s): 1,2,3,4,6,8,12,16,24,48,96,192.
# WARNING: Invalid ReuseFactor=9000 in layer "q_conv2d_1".Using ReuseFactor=576 instead. Valid ReuseFactor(s): 1,2,3,4,6,9,12,18,36,72,144,288,576.
# WARNING: Invalid ReuseFactor=9000 in layer "q_conv2d_2".Using ReuseFactor=80 instead. Valid ReuseFactor(s): 1,2,4,8,16,80.
# WARNING: Invalid ReuseFactor=9000 in layer "q_dense".Using ReuseFactor=5625 instead. Valid ReuseFactor(s): 1,3,5,9,15,25,45,75,125,225,375,1125,5625.
# WARNING: Config parameter "trace" overwrites an existing attribute in layer "q_conv2d_2" (PointwiseConv2D)
# WARNING: Config parameter "precision" overwrites an existing attribute in layer "q_conv2d_2" (PointwiseConv2D)
# WARNING: Config parameter "strategy" overwrites an existing attribute in layer "q_conv2d_2" (PointwiseConv2D)
# WARNING: You set a Part that does not correspond to the Board you specified. The correct Part is now set.
# Writing HLS project
# Done
#
# ****** Vivado(TM) HLS - High-Level Synthesis from C, C++ and SystemC v2020.1 (64-bit)
#   **** SW Build 2902540 on Wed May 27 19:54:35 MDT 2020
#   **** IP Build 2902112 on Wed May 27 22:43:36 MDT 2020
#     ** Copyright 1986-2020 Xilinx, Inc. All Rights Reserved.
#
# source /opt/Xilinx/Vivado/2020.1/scripts/vivado_hls/hls.tcl -notrace
# INFO: [HLS 200-10] Running '/opt/Xilinx/Vivado/2020.1/bin/unwrapped/lnx64.o/vivado_hls'
# INFO: [HLS 200-10] For user 'webphy' on host 'wesley-XPS-8950' (Linux_x86_64 version 6.5.0-15-generic) on Tue Feb 06 11:52:31 -03 2024
# INFO: [HLS 200-10] On os Ubuntu 22.04.3 LTS
# INFO: [HLS 200-10] In directory '/home/webphy/Desktop/dnn_processor/hls4ml/deploy/qmodel_test/hls4ml_prj'
# Sourcing Tcl script 'build_prj.tcl'
# INFO: [HLS 200-10] Creating and opening project '/home/webphy/Desktop/dnn_processor/hls4ml/deploy/qmodel_test/hls4ml_prj/myproject_prj'.
# INFO: [HLS 200-10] Adding design file 'firmware/myproject_axi.cpp' to the project
# INFO: [HLS 200-10] Adding design file 'firmware/myproject.cpp' to the project
# INFO: [HLS 200-10] Adding test bench file 'myproject_test.cpp' to the project
# INFO: [HLS 200-10] Adding test bench file 'firmware/weights' to the project
# INFO: [HLS 200-10] Adding test bench file 'tb_data' to the project
# INFO: [HLS 200-10] Creating and opening solution '/home/webphy/Desktop/dnn_processor/hls4ml/deploy/qmodel_test/hls4ml_prj/myproject_prj/solution1'.
# INFO: [XFORM 203-101] Allowed max sub elements number after partition is 4096.
# INFO: [XFORM 203-1161] The maximum of name length is set into 80.
# INFO: [HLS 200-10] Setting target device to 'xc7z020-clg400-1'
# INFO: [SYN 201-201] Setting up clock 'default' with a period of 5ns.
# INFO: [SYN 201-201] Setting up clock 'default' with an uncertainty of 0.625ns.
# ***** C/RTL SYNTHESIS *****
# INFO: [SCHED 204-61] Option 'relax_ii_for_timing' is enabled, will increase II to preserve clock frequency constraints.
# INFO: [HLS 200-10] Analyzing design file 'firmware/myproject.cpp' ...
# WARNING: [HLS 200-40] In file included from firmware/myproject.cpp:1:
# In file included from firmware/myproject.cpp:4:
# In file included from firmware/parameters.h:15:
# In file included from firmware/nnet_utils/nnet_conv2d_stream.h:7:
# firmware/nnet_utils/nnet_conv_stream.h:19:10: warning: comparison of unsigned expression < 0 is always false [-Wtautological-compare]
#  if (idx < K - S) {
#      ~~~ ^ ~~~~~
# firmware/nnet_utils/nnet_conv_stream.h:64:20: note: in instantiation of function template specialization 'nnet::scale_index_K_gte_S<4, 4, 128>' requested here
#             return scale_index_K_gte_S<K, S, W>(idx);
#                    ^
# firmware/nnet_utils/nnet_conv2d_stream.h:15:89: note: in instantiation of member function 'nnet::scale_index_regular<4, 4, 128>::scale_index' requested here
#                                                                   CONFIG_T::in_height>::scale_index(h_idx);
#                                                                                         ^
# firmware/nnet_utils/nnet_conv2d_stream.h:59:13: note: in instantiation of function template specialization 'nnet::compute_scaled_indices_2d<nnet::array<ap_ufixed<8, 0, 4, 0, 0>, 3>, config3>' requested here
#             compute_scaled_indices_2d<data_T, CONFIG_T>(i_ih, i_iw, pixel_idx);
#             ^
# firmware/nnet_utils/nnet_conv2d_stream.h:106:9: note: in instantiation of function template specialization 'nnet::conv_2d_encoded_cl<nnet::array<ap_ufixed<8, 0, 4, 0, 0>, 3>, nnet::array<ap_fixed<8, 1, 5, 3, 0>, 4>, config3>' requested here
#         conv_2d_encoded_cl<data_T, res_T, CONFIG_T>(data, res, weights, biases);
#         ^
# firmware/myproject.cpp:51:2: note: in instantiation of function template specialization 'nnet::conv_2d_cl<nnet::array<ap_ufixed<8, 0, 4, 0, 0>, 3>, nnet::array<ap_fixed<8, 1, 5, 3, 0>, 4>, config3>' requested here
#  nnet::conv_2d_cl<layer2_t, layer3_t, config3>(layer2_out, layer3_out, w3, b3);
#  ^
# In file included from firmware/myproject.cpp:1:
# In file included from firmware/myproject.cpp:4:
# In file included from firmware/parameters.h:15:
# In file included from firmware/nnet_utils/nnet_conv2d_stream.h:7:
# firmware/nnet_utils/nnet_conv_stream.h:40:10: warning: comparison of unsigned expression < 0 is always false [-Wtautological-compare]
#  if (idx < S - K) {
#      ~~~ ^ ~~~~~
# firmware/nnet_utils/nnet_conv_stream.h:66:20: note: in instantiation of function template specialization 'nnet::scale_index_K_lt_S<4, 4, 128>' requested here
#             return scale_index_K_lt_S<K, S, W>(idx);
#                    ^
# firmware/nnet_utils/nnet_conv2d_stream.h:15:89: note: in instantiation of member function 'nnet::scale_index_regular<4, 4, 128>::scale_index' requested here
#                                                                   CONFIG_T::in_height>::scale_index(h_idx);
#                                                                                         ^
# firmware/nnet_utils/nnet_conv2d_stream.h:59:13: note: in instantiation of function template specialization 'nnet::compute_scaled_indices_2d<nnet::array<ap_ufixed<8, 0, 4, 0, 0>, 3>, config3>' requested here
#             compute_scaled_indices_2d<data_T, CONFIG_T>(i_ih, i_iw, pixel_idx);
#             ^
# firmware/nnet_utils/nnet_conv2d_stream.h:106:9: note: in instantiation of function template specialization 'nnet::conv_2d_encoded_cl<nnet::array<ap_ufixed<8, 0, 4, 0, 0>, 3>, nnet::array<ap_fixed<8, 1, 5, 3, 0>, 4>, config3>' requested here
#         conv_2d_encoded_cl<data_T, res_T, CONFIG_T>(data, res, weights, biases);
#         ^
# firmware/myproject.cpp:51:2: note: in instantiation of function template specialization 'nnet::conv_2d_cl<nnet::array<ap_ufixed<8, 0, 4, 0, 0>, 3>, nnet::array<ap_fixed<8, 1, 5, 3, 0>, 4>, config3>' requested here
#  nnet::conv_2d_cl<layer2_t, layer3_t, config3>(layer2_out, layer3_out, w3, b3);
#  ^
# 2 warnings generated.
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/myproject.cpp:51:72
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/myproject.cpp:51:76
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/myproject.cpp:55:74
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/myproject.cpp:55:79
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/myproject.cpp:63:72
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/myproject.cpp:63:76
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/myproject.cpp:67:74
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/myproject.cpp:67:79
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/myproject.cpp:75:85
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/myproject.cpp:75:90
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/myproject.cpp:79:76
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/myproject.cpp:79:81
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/myproject.cpp:88:72
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/myproject.cpp:88:77
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/myproject.cpp:90:78
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/myproject.cpp:90:83
# WARNING: [HLS 200-471] Dataflow form checks found 16 issue(s) in file firmware/myproject.cpp
# INFO: [HLS 200-10] Analyzing design file 'firmware/myproject_axi.cpp' ...
# WARNING: [HLS 214-114] Since the only kind of statements allowed in a canonical dataflow region are variable declarations and function calls, the compiler may not be able to correctly handle the region: firmware/myproject_axi.cpp:17:2
# WARNING: [HLS 214-114] Since the only kind of statements allowed in a canonical dataflow region are variable declarations and function calls, the compiler may not be able to correctly handle the region: firmware/myproject_axi.cpp:29:5
# WARNING: [HLS 200-471] Dataflow form checks found 2 issue(s) in file firmware/myproject_axi.cpp
# INFO: [HLS 200-111] Finished Linking Time (s): cpu = 00:00:17 ; elapsed = 00:00:17 . Memory (MB): peak = 1647.832 ; gain = 1193.191 ; free physical = 2928 ; free virtual = 37585
# INFO: [HLS 200-111] Finished Checking Pragmas Time (s): cpu = 00:00:17 ; elapsed = 00:00:17 . Memory (MB): peak = 1647.832 ; gain = 1193.191 ; free physical = 2928 ; free virtual = 37585
# INFO: [HLS 200-10] Starting code transformations ...
# INFO: [HLS 200-489] Unrolling loop 'MultLoop' (firmware/nnet_utils/nnet_dense_resource.h:136) in function 'void nnet::dense_resource_rf_gt_nin_rem0<ap_fixed<4, 1, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config13>(FORWARD_REFERENCE*, FORWARD_REFERENCE*, FORWARD_REFERENCE::weight_t*, FORWARD_REFERENCE::bias_t*)' completely with a factor of 1.
# INFO: [HLS 200-489] Unrolling loop 'MultLoop' (firmware/nnet_utils/nnet_dense_resource.h:136) in function 'void nnet::dense_resource_rf_gt_nin_rem0<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config19_mult>(FORWARD_REFERENCE*, FORWARD_REFERENCE*, FORWARD_REFERENCE::weight_t*, FORWARD_REFERENCE::bias_t*)' completely with a factor of 1.
# INFO: [HLS 200-489] Unrolling loop 'MultLoop' (firmware/nnet_utils/nnet_dense_resource.h:136) in function 'void nnet::dense_resource_rf_gt_nin_rem0<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config6_mult>(FORWARD_REFERENCE*, FORWARD_REFERENCE*, FORWARD_REFERENCE::weight_t*, FORWARD_REFERENCE::bias_t*)' completely with a factor of 1.
# INFO: [HLS 200-489] Unrolling loop 'MultLoop' (firmware/nnet_utils/nnet_dense_resource.h:136) in function 'void nnet::dense_resource_rf_gt_nin_rem0<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config3_mult>(FORWARD_REFERENCE*, FORWARD_REFERENCE*, FORWARD_REFERENCE::weight_t*, FORWARD_REFERENCE::bias_t*)' completely with a factor of 1.
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 3u>::operator[]' into 'myproject_axi' (firmware/myproject_axi.cpp:21).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 3u>::operator[]' into 'nnet::relu<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 3u>, nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 3u>, relu_config2>' (firmware/nnet_utils/nnet_activation_stream.h:52).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 3u>::operator[]' into 'nnet::relu<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 3u>, nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 3u>, relu_config2>' (firmware/nnet_utils/nnet_activation_stream.h:51).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 3u>::operator[].1' into 'nnet::relu<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 3u>, nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 3u>, relu_config2>' (firmware/nnet_utils/nnet_activation_stream.h:54).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 3u>::operator[].1' into 'nnet::relu<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 3u>, nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 3u>, relu_config2>' (firmware/nnet_utils/nnet_activation_stream.h:52).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 3u>::operator[]' into 'nnet::shift_line_buffer<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 3u>, config3>' (firmware/nnet_utils/nnet_conv_stream.h:237).
# INFO: [XFORM 203-603] Inlining function 'nnet::kernel_shift_2d<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 3u>, config3>' into 'nnet::shift_line_buffer<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 3u>, config3>' (firmware/nnet_utils/nnet_conv_stream.h:252).
# INFO: [XFORM 203-603] Inlining function 'nnet::product::mult<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0> >::product' into 'nnet::dense_resource_rf_gt_nin_rem0<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config3_mult>' (firmware/nnet_utils/nnet_dense_resource.h:139).
# INFO: [XFORM 203-603] Inlining function 'nnet::product::mult<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0> >::product' into 'nnet::dense_resource_rf_gt_nin_rem0<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config6_mult>' (firmware/nnet_utils/nnet_dense_resource.h:139).
# INFO: [XFORM 203-603] Inlining function 'nnet::product::mult<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0> >::product' into 'nnet::dense_resource_rf_gt_nin_rem0<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config19_mult>' (firmware/nnet_utils/nnet_dense_resource.h:139).
# INFO: [XFORM 203-603] Inlining function 'nnet::dense_resource_rf_gt_nin_rem0<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config3_mult>' into 'nnet::dense_resource<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config3_mult>' (firmware/nnet_utils/nnet_dense_resource.h:255).
# INFO: [XFORM 203-603] Inlining function 'nnet::cast<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config3_mult>' into 'nnet::dense_resource<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config3_mult>' (firmware/nnet_utils/nnet_dense_resource.h:158->firmware/nnet_utils/nnet_dense_resource.h:255).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 4u>::operator[]' into 'nnet::compute_output_buffer_2d<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 3u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 4u>, config3>' (firmware/nnet_utils/nnet_conv_stream.h:305).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 4u>::operator[]' into 'nnet::relu<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 4u>, nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 4u>, relu_config5>' (firmware/nnet_utils/nnet_activation_stream.h:52).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 4u>::operator[]' into 'nnet::relu<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 4u>, nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 4u>, relu_config5>' (firmware/nnet_utils/nnet_activation_stream.h:51).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 4u>::operator[]' into 'nnet::normalize<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 4u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 4u>, config15>' (firmware/nnet_utils/nnet_batchnorm_stream.h:42).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 4u>::operator[]' into 'nnet::normalize<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 4u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 4u>, config15>' (firmware/nnet_utils/nnet_batchnorm_stream.h:41).
# INFO: [XFORM 203-603] Inlining function 'nnet::conv_2d_buffer_cl<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 3u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 4u>, config3>' into 'nnet::conv_2d_cl<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 3u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 4u>, config3>' (firmware/nnet_utils/nnet_conv2d_stream.h:103).
# INFO: [XFORM 203-603] Inlining function 'nnet::product::weight_exponential<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, exponent_scale15_t>::product' into 'nnet::normalize<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 4u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 4u>, config15>' (firmware/nnet_utils/nnet_batchnorm_stream.h:42).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 4u>::operator[].1' into 'nnet::relu<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 4u>, nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 4u>, relu_config5>' (firmware/nnet_utils/nnet_activation_stream.h:54).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 4u>::operator[].1' into 'nnet::relu<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 4u>, nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 4u>, relu_config5>' (firmware/nnet_utils/nnet_activation_stream.h:52).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 4u>::operator[]' into 'nnet::shift_line_buffer<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 4u>, config6>' (firmware/nnet_utils/nnet_conv_stream.h:237).
# INFO: [XFORM 203-603] Inlining function 'nnet::kernel_shift_2d<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 4u>, config6>' into 'nnet::shift_line_buffer<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 4u>, config6>' (firmware/nnet_utils/nnet_conv_stream.h:252).
# INFO: [XFORM 203-603] Inlining function 'nnet::dense_resource_rf_gt_nin_rem0<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config6_mult>' into 'nnet::dense_resource<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config6_mult>' (firmware/nnet_utils/nnet_dense_resource.h:255).
# INFO: [XFORM 203-603] Inlining function 'nnet::cast<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config6_mult>' into 'nnet::dense_resource<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config6_mult>' (firmware/nnet_utils/nnet_dense_resource.h:158->firmware/nnet_utils/nnet_dense_resource.h:255).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>::operator[]' into 'nnet::compute_output_buffer_2d<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 4u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config6>' (firmware/nnet_utils/nnet_conv_stream.h:305).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>::operator[]' into 'nnet::relu<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>, relu_config8>' (firmware/nnet_utils/nnet_activation_stream.h:52).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>::operator[]' into 'nnet::relu<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>, relu_config8>' (firmware/nnet_utils/nnet_activation_stream.h:51).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>::operator[]' into 'nnet::normalize<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config16>' (firmware/nnet_utils/nnet_batchnorm_stream.h:42).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>::operator[]' into 'nnet::normalize<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config16>' (firmware/nnet_utils/nnet_batchnorm_stream.h:41).
# INFO: [XFORM 203-603] Inlining function 'nnet::conv_2d_buffer_cl<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 4u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config6>' into 'nnet::conv_2d_cl<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 4u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config6>' (firmware/nnet_utils/nnet_conv2d_stream.h:103).
# INFO: [XFORM 203-603] Inlining function 'nnet::product::weight_exponential<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, exponent_scale16_t>::product' into 'nnet::normalize<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config16>' (firmware/nnet_utils/nnet_batchnorm_stream.h:42).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>::operator[].1' into 'nnet::relu<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>, relu_config8>' (firmware/nnet_utils/nnet_activation_stream.h:54).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>::operator[].1' into 'nnet::relu<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>, relu_config8>' (firmware/nnet_utils/nnet_activation_stream.h:52).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>::operator[]' into 'nnet::pointwise_mult_buffer<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config19>' (firmware/nnet_utils/nnet_sepconv_stream.h:153).
# INFO: [XFORM 203-603] Inlining function 'nnet::dense_resource_rf_gt_nin_rem0<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config19_mult>' into 'nnet::dense_resource<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config19_mult>' (firmware/nnet_utils/nnet_dense_resource.h:255).
# INFO: [XFORM 203-603] Inlining function 'nnet::cast<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config19_mult>' into 'nnet::dense_resource<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config19_mult>' (firmware/nnet_utils/nnet_dense_resource.h:158->firmware/nnet_utils/nnet_dense_resource.h:255).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>::operator[]' into 'myproject_axi' (firmware/myproject_axi.cpp:33).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>::operator[]' into 'nnet::pointwise_mult_buffer<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config19>' (firmware/nnet_utils/nnet_sepconv_stream.h:168).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>::operator[]' into 'nnet::normalize<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config18>' (firmware/nnet_utils/nnet_batchnorm_stream.h:42).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>::operator[]' into 'nnet::normalize<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config18>' (firmware/nnet_utils/nnet_batchnorm_stream.h:41).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>::operator[]' into 'nnet::dense<nnet::array<ap_fixed<4, 1, (ap_q_mode)4, (ap_o_mode)0, 0>, 5u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config13>' (firmware/nnet_utils/nnet_dense_stream.h:60).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>::operator[]' into 'nnet::linear<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, nnet::array<ap_fixed<4, 1, (ap_q_mode)4, (ap_o_mode)0, 0>, 5u>, linear_config11>' (firmware/nnet_utils/nnet_activation_stream.h:29).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>::operator[]' into 'nnet::normalize<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config17>' (firmware/nnet_utils/nnet_batchnorm_stream.h:42).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>::operator[]' into 'nnet::normalize<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config17>' (firmware/nnet_utils/nnet_batchnorm_stream.h:41).
# INFO: [XFORM 203-603] Inlining function 'nnet::dense_resource<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config19_mult>' into 'nnet::pointwise_mult_buffer<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config19>' (firmware/nnet_utils/nnet_sepconv_stream.h:161).
# INFO: [XFORM 203-603] Inlining function 'nnet::pointwise_mult_buffer<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config19>' into 'nnet::pointwise_conv_2d_cl<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config19>' (firmware/nnet_utils/nnet_sepconv2d_stream.h:113).
# INFO: [XFORM 203-603] Inlining function 'nnet::product::weight_exponential<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, exponent_scale17_t>::product' into 'nnet::normalize<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config17>' (firmware/nnet_utils/nnet_batchnorm_stream.h:42).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<4, 1, (ap_q_mode)4, (ap_o_mode)0, 0>, 5u>::operator[]' into 'nnet::dense<nnet::array<ap_fixed<4, 1, (ap_q_mode)4, (ap_o_mode)0, 0>, 5u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config13>' (firmware/nnet_utils/nnet_dense_stream.h:44).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<4, 1, (ap_q_mode)4, (ap_o_mode)0, 0>, 5u>::operator[]' into 'nnet::linear<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, nnet::array<ap_fixed<4, 1, (ap_q_mode)4, (ap_o_mode)0, 0>, 5u>, linear_config11>' (firmware/nnet_utils/nnet_activation_stream.h:29).
# INFO: [XFORM 203-603] Inlining function 'nnet::product::mult<ap_fixed<4, 1, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0> >::product' into 'nnet::dense_resource_rf_gt_nin_rem0<ap_fixed<4, 1, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config13>' (firmware/nnet_utils/nnet_dense_resource.h:139).
# INFO: [XFORM 203-603] Inlining function 'nnet::dense_resource_rf_gt_nin_rem0<ap_fixed<4, 1, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config13>' into 'nnet::dense_resource<ap_fixed<4, 1, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config13>' (firmware/nnet_utils/nnet_dense_resource.h:255).
# INFO: [XFORM 203-603] Inlining function 'nnet::cast<ap_fixed<4, 1, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config13>' into 'nnet::dense_resource<ap_fixed<4, 1, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config13>' (firmware/nnet_utils/nnet_dense_resource.h:158->firmware/nnet_utils/nnet_dense_resource.h:255).
# INFO: [XFORM 203-603] Inlining function 'nnet::dense_resource<ap_fixed<4, 1, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config13>' into 'nnet::dense_wrapper<ap_fixed<4, 1, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config13>' (firmware/nnet_utils/nnet_dense_stream.h:21).
# INFO: [XFORM 203-603] Inlining function 'nnet::product::weight_exponential<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, exponent_scale18_t>::product' into 'nnet::normalize<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config18>' (firmware/nnet_utils/nnet_batchnorm_stream.h:42).
# INFO: [HLS 200-111] Finished Standard Transforms Time (s): cpu = 00:00:20 ; elapsed = 00:00:20 . Memory (MB): peak = 1647.832 ; gain = 1193.191 ; free physical = 2673 ; free virtual = 37337
# INFO: [HLS 200-10] Checking synthesizability ...
# WARNING: [SYNCHK 200-23] firmware/myproject_axi.cpp:33: variable-indexed range selection may cause suboptimal QoR.
# INFO: [SYNCHK 200-10] 0 error(s), 1 warning(s).
# INFO: [HLS 200-111] Finished Checking Synthesizability Time (s): cpu = 00:00:21 ; elapsed = 00:00:21 . Memory (MB): peak = 1647.832 ; gain = 1193.191 ; free physical = 2668 ; free virtual = 37335
# WARNING: [XFORM 203-803] Cannot specify interface mode 'axis' on argument 'data.V.data.V' . This interface directive will be discarded. Please apply it on an argument of top module.
# WARNING: [XFORM 203-803] Cannot specify interface mode 'axis' on argument 'res.V.data.V' . This interface directive will be discarded. Please apply it on an argument of top module.
# WARNING: [XFORM 203-803] Cannot specify interface mode 'axis' (firmware/myproject.cpp:12:1) on argument 'input_1.V.data.V' (firmware/myproject.cpp:7). This interface directive will be discarded. Please apply it on an argument of top module.
# WARNING: [XFORM 203-803] Cannot specify interface mode 'axis' (firmware/myproject.cpp:12:94) on argument 'layer18_out.V.data.V' (firmware/myproject.cpp:8). This interface directive will be discarded. Please apply it on an argument of top module.
# WARNING: [XFORM 203-1103] Ignored data pack directive on non-struct variable 'out.data' (firmware/myproject_axi.cpp:3).
# WARNING: [XFORM 203-1103] Ignored data pack directive on non-struct variable 'in.data' (firmware/myproject_axi.cpp:3).
# INFO: [XFORM 203-1101] Packing variable 'out_data.data.V' (firmware/nnet_utils/nnet_activation_stream.h:45) into a 32-bit variable.
# INFO: [XFORM 203-1101] Packing variable 'out_data.data.V' (firmware/nnet_utils/nnet_activation_stream.h:45) into a 24-bit variable.
# INFO: [XFORM 203-1101] Packing variable 'out_data.data.V' (firmware/nnet_utils/nnet_activation_stream.h:45) into a 128-bit variable.
# INFO: [XFORM 203-1101] Packing variable 'res_pack.data.V' (firmware/nnet_utils/nnet_sepconv_stream.h:147) into a 40-bit variable.
# INFO: [XFORM 203-1101] Packing variable 'out_data.data.V' (firmware/nnet_utils/nnet_batchnorm_stream.h:29) into a 40-bit variable.
# INFO: [XFORM 203-1101] Packing variable 'out_data.data.V' (firmware/nnet_utils/nnet_batchnorm_stream.h:29) into a 40-bit variable.
# INFO: [XFORM 203-1101] Packing variable 'out_data.data.V' (firmware/nnet_utils/nnet_batchnorm_stream.h:29) into a 32-bit variable.
# INFO: [XFORM 203-1101] Packing variable 'out_data.data.V' (firmware/nnet_utils/nnet_batchnorm_stream.h:29) into a 128-bit variable.
# INFO: [XFORM 203-1101] Packing variable 'out_data.data.V' (firmware/nnet_utils/nnet_activation_stream.h:23) into a 20-bit variable.
# INFO: [XFORM 203-1101] Packing variable 'res_pack.data.V' (firmware/nnet_utils/nnet_dense_stream.h:55) into a 40-bit variable.
# INFO: [XFORM 203-1101] Packing variable 'ctype.data.V' (firmware/myproject_axi.cpp:18) into a 24-bit variable.
# INFO: [XFORM 203-1101] Packing variable 'res_pack.data.V' (firmware/nnet_utils/nnet_conv_stream.h:282) into a 128-bit variable.
# INFO: [XFORM 203-1101] Packing variable 'res_pack.data.V' (firmware/nnet_utils/nnet_conv_stream.h:282) into a 32-bit variable.
# INFO: [XFORM 203-502] Unrolling all sub-loops inside loop 'ReLUActLoop' (firmware/nnet_utils/nnet_activation_stream.h:41) in function 'nnet::relu<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 4u>, nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 4u>, relu_config5>' for pipelining.
# INFO: [XFORM 203-502] Unrolling all sub-loops inside loop 'ReLUActLoop' (firmware/nnet_utils/nnet_activation_stream.h:41) in function 'nnet::relu<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 3u>, nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 3u>, relu_config2>' for pipelining.
# INFO: [XFORM 203-502] Unrolling all sub-loops inside loop 'ReLUActLoop' (firmware/nnet_utils/nnet_activation_stream.h:41) in function 'nnet::relu<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>, relu_config8>' for pipelining.
# INFO: [XFORM 203-502] Unrolling all loops for pipelining in function 'nnet::normalize<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config18>' (firmware/nnet_utils/nnet_batchnorm_stream.h:18:43).
# INFO: [XFORM 203-502] Unrolling all sub-loops inside loop 'BatchNormLoop' (firmware/nnet_utils/nnet_batchnorm_stream.h:25) in function 'nnet::normalize<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config17>' for pipelining.
# INFO: [XFORM 203-502] Unrolling all sub-loops inside loop 'BatchNormLoop' (firmware/nnet_utils/nnet_batchnorm_stream.h:25) in function 'nnet::normalize<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 4u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 4u>, config15>' for pipelining.
# INFO: [XFORM 203-502] Unrolling all sub-loops inside loop 'BatchNormLoop' (firmware/nnet_utils/nnet_batchnorm_stream.h:25) in function 'nnet::normalize<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config16>' for pipelining.
# INFO: [XFORM 203-502] Unrolling all sub-loops inside loop 'LinearActLoop' (firmware/nnet_utils/nnet_activation_stream.h:19) in function 'nnet::linear<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, nnet::array<ap_fixed<4, 1, (ap_q_mode)4, (ap_o_mode)0, 0>, 5u>, linear_config11>' for pipelining.
# INFO: [XFORM 203-502] Unrolling all sub-loops inside loop 'DataPrepare' (firmware/nnet_utils/nnet_dense_stream.h:36) in function 'nnet::dense<nnet::array<ap_fixed<4, 1, (ap_q_mode)4, (ap_o_mode)0, 0>, 5u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config13>' for pipelining.
# INFO: [XFORM 203-502] Unrolling all loops for pipelining in function 'nnet::shift_line_buffer<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 4u>, config6>' (firmware/nnet_utils/nnet_conv_stream.h:194:62).
# WARNING: [XFORM 203-505] Ignored pipeline directive for loop 'KernelShiftWidth' (firmware/nnet_utils/nnet_conv_stream.h:194) because its parent loop or function is pipelined.
# INFO: [XFORM 203-502] Unrolling all loops for pipelining in function 'nnet::shift_line_buffer<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 3u>, config3>' (firmware/nnet_utils/nnet_conv_stream.h:194:62).
# WARNING: [XFORM 203-505] Ignored pipeline directive for loop 'KernelShiftWidth' (firmware/nnet_utils/nnet_conv_stream.h:194) because its parent loop or function is pipelined.
# INFO: [HLS 200-489] Unrolling loop 'ReLUPackLoop' (firmware/nnet_utils/nnet_activation_stream.h:49) in function 'nnet::relu<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 4u>, nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 4u>, relu_config5>' completely with a factor of 4.
# INFO: [HLS 200-489] Unrolling loop 'ReLUPackLoop' (firmware/nnet_utils/nnet_activation_stream.h:49) in function 'nnet::relu<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 3u>, nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 3u>, relu_config2>' completely with a factor of 3.
# INFO: [HLS 200-489] Unrolling loop 'ReLUPackLoop' (firmware/nnet_utils/nnet_activation_stream.h:49) in function 'nnet::relu<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>, relu_config8>' completely with a factor of 16.
# INFO: [HLS 200-489] Unrolling loop 'InitData' (firmware/nnet_utils/nnet_sepconv_stream.h:151) in function 'nnet::pointwise_conv_2d_cl<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config19>' completely with a factor of 16.
# INFO: [HLS 200-489] Unrolling loop 'InitAccum' (firmware/nnet_utils/nnet_dense_resource.h:108) in function 'nnet::pointwise_conv_2d_cl<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config19>' completely with a factor of 5.
# INFO: [HLS 200-489] Unrolling loop 'Result' (firmware/nnet_utils/nnet_dense_resource.h:156) in function 'nnet::pointwise_conv_2d_cl<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config19>' completely with a factor of 5.
# INFO: [HLS 200-489] Unrolling loop 'CastLoop' (firmware/nnet_utils/nnet_sepconv_stream.h:166) in function 'nnet::pointwise_conv_2d_cl<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config19>' completely with a factor of 5.
# INFO: [HLS 200-489] Unrolling loop 'BatchNormpack' (firmware/nnet_utils/nnet_batchnorm_stream.h:33) in function 'nnet::normalize<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config18>' completely with a factor of 5.
# INFO: [HLS 200-489] Unrolling loop 'BatchNormpack' (firmware/nnet_utils/nnet_batchnorm_stream.h:33) in function 'nnet::normalize<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config17>' completely with a factor of 5.
# INFO: [HLS 200-489] Unrolling loop 'BatchNormpack' (firmware/nnet_utils/nnet_batchnorm_stream.h:33) in function 'nnet::normalize<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 4u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 4u>, config15>' completely with a factor of 4.
# INFO: [HLS 200-489] Unrolling loop 'BatchNormpack' (firmware/nnet_utils/nnet_batchnorm_stream.h:33) in function 'nnet::normalize<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config16>' completely with a factor of 16.
# INFO: [HLS 200-489] Unrolling loop 'LinearPackLoop' (firmware/nnet_utils/nnet_activation_stream.h:27) in function 'nnet::linear<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, nnet::array<ap_fixed<4, 1, (ap_q_mode)4, (ap_o_mode)0, 0>, 5u>, linear_config11>' completely with a factor of 5.
# INFO: [HLS 200-489] Unrolling loop 'DataPack' (firmware/nnet_utils/nnet_dense_stream.h:42) in function 'nnet::dense<nnet::array<ap_fixed<4, 1, (ap_q_mode)4, (ap_o_mode)0, 0>, 5u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config13>' completely with a factor of 5.
# INFO: [HLS 200-489] Unrolling loop 'ResPack' (firmware/nnet_utils/nnet_dense_stream.h:58) in function 'nnet::dense<nnet::array<ap_fixed<4, 1, (ap_q_mode)4, (ap_o_mode)0, 0>, 5u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config13>' completely with a factor of 5.
# INFO: [HLS 200-489] Unrolling loop 'InitAccum' (firmware/nnet_utils/nnet_dense_resource.h:108) in function 'nnet::dense_wrapper<ap_fixed<4, 1, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config13>' completely with a factor of 5.
# INFO: [HLS 200-489] Unrolling loop 'Result' (firmware/nnet_utils/nnet_dense_resource.h:156) in function 'nnet::dense_wrapper<ap_fixed<4, 1, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config13>' completely with a factor of 5.
# INFO: [HLS 200-489] Unrolling loop 'CastLoop' (firmware/nnet_utils/nnet_conv_stream.h:303) in function 'nnet::compute_output_buffer_2d<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 4u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config6>' completely with a factor of 16.
# INFO: [HLS 200-489] Unrolling loop 'InitAccum' (firmware/nnet_utils/nnet_dense_resource.h:108) in function 'nnet::dense_resource<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config6_mult>' completely with a factor of 16.
# INFO: [HLS 200-489] Unrolling loop 'Result' (firmware/nnet_utils/nnet_dense_resource.h:156) in function 'nnet::dense_resource<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config6_mult>' completely with a factor of 16.
# INFO: [HLS 200-489] Unrolling loop 'UpdateBuffer' (firmware/nnet_utils/nnet_conv_stream.h:233) in function 'nnet::shift_line_buffer<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 4u>, config6>' completely with a factor of 4.
# INFO: [HLS 200-489] Unrolling loop 'LineBufferDataIn' (firmware/nnet_utils/nnet_conv_stream.h:241) in function 'nnet::shift_line_buffer<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 4u>, config6>' completely with a factor of 4.
# INFO: [HLS 200-489] Unrolling loop 'LineBufferShift' (firmware/nnet_utils/nnet_conv_stream.h:244) in function 'nnet::shift_line_buffer<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 4u>, config6>' completely with a factor of 2.
# INFO: [HLS 200-489] Unrolling loop 'KernelShiftWidth' (firmware/nnet_utils/nnet_conv_stream.h:194) in function 'nnet::shift_line_buffer<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 4u>, config6>' completely with a factor of 2.
# INFO: [HLS 200-489] Unrolling loop 'KernelShiftHeight' (firmware/nnet_utils/nnet_conv_stream.h:197) in function 'nnet::shift_line_buffer<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 4u>, config6>' completely with a factor of 3.
# INFO: [HLS 200-489] Unrolling loop 'KernelShiftChannel' (firmware/nnet_utils/nnet_conv_stream.h:199) in function 'nnet::shift_line_buffer<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 4u>, config6>' completely with a factor of 4.
# INFO: [HLS 200-489] Unrolling loop 'KernelPushHeight' (firmware/nnet_utils/nnet_conv_stream.h:210) in function 'nnet::shift_line_buffer<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 4u>, config6>' completely with a factor of 3.
# INFO: [HLS 200-489] Unrolling loop 'KernelPushChannel' (firmware/nnet_utils/nnet_conv_stream.h:213) in function 'nnet::shift_line_buffer<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 4u>, config6>' completely with a factor of 4.
# INFO: [HLS 200-489] Unrolling loop 'CastLoop' (firmware/nnet_utils/nnet_conv_stream.h:303) in function 'nnet::compute_output_buffer_2d<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 3u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 4u>, config3>' completely with a factor of 4.
# ...
# report_drc completed successfully
# INFO: [runtcl-4] Executing : report_methodology -file design_1_wrapper_methodology_drc_routed.rpt -pb design_1_wrapper_methodology_drc_routed.pb -rpx design_1_wrapper_methodology_drc_routed.rpx
# Command: report_methodology -file design_1_wrapper_methodology_drc_routed.rpt -pb design_1_wrapper_methodology_drc_routed.pb -rpx design_1_wrapper_methodology_drc_routed.rpx
# INFO: [Timing 38-35] Done setting XDC timing constraints.
# INFO: [DRC 23-133] Running Methodology with 8 threads
# INFO: [Coretcl 2-1520] The results of Report Methodology are in file /home/webphy/Desktop/dnn_processor/hls4ml/deploy/qmodel_test/hls4ml_prj/myproject_vivado_accelerator/project_1.runs/impl_1/design_1_wrapper_methodology_drc_routed.rpt.
# report_methodology completed successfully
# INFO: [runtcl-4] Executing : report_power -file design_1_wrapper_power_routed.rpt -pb design_1_wrapper_power_summary_routed.pb -rpx design_1_wrapper_power_routed.rpx
# Command: report_power -file design_1_wrapper_power_routed.rpt -pb design_1_wrapper_power_summary_routed.pb -rpx design_1_wrapper_power_routed.rpx
# INFO: [Timing 38-35] Done setting XDC timing constraints.
# Running Vector-less Activity Propagation...
#
# Finished Running Vector-less Activity Propagation
# WARNING: [Power 33-332] Found switching activity that implies high-fanout reset nets being asserted for excessive periods of time which may result in inaccurate power analysis.
# Resolution: To review and fix problems, please run Power Constraints Advisor in the GUI from Tools > Power Constraints Advisor or run report_power with the -advisory option to generate a text report.
# 124 Infos, 4 Warnings, 0 Critical Warnings and 0 Errors encountered.
# report_power completed successfully
# INFO: [runtcl-4] Executing : report_route_status -file design_1_wrapper_route_status.rpt -pb design_1_wrapper_route_status.pb
# INFO: [runtcl-4] Executing : report_timing_summary -max_paths 10 -file design_1_wrapper_timing_summary_routed.rpt -pb design_1_wrapper_timing_summary_routed.pb -rpx design_1_wrapper_timing_summary_routed.rpx -warn_on_violation
# INFO: [Timing 38-91] UpdateTimingParams: Speed grade: -1, Delay Type: min_max.
# INFO: [Timing 38-191] Multithreading enabled for timing update using a maximum of 8 CPUs
# INFO: [runtcl-4] Executing : report_incremental_reuse -file design_1_wrapper_incremental_reuse_routed.rpt
# INFO: [Vivado_Tcl 4-1062] Incremental flow is disabled. No incremental reuse Info to report.
# INFO: [runtcl-4] Executing : report_clock_utilization -file design_1_wrapper_clock_utilization_routed.rpt
# INFO: [runtcl-4] Executing : report_bus_skew -warn_on_violation -file design_1_wrapper_bus_skew_routed.rpt -pb design_1_wrapper_bus_skew_routed.pb -rpx design_1_wrapper_bus_skew_routed.rpx
# INFO: [Timing 38-91] UpdateTimingParams: Speed grade: -1, Delay Type: min_max.
# INFO: [Timing 38-191] Multithreading enabled for timing update using a maximum of 8 CPUs
# INFO: [Memdata 28-167] Found XPM memory block design_1_i/hier_0/axi_dma_0/U0/I_PRMRY_DATAMOVER/GEN_S2MM_FULL.I_S2MM_FULL_WRAPPER/GEN_ENABLE_INDET_BTT_SF.I_INDET_BTT/I_XD_FIFO/NON_BLK_MEM.I_SYNC_FIFOGEN_FIFO/xpm_fifo_instance.xpm_fifo_sync_inst/xpm_fifo_base_inst/gen_sdpram.xpm_memory_base_inst with a P_MEMORY_PRIMITIVE property set to auto. A value of block is required. You will not be able to use the updatemem program to update the bitstream with new data for the design_1_i/hier_0/axi_dma_0/U0/I_PRMRY_DATAMOVER/GEN_S2MM_FULL.I_S2MM_FULL_WRAPPER/GEN_ENABLE_INDET_BTT_SF.I_INDET_BTT/I_XD_FIFO/NON_BLK_MEM.I_SYNC_FIFOGEN_FIFO/xpm_fifo_instance.xpm_fifo_sync_inst/xpm_fifo_base_inst/gen_sdpram.xpm_memory_base_inst block.
# INFO: [Memdata 28-208] The XPM instance: <design_1_i/hier_0/axi_dma_0/U0/I_PRMRY_DATAMOVER/GEN_S2MM_FULL.I_S2MM_FULL_WRAPPER/GEN_ENABLE_INDET_BTT_SF.I_INDET_BTT/I_DATA_FIFO/BLK_MEM.I_SYNC_FIFOGEN_FIFO/xpm_fifo_instance.xpm_fifo_sync_inst/xpm_fifo_base_inst/gen_sdpram.xpm_memory_base_inst> is part of IP: <design_1_i/hier_0/axi_dma_0>. This XPM instance will be excluded from the .mmi because updatemem is prohibited from making changes to an XPM that is part of an IP.
# INFO: [Memdata 28-208] The XPM instance: <design_1_i/hier_0/axi_dma_0/U0/I_PRMRY_DATAMOVER/GEN_MM2S_FULL.I_MM2S_FULL_WRAPPER/GEN_INCLUDE_MM2S_SF.I_RD_SF/I_DATA_FIFO/BLK_MEM.I_SYNC_FIFOGEN_FIFO/xpm_fifo_instance.xpm_fifo_sync_inst/xpm_fifo_base_inst/gen_sdpram.xpm_memory_base_inst> is part of IP: <design_1_i/hier_0/axi_dma_0>. This XPM instance will be excluded from the .mmi because updatemem is prohibited from making changes to an XPM that is part of an IP.
# Command: write_bitstream -force design_1_wrapper.bit
# Attempting to get a license for feature 'Implementation' and/or device 'xc7z020'
# INFO: [Common 17-349] Got license for feature 'Implementation' and/or device 'xc7z020'
# Running DRC as a precondition to command write_bitstream
# INFO: [IP_Flow 19-1839] IP Catalog is up to date.
# INFO: [DRC 23-27] Running DRC with 8 threads
# WARNING: [DRC DPOP-2] MREG Output pipelining: DSP design_1_i/hier_0/myproject_axi_0/inst/myproject_U0/conv_2d_cl_array_ap_ufixed_3u_array_ap_fixed_8_1_5_3_0_4u_config3_U0/grp_compute_output_buffer_2d_array_array_ap_fixed_8_1_5_3_0_4u_config3_s_fu_193/grp_dense_resource_ap_ufixed_8_0_4_0_0_ap_fixed_8_1_5_3_0_config3_mult_s_fu_211/r_V_3_fu_914_p2 multiplier stage design_1_i/hier_0/myproject_axi_0/inst/myproject_U0/conv_2d_cl_array_ap_ufixed_3u_array_ap_fixed_8_1_5_3_0_4u_config3_U0/grp_compute_output_buffer_2d_array_array_ap_fixed_8_1_5_3_0_4u_config3_s_fu_193/grp_dense_resource_ap_ufixed_8_0_4_0_0_ap_fixed_8_1_5_3_0_config3_mult_s_fu_211/r_V_3_fu_914_p2/P[47:0] is not pipelined (MREG=0). Pipelining the multiplier function will improve performance and will save significant power so it is suggested whenever possible to fully pipeline this function.  If this multiplier was inferred, it is suggested to describe an additional register stage after this function.  If there is no registered adder/accumulator following the multiply function, two pipeline stages are suggested to allow both the MREG and PREG registers to be used.  If the DSP48 was instantiated in the design, it is suggested to set both the MREG and PREG attributes to 1 when performing multiply functions.
# WARNING: [DRC DPOP-2] MREG Output pipelining: DSP design_1_i/hier_0/myproject_axi_0/inst/myproject_U0/conv_2d_cl_array_ap_ufixed_4u_array_ap_fixed_8_1_5_3_0_16u_config6_U0/grp_compute_output_buffer_2d_array_array_ap_fixed_8_1_5_3_0_16u_config6_s_fu_195/grp_dense_resource_ap_ufixed_8_0_4_0_0_ap_fixed_8_1_5_3_0_config6_mult_s_fu_255/r_V_2_fu_2752_p2 multiplier stage design_1_i/hier_0/myproject_axi_0/inst/myproject_U0/conv_2d_cl_array_ap_ufixed_4u_array_ap_fixed_8_1_5_3_0_16u_config6_U0/grp_compute_output_buffer_2d_array_array_ap_fixed_8_1_5_3_0_16u_config6_s_fu_195/grp_dense_resource_ap_ufixed_8_0_4_0_0_ap_fixed_8_1_5_3_0_config6_mult_s_fu_255/r_V_2_fu_2752_p2/P[47:0] is not pipelined (MREG=0). Pipelining the multiplier function will improve performance and will save significant power so it is suggested whenever possible to fully pipeline this function.  If this multiplier was inferred, it is suggested to describe an additional register stage after this function.  If there is no registered adder/accumulator following the multiply function, two pipeline stages are suggested to allow both the MREG and PREG registers to be used.  If the DSP48 was instantiated in the design, it is suggested to set both the MREG and PREG attributes to 1 when performing multiply functions.
# WARNING: [DRC DPOP-2] MREG Output pipelining: DSP design_1_i/hier_0/myproject_axi_0/inst/myproject_U0/pointwise_conv_2d_cl_array_array_ap_fixed_8_1_5_3_0_5u_config19_U0/r_V_1_fu_947_p2 multiplier stage design_1_i/hier_0/myproject_axi_0/inst/myproject_U0/pointwise_conv_2d_cl_array_array_ap_fixed_8_1_5_3_0_5u_config19_U0/r_V_1_fu_947_p2/P[47:0] is not pipelined (MREG=0). Pipelining the multiplier function will improve performance and will save significant power so it is suggested whenever possible to fully pipeline this function.  If this multiplier was inferred, it is suggested to describe an additional register stage after this function.  If there is no registered adder/accumulator following the multiply function, two pipeline stages are suggested to allow both the MREG and PREG registers to be used.  If the DSP48 was instantiated in the design, it is suggested to set both the MREG and PREG attributes to 1 when performing multiply functions.
# WARNING: [DRC RTSTAT-10] No routable loads: 33 net(s) have no routable loads. The problem bus(es) and/or net(s) are design_1_i/axi_mem_intercon/m00_couplers/auto_pc/inst/gen_axi4_axi3.axi3_conv_inst/USE_READ.USE_SPLIT_R.read_addr_inst/USE_R_CHANNEL.cmd_queue/inst/fifo_gen_inst/inst_fifo_gen/gconvfifo.rf/grf.rf/gntv_or_sync_fifo.gl0.rd/gr1.gr1_int.rfwft/aempty_fwft_i, design_1_i/axi_mem_intercon/m00_couplers/auto_pc/inst/gen_axi4_axi3.axi3_conv_inst/USE_WRITE.write_addr_inst/USE_B_CHANNEL.cmd_b_queue/inst/fifo_gen_inst/inst_fifo_gen/gconvfifo.rf/grf.rf/gntv_or_sync_fifo.gl0.rd/gr1.gr1_int.rfwft/aempty_fwft_i, design_1_i/axi_mem_intercon/m00_couplers/auto_pc/inst/gen_axi4_axi3.axi3_conv_inst/USE_WRITE.write_addr_inst/USE_BURSTS.cmd_queue/inst/fifo_gen_inst/inst_fifo_gen/gconvfifo.rf/grf.rf/gntv_or_sync_fifo.gl0.rd/gr1.gr1_int.rfwft/aempty_fwft_i, design_1_i/axi_mem_intercon/m00_couplers/auto_pc/inst/gen_axi4_axi3.axi3_conv_inst/USE_WRITE.write_addr_inst/USE_B_CHANNEL.cmd_b_queue/inst/fifo_gen_inst/inst_fifo_gen/gconvfifo.rf/grf.rf/gntv_or_sync_fifo.gl0.wr/gwss.wsts/ram_afull_fb, design_1_i/axi_mem_intercon/m00_couplers/auto_pc/inst/gen_axi4_axi3.axi3_conv_inst/USE_WRITE.write_addr_inst/USE_BURSTS.cmd_queue/inst/fifo_gen_inst/inst_fifo_gen/gconvfifo.rf/grf.rf/gntv_or_sync_fifo.gl0.wr/gwss.wsts/ram_afull_fb, design_1_i/axi_mem_intercon/m00_couplers/auto_pc/inst/gen_axi4_axi3.axi3_conv_inst/USE_READ.USE_SPLIT_R.read_addr_inst/USE_R_CHANNEL.cmd_queue/inst/fifo_gen_inst/inst_fifo_gen/gconvfifo.rf/grf.rf/gntv_or_sync_fifo.gl0.wr/gwss.wsts/ram_afull_fb, design_1_i/axi_mem_intercon/m00_couplers/auto_pc/inst/gen_axi4_axi3.axi3_conv_inst/USE_WRITE.write_addr_inst/USE_B_CHANNEL.cmd_b_queue/inst/fifo_gen_inst/inst_fifo_gen/gconvfifo.rf/grf.rf/gntv_or_sync_fifo.gl0.wr/gwss.wsts/ram_afull_i, design_1_i/axi_mem_intercon/m00_couplers/auto_pc/inst/gen_axi4_axi3.axi3_conv_inst/USE_READ.USE_SPLIT_R.read_addr_inst/USE_R_CHANNEL.cmd_queue/inst/fifo_gen_inst/inst_fifo_gen/gconvfifo.rf/grf.rf/gntv_or_sync_fifo.gl0.wr/gwss.wsts/ram_afull_i, design_1_i/axi_mem_intercon/m00_couplers/auto_pc/inst/gen_axi4_axi3.axi3_conv_inst/USE_WRITE.write_addr_inst/USE_BURSTS.cmd_queue/inst/fifo_gen_inst/inst_fifo_gen/gconvfifo.rf/grf.rf/gntv_or_sync_fifo.gl0.wr/gwss.wsts/ram_afull_i, design_1_i/axi_mem_intercon/m00_couplers/auto_pc/inst/gen_axi4_axi3.axi3_conv_inst/USE_WRITE.write_addr_inst/USE_B_CHANNEL.cmd_b_queue/inst/fifo_gen_inst/inst_fifo_gen/gconvfifo.rf/grf.rf/gntv_or_sync_fifo.gl0.rd/grss.rsts/ram_empty_i, design_1_i/axi_mem_intercon/m00_couplers/auto_pc/inst/gen_axi4_axi3.axi3_conv_inst/USE_WRITE.write_addr_inst/USE_BURSTS.cmd_queue/inst/fifo_gen_inst/inst_fifo_gen/gconvfifo.rf/grf.rf/gntv_or_sync_fifo.gl0.rd/grss.rsts/ram_empty_i, design_1_i/axi_mem_intercon/m00_couplers/auto_pc/inst/gen_axi4_axi3.axi3_conv_inst/USE_READ.USE_SPLIT_R.read_addr_inst/USE_R_CHANNEL.cmd_queue/inst/fifo_gen_inst/inst_fifo_gen/gconvfifo.rf/grf.rf/gntv_or_sync_fifo.gl0.rd/grss.rsts/ram_empty_i, design_1_i/axi_mem_intercon/m00_couplers/auto_pc/inst/gen_axi4_axi3.axi3_conv_inst/USE_WRITE.write_addr_inst/USE_BURSTS.cmd_queue/inst/fifo_gen_inst/inst_fifo_gen/gconvfifo.rf/grf.rf/rstblk/rd_rst_reg[2:0], design_1_i/axi_mem_intercon/m00_couplers/auto_pc/inst/gen_axi4_axi3.axi3_conv_inst/USE_READ.USE_SPLIT_R.read_addr_inst/USE_R_CHANNEL.cmd_queue/inst/fifo_gen_inst/inst_fifo_gen/gconvfifo.rf/grf.rf/rstblk/rd_rst_reg[2:0], design_1_i/axi_mem_intercon/m00_couplers/auto_pc/inst/gen_axi4_axi3.axi3_conv_inst/USE_WRITE.write_addr_inst/USE_B_CHANNEL.cmd_b_queue/inst/fifo_gen_inst/inst_fifo_gen/gconvfifo.rf/grf.rf/rstblk/rd_rst_reg[2:0]... and (the first 15 of 21 listed).
# INFO: [Vivado 12-3199] DRC finished with 0 Errors, 4 Warnings
# INFO: [Vivado 12-3200] Please refer to the DRC report (report_drc) for more information.
# INFO: [Designutils 20-2272] Running write_bitstream with 8 threads.
# Loading data files...
# Loading site data...
# Loading route data...
# Processing options...
# Creating bitmap...
# Creating bitstream...
# Writing bitstream ./design_1_wrapper.bit...
# INFO: [Vivado 12-1842] Bitgen Completed Successfully.
# INFO: [Project 1-120] WebTalk data collection is mandatory when using a WebPACK part without a full Vivado license. To see the specific WebTalk data collected for your design, open the usage_statistics_webtalk.html or usage_statistics_webtalk.xml file in the implementation directory.
# INFO: [Common 17-83] Releasing license: Implementation
# 146 Infos, 8 Warnings, 0 Critical Warnings and 0 Errors encountered.
# write_bitstream completed successfully
# write_bitstream: Time (s): cpu = 00:00:17 ; elapsed = 00:00:11 . Memory (MB): peak = 3769.105 ; gain = 201.195 ; free physical = 6069 ; free virtual = 35030
# INFO: [Common 17-206] Exiting Vivado at Tue Feb  6 12:00:48 2024...
# [Tue Feb  6 12:00:48 2024] impl_1 finished
# wait_on_run: Time (s): cpu = 00:11:15 ; elapsed = 00:06:12 . Memory (MB): peak = 2433.863 ; gain = 0.000 ; free physical = 7982 ; free virtual = 36943
# # open_run impl_1
# INFO: [Device 21-403] Loading part xc7z020clg400-1
# Netlist sorting complete. Time (s): cpu = 00:00:00.14 ; elapsed = 00:00:00.14 . Memory (MB): peak = 2433.863 ; gain = 0.000 ; free physical = 7781 ; free virtual = 36754
# INFO: [Netlist 29-17] Analyzing 1839 Unisim elements for replacement
# INFO: [Netlist 29-28] Unisim Transformation completed in 0 CPU seconds
# INFO: [Project 1-479] Netlist was created with Vivado 2020.1
# INFO: [Project 1-570] Preparing netlist for logic optimization
# INFO: [Timing 38-478] Restoring timing data from binary archive.
# INFO: [Timing 38-479] Binary timing data restore complete.
# INFO: [Project 1-856] Restoring constraints from binary archive.
# INFO: [Project 1-853] Binary constraint restore complete.
# Reading XDEF placement.
# Reading placer database...
# Reading XDEF routing.
# Read XDEF File: Time (s): cpu = 00:00:01 ; elapsed = 00:00:01 . Memory (MB): peak = 2898.508 ; gain = 38.008 ; free physical = 7156 ; free virtual = 36133
# Restored from archive | CPU: 1.200000 secs | Memory: 43.472008 MB |
# Finished XDEF File Restore: Time (s): cpu = 00:00:01 ; elapsed = 00:00:01 . Memory (MB): peak = 2898.508 ; gain = 38.008 ; free physical = 7156 ; free virtual = 36133
# Netlist sorting complete. Time (s): cpu = 00:00:00 ; elapsed = 00:00:00 . Memory (MB): peak = 2898.508 ; gain = 0.000 ; free physical = 7161 ; free virtual = 36139
# INFO: [Project 1-111] Unisim Transformation Summary:
#   A total of 9 instances were transformed.
#   RAM32M => RAM32M (RAMD32(x6), RAMS32(x2)): 5 instances
#   RAM32X1D => RAM32X1D (RAMD32(x2)): 1 instance
#   SRLC32E => SRL16E: 3 instances
#
# open_run: Time (s): cpu = 00:00:09 ; elapsed = 00:00:11 . Memory (MB): peak = 2898.508 ; gain = 464.645 ; free physical = 7161 ; free virtual = 36139
# # report_utilization -file util.rpt -hierarchical -hierarchical_percentages
# INFO: [Common 17-206] Exiting Vivado at Tue Feb  6 12:01:00 2024...
# Vivado synthesis report not found.
# Cosim report not found.
# {'CSynthesisReport': {'TargetClockPeriod': '5.00',
#   'EstimatedClockPeriod': '5.827',
#   'BestLatency': '3293173',
#   'WorstLatency': '3293580',
#   'IntervalMin': '425986',
#   'IntervalMax': '3293186',
#   'BRAM_18K': '132',
#   'DSP': '0',
#   'FF': '24484',
#   'LUT': '47416',
#   'URAM': '0',
#   'AvailableBRAM_18K': '280',
#   'AvailableDSP': '220',
#   'AvailableFF': '106400',
#   'AvailableLUT': '53200',
#   'AvailableURAM': '0'},
#  'TimingReport': {'WNS': 0.675,
#   'TNS': 0.0,
#   'WHS': 0.028,
#   'THS': 0.0,
#   'WPWS': 3.75,
#   'TPWS': 0.0}}

# %%
hls4ml.report.read_vivado_report(output_dir)
# Out:
# Found 1 solution(s) in deploy/qmodel_test/hls4ml_prj/myproject_prj.
# Reports for solution "solution1":
#
# C simulation report not found.
# SYNTHESIS REPORT:
# ================================================================
# == Vivado HLS Report for 'myproject_axi'
# ================================================================
# * Date:           Tue Feb  6 11:53:59 2024
#
# * Version:        2020.1 (Build 2897737 on Wed May 27 20:21:37 MDT 2020)
# * Project:        myproject_prj
# * Solution:       solution1
# * Product family: zynq
# * Target device:  xc7z020-clg400-1
#
#
# ================================================================
# == Performance Estimates
# ================================================================
# + Timing:
#     * Summary:
#     +--------+---------+----------+------------+
#     |  Clock |  Target | Estimated| Uncertainty|
#     +--------+---------+----------+------------+
#     |ap_clk  | 5.00 ns | 5.827 ns |   0.62 ns  |
#     +--------+---------+----------+------------+
#
# + Latency:
#     * Summary:
#     +---------+---------+-----------+-----------+--------+---------+----------+
#     |  Latency (cycles) |   Latency (absolute)  |     Interval     | Pipeline |
#     |   min   |   max   |    min    |    max    |   min  |   max   |   Type   |
#     +---------+---------+-----------+-----------+--------+---------+----------+
#     |  3293173|  3293580| 19.189 ms | 19.192 ms |  425986|  3293186| dataflow |
#     +---------+---------+-----------+-----------+--------+---------+----------+
#
#     + Detail:
#         * Instance:
#         +------------------------------------+---------------------------------+---------+---------+-----------+-----------+--------+---------+----------+
#         |                                    |                                 |  Latency (cycles) |   Latency (absolute)  |     Interval     | Pipeline |
#         |              Instance              |              Module             |   min   |   max   |    min    |    max    |   min  |   max   |   Type   |
#         +------------------------------------+---------------------------------+---------+---------+-----------+-----------+--------+---------+----------+
#         |myproject_U0                        |myproject                        |  3293172|  3293579| 19.189 ms | 19.192 ms |   81922|  3293186| dataflow |
#         |Loop_2_proc_U0                      |Loop_2_proc                      |       56|       56|  0.326 us |  0.326 us |      56|       56|   none   |
#         |Loop_1_proc305_U0                   |Loop_1_proc305                   |   425985|   425985|  2.482 ms |  2.482 ms |  425985|   425985|   none   |
#         |Block_myproject_axi_exit45_proc_U0  |Block_myproject_axi_exit45_proc  |        0|        0|    0 ns   |    0 ns   |       0|        0|   none   |
#         +------------------------------------+---------------------------------+---------+---------+-----------+-----------+--------+---------+----------+
#
#         * Loop:
#         N/A
#
#
#
# ================================================================
# == Utilization Estimates
# ================================================================
# * Summary:
# +-----------------+---------+-------+--------+-------+-----+
# |       Name      | BRAM_18K| DSP48E|   FF   |  LUT  | URAM|
# +-----------------+---------+-------+--------+-------+-----+
# |DSP              |        -|      -|       -|      -|    -|
# |Expression       |        -|      -|       0|     24|    -|
# |FIFO             |       24|      -|     604|   1956|    -|
# |Instance         |      108|      0|   23875|  45391|    -|
# |Memory           |        -|      -|       -|      -|    -|
# |Multiplexer      |        -|      -|       -|     45|    -|
# |Register         |        -|      -|       5|      -|    -|
# +-----------------+---------+-------+--------+-------+-----+
# |Total            |      132|      0|   24484|  47416|    0|
# +-----------------+---------+-------+--------+-------+-----+
# |Available        |      280|    220|  106400|  53200|    0|
# +-----------------+---------+-------+--------+-------+-----+
# |Utilization (%)  |       47|      0|      23|     89|    0|
# +-----------------+---------+-------+--------+-------+-----+
#
# + Detail:
#     * Instance:
#     +------------------------------------+---------------------------------+---------+-------+-------+-------+-----+
#     |              Instance              |              Module             | BRAM_18K| DSP48E|   FF  |  LUT  | URAM|
#     +------------------------------------+---------------------------------+---------+-------+-------+-------+-----+
#     |Block_myproject_axi_exit45_proc_U0  |Block_myproject_axi_exit45_proc  |        0|      0|     42|    103|    0|
#     |Loop_1_proc305_U0                   |Loop_1_proc305                   |        0|      0|    716|   1282|    0|
#     |Loop_2_proc_U0                      |Loop_2_proc                      |        0|      0|    741|    922|    0|
#     |myproject_U0                        |myproject                        |      108|      0|  22376|  43084|    0|
#     +------------------------------------+---------------------------------+---------+-------+-------+-------+-----+
#     |Total                               |                                 |      108|      0|  23875|  45391|    0|
#     +------------------------------------+---------------------------------+---------+-------+-------+-------+-----+
#
# Co-simulation report not found.

# %% [markdown]
# # FIFO depth optimization

# %%
import hls4ml


config["Flows"] = ["vivado:fifo_depth_optimization"]
hls4ml.model.optimizer.get_optimizer("vivado:fifo_depth_optimization").configure(
    profiling_fifo_depth=100_000
)


hls_model = hls4ml.converters.convert_from_keras_model(
    qkeras_model,
    hls_config=config,
    io_type="io_stream",
    output_dir=f"deploy/qmodel_{trial_id}_fifo_opt/hls4ml_prj",
    part="xc7z020clg400-1",
    backend="Vivado",
)

hls_model.build(reset=False, csim=True, synth=True, cosim=True)
# Out:
# Interpreting Model
# Topology:
# Layer name: input_1, layer type: InputLayer, input shapes: [[None, 128, 128, 3]], output shape: [None, 128, 128, 3]
# Layer name: q_activation, layer type: Activation, input shapes: [[None, 128, 128, 3]], output shape: [None, 128, 128, 3]
# Layer name: q_conv2d, layer type: QConv2D, input shapes: [[None, 128, 128, 3]], output shape: [None, 32, 32, 4]
# Layer name: q_activation_1, layer type: Activation, input shapes: [[None, 32, 32, 4]], output shape: [None, 32, 32, 4]
# Layer name: q_conv2d_1, layer type: QConv2D, input shapes: [[None, 32, 32, 4]], output shape: [None, 15, 15, 16]
# Layer name: q_activation_2, layer type: Activation, input shapes: [[None, 15, 15, 16]], output shape: [None, 15, 15, 16]
# Layer name: q_conv2d_2, layer type: QConv2D, input shapes: [[None, 15, 15, 16]], output shape: [None, 15, 15, 5]
# Layer name: q_activation_3, layer type: Activation, input shapes: [[None, 15, 15, 5]], output shape: [None, 15, 15, 5]
# Layer name: flatten, layer type: Reshape, input shapes: [[None, 15, 15, 5]], output shape: [None, 1125]
# Layer name: q_dense, layer type: QDense, input shapes: [[None, 1125]], output shape: [None, 5]
# Creating HLS model
# WARNING: Strategy for layer input_1 set to "Resource", while pipeline style set to "pipeline".
# WARNING: Strategy for layer q_activation set to "Resource", while pipeline style set to "pipeline".
# WARNING: Strategy for layer q_conv2d set to "Resource", while pipeline style set to "pipeline".
# WARNING: Strategy for layer q_conv2d_linear set to "Resource", while pipeline style set to "pipeline".
# WARNING: Strategy for layer q_activation_1 set to "Resource", while pipeline style set to "pipeline".
# WARNING: Strategy for layer q_conv2d_1 set to "Resource", while pipeline style set to "pipeline".
# WARNING: Strategy for layer q_conv2d_1_linear set to "Resource", while pipeline style set to "pipeline".
# WARNING: Strategy for layer q_activation_2 set to "Resource", while pipeline style set to "pipeline".
# WARNING: Strategy for layer q_conv2d_2 set to "Resource", while pipeline style set to "pipeline".
# WARNING: Strategy for layer q_conv2d_2_linear set to "Resource", while pipeline style set to "pipeline".
# WARNING: Strategy for layer q_activation_3 set to "Resource", while pipeline style set to "pipeline".
# WARNING: Strategy for layer flatten set to "Resource", while pipeline style set to "pipeline".
# WARNING: Strategy for layer q_dense set to "Resource", while pipeline style set to "pipeline".
# WARNING: Strategy for layer q_dense_linear set to "Resource", while pipeline style set to "pipeline".
# WARNING: Changing pipeline style to "dataflow".
# WARNING: Invalid ReuseFactor=9000 in layer "q_conv2d".Using ReuseFactor=192 instead. Valid ReuseFactor(s): 1,2,3,4,6,8,12,16,24,48,96,192.
# WARNING: Invalid ReuseFactor=9000 in layer "q_conv2d_1".Using ReuseFactor=576 instead. Valid ReuseFactor(s): 1,2,3,4,6,9,12,18,36,72,144,288,576.
# WARNING: Invalid ReuseFactor=9000 in layer "q_conv2d_2".Using ReuseFactor=80 instead. Valid ReuseFactor(s): 1,2,4,8,16,80.
# WARNING: Invalid ReuseFactor=9000 in layer "q_dense".Using ReuseFactor=5625 instead. Valid ReuseFactor(s): 1,3,5,9,15,25,45,75,125,225,375,1125,5625.
# WARNING: Config parameter "trace" overwrites an existing attribute in layer "q_conv2d_2" (PointwiseConv2D)
# WARNING: Config parameter "precision" overwrites an existing attribute in layer "q_conv2d_2" (PointwiseConv2D)
# WARNING: Config parameter "strategy" overwrites an existing attribute in layer "q_conv2d_2" (PointwiseConv2D)
# Writing HLS project
# Done
#
# ****** Vivado(TM) HLS - High-Level Synthesis from C, C++ and SystemC v2020.1 (64-bit)
#   **** SW Build 2902540 on Wed May 27 19:54:35 MDT 2020
#   **** IP Build 2902112 on Wed May 27 22:43:36 MDT 2020
#     ** Copyright 1986-2020 Xilinx, Inc. All Rights Reserved.
#
# source /opt/Xilinx/Vivado/2020.1/scripts/vivado_hls/hls.tcl -notrace
# INFO: [HLS 200-10] Running '/opt/Xilinx/Vivado/2020.1/bin/unwrapped/lnx64.o/vivado_hls'
# INFO: [HLS 200-10] For user 'webphy' on host 'wesley-XPS-8950' (Linux_x86_64 version 6.5.0-15-generic) on Tue Feb 06 12:01:04 -03 2024
# INFO: [HLS 200-10] On os Ubuntu 22.04.3 LTS
# INFO: [HLS 200-10] In directory '/home/webphy/Desktop/dnn_processor/hls4ml/deploy/qmodel_handmade_model_fifo_opt/hls4ml_prj'
# Sourcing Tcl script 'build_prj.tcl'
# INFO: [HLS 200-10] Creating and opening project '/home/webphy/Desktop/dnn_processor/hls4ml/deploy/qmodel_handmade_model_fifo_opt/hls4ml_prj/myproject_prj'.
# INFO: [HLS 200-10] Adding design file 'firmware/myproject.cpp' to the project
# INFO: [HLS 200-10] Adding test bench file 'myproject_test.cpp' to the project
# INFO: [HLS 200-10] Adding test bench file 'firmware/weights' to the project
# INFO: [HLS 200-10] Adding test bench file 'tb_data' to the project
# INFO: [HLS 200-10] Creating and opening solution '/home/webphy/Desktop/dnn_processor/hls4ml/deploy/qmodel_handmade_model_fifo_opt/hls4ml_prj/myproject_prj/solution1'.
# INFO: [XFORM 203-101] Allowed max sub elements number after partition is 4096.
# INFO: [XFORM 203-1161] The maximum of name length is set into 80.
# INFO: [HLS 200-10] Setting target device to 'xc7z020-clg400-1'
# INFO: [SYN 201-201] Setting up clock 'default' with a period of 5ns.
# INFO: [SYN 201-201] Setting up clock 'default' with an uncertainty of 0.625ns.
# ***** C SIMULATION *****
# INFO: [SIM 211-2] *************** CSIM start ***************
# INFO: [SIM 211-4] CSIM will launch GCC as the compiler.
#    Compiling ../../../../myproject_test.cpp in debug mode
#    Compiling ../../../../firmware/myproject.cpp in debug mode
#    Generating csim.exe
# INFO: Unable to open input/predictions file, using default input.
# -0.015625 -0.0859375 0.078125 -0.0390625 0.0546875
# INFO: Saved inference results to file: tb_data/csim_results.log
# INFO: [SIM 211-1] CSim done with 0 errors.
# INFO: [SIM 211-3] *************** CSIM finish ***************
# ***** C SIMULATION COMPLETED IN 0h0m3s *****
# ***** C/RTL SYNTHESIS *****
# INFO: [SCHED 204-61] Option 'relax_ii_for_timing' is enabled, will increase II to preserve clock frequency constraints.
# INFO: [HLS 200-10] Analyzing design file 'firmware/myproject.cpp' ...
# WARNING: [HLS 200-40] In file included from firmware/myproject.cpp:1:
# In file included from firmware/myproject.cpp:4:
# In file included from firmware/parameters.h:15:
# In file included from firmware/nnet_utils/nnet_conv2d_stream.h:7:
# firmware/nnet_utils/nnet_conv_stream.h:19:10: warning: comparison of unsigned expression < 0 is always false [-Wtautological-compare]
#  if (idx < K - S) {
#      ~~~ ^ ~~~~~
# firmware/nnet_utils/nnet_conv_stream.h:64:20: note: in instantiation of function template specialization 'nnet::scale_index_K_gte_S<4, 4, 128>' requested here
#             return scale_index_K_gte_S<K, S, W>(idx);
#                    ^
# firmware/nnet_utils/nnet_conv2d_stream.h:15:89: note: in instantiation of member function 'nnet::scale_index_regular<4, 4, 128>::scale_index' requested here
#                                                                   CONFIG_T::in_height>::scale_index(h_idx);
#                                                                                         ^
# firmware/nnet_utils/nnet_conv2d_stream.h:59:13: note: in instantiation of function template specialization 'nnet::compute_scaled_indices_2d<nnet::array<ap_ufixed<8, 0, 4, 0, 0>, 3>, config3>' requested here
#             compute_scaled_indices_2d<data_T, CONFIG_T>(i_ih, i_iw, pixel_idx);
#             ^
# firmware/nnet_utils/nnet_conv2d_stream.h:106:9: note: in instantiation of function template specialization 'nnet::conv_2d_encoded_cl<nnet::array<ap_ufixed<8, 0, 4, 0, 0>, 3>, nnet::array<ap_fixed<8, 1, 5, 3, 0>, 4>, config3>' requested here
#         conv_2d_encoded_cl<data_T, res_T, CONFIG_T>(data, res, weights, biases);
#         ^
# firmware/myproject.cpp:51:2: note: in instantiation of function template specialization 'nnet::conv_2d_cl<nnet::array<ap_ufixed<8, 0, 4, 0, 0>, 3>, nnet::array<ap_fixed<8, 1, 5, 3, 0>, 4>, config3>' requested here
#  nnet::conv_2d_cl<layer2_t, layer3_t, config3>(layer2_out, layer3_out, w3, b3);
#  ^
# In file included from firmware/myproject.cpp:1:
# In file included from firmware/myproject.cpp:4:
# In file included from firmware/parameters.h:15:
# In file included from firmware/nnet_utils/nnet_conv2d_stream.h:7:
# firmware/nnet_utils/nnet_conv_stream.h:40:10: warning: comparison of unsigned expression < 0 is always false [-Wtautological-compare]
#  if (idx < S - K) {
#      ~~~ ^ ~~~~~
# firmware/nnet_utils/nnet_conv_stream.h:66:20: note: in instantiation of function template specialization 'nnet::scale_index_K_lt_S<4, 4, 128>' requested here
#             return scale_index_K_lt_S<K, S, W>(idx);
#                    ^
# firmware/nnet_utils/nnet_conv2d_stream.h:15:89: note: in instantiation of member function 'nnet::scale_index_regular<4, 4, 128>::scale_index' requested here
#                                                                   CONFIG_T::in_height>::scale_index(h_idx);
#                                                                                         ^
# firmware/nnet_utils/nnet_conv2d_stream.h:59:13: note: in instantiation of function template specialization 'nnet::compute_scaled_indices_2d<nnet::array<ap_ufixed<8, 0, 4, 0, 0>, 3>, config3>' requested here
#             compute_scaled_indices_2d<data_T, CONFIG_T>(i_ih, i_iw, pixel_idx);
#             ^
# firmware/nnet_utils/nnet_conv2d_stream.h:106:9: note: in instantiation of function template specialization 'nnet::conv_2d_encoded_cl<nnet::array<ap_ufixed<8, 0, 4, 0, 0>, 3>, nnet::array<ap_fixed<8, 1, 5, 3, 0>, 4>, config3>' requested here
#         conv_2d_encoded_cl<data_T, res_T, CONFIG_T>(data, res, weights, biases);
#         ^
# firmware/myproject.cpp:51:2: note: in instantiation of function template specialization 'nnet::conv_2d_cl<nnet::array<ap_ufixed<8, 0, 4, 0, 0>, 3>, nnet::array<ap_fixed<8, 1, 5, 3, 0>, 4>, config3>' requested here
#  nnet::conv_2d_cl<layer2_t, layer3_t, config3>(layer2_out, layer3_out, w3, b3);
#  ^
# 2 warnings generated.
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/myproject.cpp:51:72
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/myproject.cpp:51:76
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/myproject.cpp:55:74
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/myproject.cpp:55:79
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/myproject.cpp:63:72
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/myproject.cpp:63:76
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/myproject.cpp:67:74
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/myproject.cpp:67:79
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/myproject.cpp:75:85
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/myproject.cpp:75:90
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/myproject.cpp:79:76
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/myproject.cpp:79:81
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/myproject.cpp:88:72
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/myproject.cpp:88:77
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/myproject.cpp:90:78
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/myproject.cpp:90:83
# WARNING: [HLS 200-471] Dataflow form checks found 16 issue(s) in file firmware/myproject.cpp
# INFO: [HLS 200-111] Finished Linking Time (s): cpu = 00:00:15 ; elapsed = 00:00:16 . Memory (MB): peak = 1583.832 ; gain = 1161.754 ; free physical = 8144 ; free virtual = 37398
# INFO: [HLS 200-111] Finished Checking Pragmas Time (s): cpu = 00:00:15 ; elapsed = 00:00:16 . Memory (MB): peak = 1583.832 ; gain = 1161.754 ; free physical = 8144 ; free virtual = 37398
# INFO: [HLS 200-10] Starting code transformations ...
# INFO: [HLS 200-489] Unrolling loop 'MultLoop' (firmware/nnet_utils/nnet_dense_resource.h:136) in function 'void nnet::dense_resource_rf_gt_nin_rem0<ap_fixed<4, 1, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config13>(FORWARD_REFERENCE*, FORWARD_REFERENCE*, FORWARD_REFERENCE::weight_t*, FORWARD_REFERENCE::bias_t*)' completely with a factor of 1.
# INFO: [HLS 200-489] Unrolling loop 'MultLoop' (firmware/nnet_utils/nnet_dense_resource.h:136) in function 'void nnet::dense_resource_rf_gt_nin_rem0<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config19_mult>(FORWARD_REFERENCE*, FORWARD_REFERENCE*, FORWARD_REFERENCE::weight_t*, FORWARD_REFERENCE::bias_t*)' completely with a factor of 1.
# INFO: [HLS 200-489] Unrolling loop 'MultLoop' (firmware/nnet_utils/nnet_dense_resource.h:136) in function 'void nnet::dense_resource_rf_gt_nin_rem0<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config6_mult>(FORWARD_REFERENCE*, FORWARD_REFERENCE*, FORWARD_REFERENCE::weight_t*, FORWARD_REFERENCE::bias_t*)' completely with a factor of 1.
# INFO: [HLS 200-489] Unrolling loop 'MultLoop' (firmware/nnet_utils/nnet_dense_resource.h:136) in function 'void nnet::dense_resource_rf_gt_nin_rem0<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config3_mult>(FORWARD_REFERENCE*, FORWARD_REFERENCE*, FORWARD_REFERENCE::weight_t*, FORWARD_REFERENCE::bias_t*)' completely with a factor of 1.
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 3u>::operator[]' into 'nnet::relu<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 3u>, nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 3u>, relu_config2>' (firmware/nnet_utils/nnet_activation_stream.h:52).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 3u>::operator[]' into 'nnet::relu<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 3u>, nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 3u>, relu_config2>' (firmware/nnet_utils/nnet_activation_stream.h:51).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 3u>::operator[].1' into 'nnet::relu<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 3u>, nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 3u>, relu_config2>' (firmware/nnet_utils/nnet_activation_stream.h:54).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 3u>::operator[].1' into 'nnet::relu<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 3u>, nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 3u>, relu_config2>' (firmware/nnet_utils/nnet_activation_stream.h:52).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 3u>::operator[]' into 'nnet::shift_line_buffer<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 3u>, config3>' (firmware/nnet_utils/nnet_conv_stream.h:237).
# INFO: [XFORM 203-603] Inlining function 'nnet::kernel_shift_2d<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 3u>, config3>' into 'nnet::shift_line_buffer<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 3u>, config3>' (firmware/nnet_utils/nnet_conv_stream.h:252).
# INFO: [XFORM 203-603] Inlining function 'nnet::product::mult<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0> >::product' into 'nnet::dense_resource_rf_gt_nin_rem0<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config3_mult>' (firmware/nnet_utils/nnet_dense_resource.h:139).
# INFO: [XFORM 203-603] Inlining function 'nnet::product::mult<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0> >::product' into 'nnet::dense_resource_rf_gt_nin_rem0<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config6_mult>' (firmware/nnet_utils/nnet_dense_resource.h:139).
# INFO: [XFORM 203-603] Inlining function 'nnet::product::mult<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0> >::product' into 'nnet::dense_resource_rf_gt_nin_rem0<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config19_mult>' (firmware/nnet_utils/nnet_dense_resource.h:139).
# INFO: [XFORM 203-603] Inlining function 'nnet::dense_resource_rf_gt_nin_rem0<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config3_mult>' into 'nnet::dense_resource<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config3_mult>' (firmware/nnet_utils/nnet_dense_resource.h:255).
# INFO: [XFORM 203-603] Inlining function 'nnet::cast<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config3_mult>' into 'nnet::dense_resource<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config3_mult>' (firmware/nnet_utils/nnet_dense_resource.h:158->firmware/nnet_utils/nnet_dense_resource.h:255).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 4u>::operator[]' into 'nnet::compute_output_buffer_2d<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 3u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 4u>, config3>' (firmware/nnet_utils/nnet_conv_stream.h:305).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 4u>::operator[]' into 'nnet::relu<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 4u>, nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 4u>, relu_config5>' (firmware/nnet_utils/nnet_activation_stream.h:52).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 4u>::operator[]' into 'nnet::relu<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 4u>, nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 4u>, relu_config5>' (firmware/nnet_utils/nnet_activation_stream.h:51).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 4u>::operator[]' into 'nnet::normalize<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 4u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 4u>, config15>' (firmware/nnet_utils/nnet_batchnorm_stream.h:42).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 4u>::operator[]' into 'nnet::normalize<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 4u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 4u>, config15>' (firmware/nnet_utils/nnet_batchnorm_stream.h:41).
# INFO: [XFORM 203-603] Inlining function 'nnet::conv_2d_buffer_cl<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 3u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 4u>, config3>' into 'nnet::conv_2d_cl<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 3u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 4u>, config3>' (firmware/nnet_utils/nnet_conv2d_stream.h:103).
# INFO: [XFORM 203-603] Inlining function 'nnet::product::weight_exponential<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, exponent_scale15_t>::product' into 'nnet::normalize<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 4u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 4u>, config15>' (firmware/nnet_utils/nnet_batchnorm_stream.h:42).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 4u>::operator[].1' into 'nnet::relu<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 4u>, nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 4u>, relu_config5>' (firmware/nnet_utils/nnet_activation_stream.h:54).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 4u>::operator[].1' into 'nnet::relu<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 4u>, nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 4u>, relu_config5>' (firmware/nnet_utils/nnet_activation_stream.h:52).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 4u>::operator[]' into 'nnet::shift_line_buffer<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 4u>, config6>' (firmware/nnet_utils/nnet_conv_stream.h:237).
# INFO: [XFORM 203-603] Inlining function 'nnet::kernel_shift_2d<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 4u>, config6>' into 'nnet::shift_line_buffer<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 4u>, config6>' (firmware/nnet_utils/nnet_conv_stream.h:252).
# INFO: [XFORM 203-603] Inlining function 'nnet::dense_resource_rf_gt_nin_rem0<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config6_mult>' into 'nnet::dense_resource<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config6_mult>' (firmware/nnet_utils/nnet_dense_resource.h:255).
# INFO: [XFORM 203-603] Inlining function 'nnet::cast<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config6_mult>' into 'nnet::dense_resource<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config6_mult>' (firmware/nnet_utils/nnet_dense_resource.h:158->firmware/nnet_utils/nnet_dense_resource.h:255).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>::operator[]' into 'nnet::compute_output_buffer_2d<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 4u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config6>' (firmware/nnet_utils/nnet_conv_stream.h:305).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>::operator[]' into 'nnet::relu<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>, relu_config8>' (firmware/nnet_utils/nnet_activation_stream.h:52).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>::operator[]' into 'nnet::relu<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>, relu_config8>' (firmware/nnet_utils/nnet_activation_stream.h:51).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>::operator[]' into 'nnet::normalize<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config16>' (firmware/nnet_utils/nnet_batchnorm_stream.h:42).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>::operator[]' into 'nnet::normalize<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config16>' (firmware/nnet_utils/nnet_batchnorm_stream.h:41).
# INFO: [XFORM 203-603] Inlining function 'nnet::conv_2d_buffer_cl<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 4u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config6>' into 'nnet::conv_2d_cl<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 4u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config6>' (firmware/nnet_utils/nnet_conv2d_stream.h:103).
# INFO: [XFORM 203-603] Inlining function 'nnet::product::weight_exponential<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, exponent_scale16_t>::product' into 'nnet::normalize<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config16>' (firmware/nnet_utils/nnet_batchnorm_stream.h:42).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>::operator[].1' into 'nnet::relu<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>, relu_config8>' (firmware/nnet_utils/nnet_activation_stream.h:54).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>::operator[].1' into 'nnet::relu<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>, relu_config8>' (firmware/nnet_utils/nnet_activation_stream.h:52).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>::operator[]' into 'nnet::pointwise_mult_buffer<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config19>' (firmware/nnet_utils/nnet_sepconv_stream.h:153).
# INFO: [XFORM 203-603] Inlining function 'nnet::dense_resource_rf_gt_nin_rem0<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config19_mult>' into 'nnet::dense_resource<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config19_mult>' (firmware/nnet_utils/nnet_dense_resource.h:255).
# INFO: [XFORM 203-603] Inlining function 'nnet::cast<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config19_mult>' into 'nnet::dense_resource<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config19_mult>' (firmware/nnet_utils/nnet_dense_resource.h:158->firmware/nnet_utils/nnet_dense_resource.h:255).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>::operator[]' into 'nnet::pointwise_mult_buffer<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config19>' (firmware/nnet_utils/nnet_sepconv_stream.h:168).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>::operator[]' into 'nnet::normalize<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config18>' (firmware/nnet_utils/nnet_batchnorm_stream.h:42).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>::operator[]' into 'nnet::normalize<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config18>' (firmware/nnet_utils/nnet_batchnorm_stream.h:41).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>::operator[]' into 'nnet::dense<nnet::array<ap_fixed<4, 1, (ap_q_mode)4, (ap_o_mode)0, 0>, 5u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config13>' (firmware/nnet_utils/nnet_dense_stream.h:60).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>::operator[]' into 'nnet::linear<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, nnet::array<ap_fixed<4, 1, (ap_q_mode)4, (ap_o_mode)0, 0>, 5u>, linear_config11>' (firmware/nnet_utils/nnet_activation_stream.h:29).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>::operator[]' into 'nnet::normalize<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config17>' (firmware/nnet_utils/nnet_batchnorm_stream.h:42).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>::operator[]' into 'nnet::normalize<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config17>' (firmware/nnet_utils/nnet_batchnorm_stream.h:41).
# INFO: [XFORM 203-603] Inlining function 'nnet::dense_resource<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config19_mult>' into 'nnet::pointwise_mult_buffer<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config19>' (firmware/nnet_utils/nnet_sepconv_stream.h:161).
# INFO: [XFORM 203-603] Inlining function 'nnet::pointwise_mult_buffer<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config19>' into 'nnet::pointwise_conv_2d_cl<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config19>' (firmware/nnet_utils/nnet_sepconv2d_stream.h:113).
# INFO: [XFORM 203-603] Inlining function 'nnet::product::weight_exponential<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, exponent_scale17_t>::product' into 'nnet::normalize<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config17>' (firmware/nnet_utils/nnet_batchnorm_stream.h:42).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<4, 1, (ap_q_mode)4, (ap_o_mode)0, 0>, 5u>::operator[]' into 'nnet::dense<nnet::array<ap_fixed<4, 1, (ap_q_mode)4, (ap_o_mode)0, 0>, 5u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config13>' (firmware/nnet_utils/nnet_dense_stream.h:44).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<4, 1, (ap_q_mode)4, (ap_o_mode)0, 0>, 5u>::operator[]' into 'nnet::linear<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, nnet::array<ap_fixed<4, 1, (ap_q_mode)4, (ap_o_mode)0, 0>, 5u>, linear_config11>' (firmware/nnet_utils/nnet_activation_stream.h:29).
# INFO: [XFORM 203-603] Inlining function 'nnet::product::mult<ap_fixed<4, 1, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0> >::product' into 'nnet::dense_resource_rf_gt_nin_rem0<ap_fixed<4, 1, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config13>' (firmware/nnet_utils/nnet_dense_resource.h:139).
# INFO: [XFORM 203-603] Inlining function 'nnet::dense_resource_rf_gt_nin_rem0<ap_fixed<4, 1, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config13>' into 'nnet::dense_resource<ap_fixed<4, 1, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config13>' (firmware/nnet_utils/nnet_dense_resource.h:255).
# INFO: [XFORM 203-603] Inlining function 'nnet::cast<ap_fixed<4, 1, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config13>' into 'nnet::dense_resource<ap_fixed<4, 1, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config13>' (firmware/nnet_utils/nnet_dense_resource.h:158->firmware/nnet_utils/nnet_dense_resource.h:255).
# INFO: [XFORM 203-603] Inlining function 'nnet::dense_resource<ap_fixed<4, 1, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config13>' into 'nnet::dense_wrapper<ap_fixed<4, 1, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config13>' (firmware/nnet_utils/nnet_dense_stream.h:21).
# INFO: [XFORM 203-603] Inlining function 'nnet::product::weight_exponential<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, exponent_scale18_t>::product' into 'nnet::normalize<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config18>' (firmware/nnet_utils/nnet_batchnorm_stream.h:42).
# INFO: [HLS 200-111] Finished Standard Transforms Time (s): cpu = 00:00:18 ; elapsed = 00:00:19 . Memory (MB): peak = 1583.832 ; gain = 1161.754 ; free physical = 7876 ; free virtual = 37142
# INFO: [HLS 200-10] Checking synthesizability ...
# INFO: [HLS 200-111] Finished Checking Synthesizability Time (s): cpu = 00:00:18 ; elapsed = 00:00:19 . Memory (MB): peak = 1583.832 ; gain = 1161.754 ; free physical = 7871 ; free virtual = 37140
# INFO: [XFORM 203-1101] Packing variable 'out_data.data.V' (firmware/nnet_utils/nnet_activation_stream.h:45) into a 32-bit variable.
# INFO: [XFORM 203-1101] Packing variable 'out_data.data.V' (firmware/nnet_utils/nnet_activation_stream.h:45) into a 24-bit variable.
# INFO: [XFORM 203-1101] Packing variable 'out_data.data.V' (firmware/nnet_utils/nnet_activation_stream.h:45) into a 128-bit variable.
# INFO: [XFORM 203-1101] Packing variable 'res_pack.data.V' (firmware/nnet_utils/nnet_sepconv_stream.h:147) into a 40-bit variable.
# INFO: [XFORM 203-1101] Packing variable 'out_data.data.V' (firmware/nnet_utils/nnet_batchnorm_stream.h:29) into a 40-bit variable.
# INFO: [XFORM 203-1101] Packing variable 'out_data.data.V' (firmware/nnet_utils/nnet_batchnorm_stream.h:29) into a 40-bit variable.
# INFO: [XFORM 203-1101] Packing variable 'out_data.data.V' (firmware/nnet_utils/nnet_batchnorm_stream.h:29) into a 32-bit variable.
# INFO: [XFORM 203-1101] Packing variable 'out_data.data.V' (firmware/nnet_utils/nnet_batchnorm_stream.h:29) into a 128-bit variable.
# INFO: [XFORM 203-1101] Packing variable 'out_data.data.V' (firmware/nnet_utils/nnet_activation_stream.h:23) into a 20-bit variable.
# INFO: [XFORM 203-1101] Packing variable 'res_pack.data.V' (firmware/nnet_utils/nnet_dense_stream.h:55) into a 40-bit variable.
# INFO: [XFORM 203-1101] Packing variable 'res_pack.data.V' (firmware/nnet_utils/nnet_conv_stream.h:282) into a 128-bit variable.
# INFO: [XFORM 203-1101] Packing variable 'res_pack.data.V' (firmware/nnet_utils/nnet_conv_stream.h:282) into a 32-bit variable.
# INFO: [XFORM 203-502] Unrolling all sub-loops inside loop 'ReLUActLoop' (firmware/nnet_utils/nnet_activation_stream.h:41) in function 'nnet::relu<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 4u>, nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 4u>, relu_config5>' for pipelining.
# INFO: [XFORM 203-502] Unrolling all sub-loops inside loop 'ReLUActLoop' (firmware/nnet_utils/nnet_activation_stream.h:41) in function 'nnet::relu<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 3u>, nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 3u>, relu_config2>' for pipelining.
# INFO: [XFORM 203-502] Unrolling all sub-loops inside loop 'ReLUActLoop' (firmware/nnet_utils/nnet_activation_stream.h:41) in function 'nnet::relu<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>, relu_config8>' for pipelining.
# INFO: [XFORM 203-502] Unrolling all loops for pipelining in function 'nnet::normalize<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config18>' (firmware/nnet_utils/nnet_batchnorm_stream.h:18:43).
# INFO: [XFORM 203-502] Unrolling all sub-loops inside loop 'BatchNormLoop' (firmware/nnet_utils/nnet_batchnorm_stream.h:25) in function 'nnet::normalize<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config17>' for pipelining.
# INFO: [XFORM 203-502] Unrolling all sub-loops inside loop 'BatchNormLoop' (firmware/nnet_utils/nnet_batchnorm_stream.h:25) in function 'nnet::normalize<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 4u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 4u>, config15>' for pipelining.
# INFO: [XFORM 203-502] Unrolling all sub-loops inside loop 'BatchNormLoop' (firmware/nnet_utils/nnet_batchnorm_stream.h:25) in function 'nnet::normalize<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config16>' for pipelining.
# INFO: [XFORM 203-502] Unrolling all sub-loops inside loop 'LinearActLoop' (firmware/nnet_utils/nnet_activation_stream.h:19) in function 'nnet::linear<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, nnet::array<ap_fixed<4, 1, (ap_q_mode)4, (ap_o_mode)0, 0>, 5u>, linear_config11>' for pipelining.
# INFO: [XFORM 203-502] Unrolling all sub-loops inside loop 'DataPrepare' (firmware/nnet_utils/nnet_dense_stream.h:36) in function 'nnet::dense<nnet::array<ap_fixed<4, 1, (ap_q_mode)4, (ap_o_mode)0, 0>, 5u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config13>' for pipelining.
# INFO: [XFORM 203-502] Unrolling all loops for pipelining in function 'nnet::shift_line_buffer<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 4u>, config6>' (firmware/nnet_utils/nnet_conv_stream.h:194:62).
# WARNING: [XFORM 203-505] Ignored pipeline directive for loop 'KernelShiftWidth' (firmware/nnet_utils/nnet_conv_stream.h:194) because its parent loop or function is pipelined.
# INFO: [XFORM 203-502] Unrolling all loops for pipelining in function 'nnet::shift_line_buffer<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 3u>, config3>' (firmware/nnet_utils/nnet_conv_stream.h:194:62).
# WARNING: [XFORM 203-505] Ignored pipeline directive for loop 'KernelShiftWidth' (firmware/nnet_utils/nnet_conv_stream.h:194) because its parent loop or function is pipelined.
# INFO: [HLS 200-489] Unrolling loop 'ReLUPackLoop' (firmware/nnet_utils/nnet_activation_stream.h:49) in function 'nnet::relu<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 4u>, nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 4u>, relu_config5>' completely with a factor of 4.
# INFO: [HLS 200-489] Unrolling loop 'ReLUPackLoop' (firmware/nnet_utils/nnet_activation_stream.h:49) in function 'nnet::relu<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 3u>, nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 3u>, relu_config2>' completely with a factor of 3.
# INFO: [HLS 200-489] Unrolling loop 'ReLUPackLoop' (firmware/nnet_utils/nnet_activation_stream.h:49) in function 'nnet::relu<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>, relu_config8>' completely with a factor of 16.
# INFO: [HLS 200-489] Unrolling loop 'InitData' (firmware/nnet_utils/nnet_sepconv_stream.h:151) in function 'nnet::pointwise_conv_2d_cl<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config19>' completely with a factor of 16.
# INFO: [HLS 200-489] Unrolling loop 'InitAccum' (firmware/nnet_utils/nnet_dense_resource.h:108) in function 'nnet::pointwise_conv_2d_cl<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config19>' completely with a factor of 5.
# INFO: [HLS 200-489] Unrolling loop 'Result' (firmware/nnet_utils/nnet_dense_resource.h:156) in function 'nnet::pointwise_conv_2d_cl<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config19>' completely with a factor of 5.
# INFO: [HLS 200-489] Unrolling loop 'CastLoop' (firmware/nnet_utils/nnet_sepconv_stream.h:166) in function 'nnet::pointwise_conv_2d_cl<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config19>' completely with a factor of 5.
# INFO: [HLS 200-489] Unrolling loop 'BatchNormpack' (firmware/nnet_utils/nnet_batchnorm_stream.h:33) in function 'nnet::normalize<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config18>' completely with a factor of 5.
# INFO: [HLS 200-489] Unrolling loop 'BatchNormpack' (firmware/nnet_utils/nnet_batchnorm_stream.h:33) in function 'nnet::normalize<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config17>' completely with a factor of 5.
# INFO: [HLS 200-489] Unrolling loop 'BatchNormpack' (firmware/nnet_utils/nnet_batchnorm_stream.h:33) in function 'nnet::normalize<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 4u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 4u>, config15>' completely with a factor of 4.
# INFO: [HLS 200-489] Unrolling loop 'BatchNormpack' (firmware/nnet_utils/nnet_batchnorm_stream.h:33) in function 'nnet::normalize<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config16>' completely with a factor of 16.
# INFO: [HLS 200-489] Unrolling loop 'LinearPackLoop' (firmware/nnet_utils/nnet_activation_stream.h:27) in function 'nnet::linear<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, nnet::array<ap_fixed<4, 1, (ap_q_mode)4, (ap_o_mode)0, 0>, 5u>, linear_config11>' completely with a factor of 5.
# INFO: [HLS 200-489] Unrolling loop 'DataPack' (firmware/nnet_utils/nnet_dense_stream.h:42) in function 'nnet::dense<nnet::array<ap_fixed<4, 1, (ap_q_mode)4, (ap_o_mode)0, 0>, 5u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config13>' completely with a factor of 5.
# INFO: [HLS 200-489] Unrolling loop 'ResPack' (firmware/nnet_utils/nnet_dense_stream.h:58) in function 'nnet::dense<nnet::array<ap_fixed<4, 1, (ap_q_mode)4, (ap_o_mode)0, 0>, 5u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config13>' completely with a factor of 5.
# INFO: [HLS 200-489] Unrolling loop 'InitAccum' (firmware/nnet_utils/nnet_dense_resource.h:108) in function 'nnet::dense_wrapper<ap_fixed<4, 1, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config13>' completely with a factor of 5.
# INFO: [HLS 200-489] Unrolling loop 'Result' (firmware/nnet_utils/nnet_dense_resource.h:156) in function 'nnet::dense_wrapper<ap_fixed<4, 1, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config13>' completely with a factor of 5.
# INFO: [HLS 200-489] Unrolling loop 'CastLoop' (firmware/nnet_utils/nnet_conv_stream.h:303) in function 'nnet::compute_output_buffer_2d<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 4u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config6>' completely with a factor of 16.
# INFO: [HLS 200-489] Unrolling loop 'InitAccum' (firmware/nnet_utils/nnet_dense_resource.h:108) in function 'nnet::dense_resource<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config6_mult>' completely with a factor of 16.
# INFO: [HLS 200-489] Unrolling loop 'Result' (firmware/nnet_utils/nnet_dense_resource.h:156) in function 'nnet::dense_resource<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config6_mult>' completely with a factor of 16.
# INFO: [HLS 200-489] Unrolling loop 'UpdateBuffer' (firmware/nnet_utils/nnet_conv_stream.h:233) in function 'nnet::shift_line_buffer<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 4u>, config6>' completely with a factor of 4.
# INFO: [HLS 200-489] Unrolling loop 'LineBufferDataIn' (firmware/nnet_utils/nnet_conv_stream.h:241) in function 'nnet::shift_line_buffer<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 4u>, config6>' completely with a factor of 4.
# INFO: [HLS 200-489] Unrolling loop 'LineBufferShift' (firmware/nnet_utils/nnet_conv_stream.h:244) in function 'nnet::shift_line_buffer<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 4u>, config6>' completely with a factor of 2.
# INFO: [HLS 200-489] Unrolling loop 'KernelShiftWidth' (firmware/nnet_utils/nnet_conv_stream.h:194) in function 'nnet::shift_line_buffer<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 4u>, config6>' completely with a factor of 2.
# INFO: [HLS 200-489] Unrolling loop 'KernelShiftHeight' (firmware/nnet_utils/nnet_conv_stream.h:197) in function 'nnet::shift_line_buffer<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 4u>, config6>' completely with a factor of 3.
# INFO: [HLS 200-489] Unrolling loop 'KernelShiftChannel' (firmware/nnet_utils/nnet_conv_stream.h:199) in function 'nnet::shift_line_buffer<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 4u>, config6>' completely with a factor of 4.
# INFO: [HLS 200-489] Unrolling loop 'KernelPushHeight' (firmware/nnet_utils/nnet_conv_stream.h:210) in function 'nnet::shift_line_buffer<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 4u>, config6>' completely with a factor of 3.
# INFO: [HLS 200-489] Unrolling loop 'KernelPushChannel' (firmware/nnet_utils/nnet_conv_stream.h:213) in function 'nnet::shift_line_buffer<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 4u>, config6>' completely with a factor of 4.
# INFO: [HLS 200-489] Unrolling loop 'CastLoop' (firmware/nnet_utils/nnet_conv_stream.h:303) in function 'nnet::compute_output_buffer_2d<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 3u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 4u>, config3>' completely with a factor of 4.
# INFO: [HLS 200-489] Unrolling loop 'InitAccum' (firmware/nnet_utils/nnet_dense_resource.h:108) in function 'nnet::dense_resource<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config3_mult>' completely with a factor of 4.
# INFO: [HLS 200-489] Unrolling loop 'Result' (firmware/nnet_utils/nnet_dense_resource.h:156) in function 'nnet::dense_resource<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config3_mult>' completely with a factor of 4.
# INFO: [HLS 200-489] Unrolling loop 'UpdateBuffer' (firmware/nnet_utils/nnet_conv_stream.h:233) in function 'nnet::shift_line_buffer<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 3u>, config3>' completely with a factor of 3.
# INFO: [HLS 200-489] Unrolling loop 'LineBufferDataIn' (firmware/nnet_utils/nnet_conv_stream.h:241) in function 'nnet::shift_line_buffer<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 3u>, config3>' completely with a factor of 3.
# INFO: [HLS 200-489] Unrolling loop 'LineBufferShift' (firmware/nnet_utils/nnet_conv_stream.h:244) in function 'nnet::shift_line_buffer<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 3u>, config3>' completely with a factor of 3.
# INFO: [HLS 200-489] Unrolling loop 'KernelShiftWidth' (firmware/nnet_utils/nnet_conv_stream.h:194) in function 'nnet::shift_line_buffer<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 3u>, config3>' completely with a factor of 3.
# INFO: [HLS 200-489] Unrolling loop 'KernelShiftHeight' (firmware/nnet_utils/nnet_conv_stream.h:197) in function 'nnet::shift_line_buffer<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 3u>, config3>' completely with a factor of 4.
# ...
# Compiling module xil_defaultlib.fifo_w4_d2_A_shiftReg
# Compiling module xil_defaultlib.fifo_w4_d2_A
# Compiling module xil_defaultlib.start_for_conv_2d_cl_array_ap_uf...
# Compiling module xil_defaultlib.start_for_conv_2d_cl_array_ap_uf...
# Compiling module xil_defaultlib.start_for_normalize_array_ap_fix...
# Compiling module xil_defaultlib.start_for_normalize_array_ap_fix...
# Compiling module xil_defaultlib.start_for_relu_array_ap_fixed_4u...
# Compiling module xil_defaultlib.start_for_relu_array_ap_fixed_4u...
# Compiling module xil_defaultlib.start_for_conv_2d_cl_array_ap_uf...
# Compiling module xil_defaultlib.start_for_conv_2d_cl_array_ap_uf...
# Compiling module xil_defaultlib.start_for_normalize_array_ap_fix...
# Compiling module xil_defaultlib.start_for_normalize_array_ap_fix...
# Compiling module xil_defaultlib.start_for_relu_array_ap_fixed_16...
# Compiling module xil_defaultlib.start_for_relu_array_ap_fixed_16...
# Compiling module xil_defaultlib.start_for_pointwise_conv_2d_cl_a...
# Compiling module xil_defaultlib.start_for_pointwise_conv_2d_cl_a...
# Compiling module xil_defaultlib.start_for_normalize_array_ap_fix...
# Compiling module xil_defaultlib.start_for_normalize_array_ap_fix...
# Compiling module xil_defaultlib.start_for_linear_array_ap_fixed_...
# Compiling module xil_defaultlib.start_for_linear_array_ap_fixed_...
# Compiling module xil_defaultlib.start_for_dense_array_ap_fixed_5...
# Compiling module xil_defaultlib.start_for_dense_array_ap_fixed_5...
# Compiling module xil_defaultlib.start_for_normalize_array_ap_fix...
# Compiling module xil_defaultlib.start_for_normalize_array_ap_fix...
# Compiling module xil_defaultlib.myproject
# Compiling module xil_defaultlib.fifo(DEPTH=16384)
# Compiling module xil_defaultlib.AESL_axi_s_input_1_V_data_0_V
# Compiling module xil_defaultlib.AESL_axi_s_input_1_V_data_1_V
# Compiling module xil_defaultlib.AESL_axi_s_input_1_V_data_2_V
# Compiling module xil_defaultlib.fifo(DEPTH=1)
# Compiling module xil_defaultlib.AESL_axi_s_layer18_out_V_data_0_...
# Compiling module xil_defaultlib.AESL_axi_s_layer18_out_V_data_1_...
# Compiling module xil_defaultlib.AESL_axi_s_layer18_out_V_data_2_...
# Compiling module xil_defaultlib.AESL_axi_s_layer18_out_V_data_3_...
# Compiling module xil_defaultlib.AESL_axi_s_layer18_out_V_data_4_...
# Compiling module xil_defaultlib.AESL_deadlock_detect_unit(PROC_N...
# Compiling module xil_defaultlib.AESL_deadlock_detect_unit(PROC_N...
# Compiling module xil_defaultlib.AESL_deadlock_detect_unit(PROC_N...
# Compiling module xil_defaultlib.AESL_deadlock_detect_unit(PROC_N...
# Compiling module xil_defaultlib.AESL_deadlock_detect_unit(PROC_N...
# Compiling module xil_defaultlib.AESL_deadlock_detect_unit(PROC_N...
# Compiling module xil_defaultlib.AESL_deadlock_detect_unit(PROC_N...
# Compiling module xil_defaultlib.AESL_deadlock_detect_unit(PROC_N...
# Compiling module xil_defaultlib.AESL_deadlock_detect_unit(PROC_N...
# Compiling module xil_defaultlib.AESL_deadlock_detect_unit(PROC_N...
# Compiling module xil_defaultlib.AESL_deadlock_detect_unit(PROC_N...
# Compiling module xil_defaultlib.AESL_deadlock_detect_unit(PROC_N...
# Compiling module xil_defaultlib.AESL_deadlock_report_unit(PROC_N...
# Compiling module xil_defaultlib.AESL_deadlock_detector_1
# Compiling module xil_defaultlib.apatb_myproject_top
# Compiling module work.glbl
# Built simulation snapshot myproject
#
# ****** Webtalk v2020.1 (64-bit)
#   **** SW Build 2902540 on Wed May 27 19:54:35 MDT 2020
#   **** IP Build 2902112 on Wed May 27 22:43:36 MDT 2020
#     ** Copyright 1986-2020 Xilinx, Inc. All Rights Reserved.
#
# source /home/webphy/Desktop/dnn_processor/hls4ml/deploy/qmodel_handmade_model_fifo_opt/hls4ml_prj/myproject_prj/solution1/sim/verilog/xsim.dir/myproject/webtalk/xsim_webtalk.tcl -notrace
# INFO: [Common 17-206] Exiting Webtalk at Tue Feb  6 12:05:30 2024...
#
# ****** xsim v2020.1 (64-bit)
#   **** SW Build 2902540 on Wed May 27 19:54:35 MDT 2020
#   **** IP Build 2902112 on Wed May 27 22:43:36 MDT 2020
#     ** Copyright 1986-2020 Xilinx, Inc. All Rights Reserved.
#
# source xsim.dir/myproject/xsim_script.tcl
# # xsim {myproject} -autoloadwcfg -tclbatch {myproject.tcl}
# Vivado Simulator 2020.1
# Time resolution is 1 ps
# source myproject.tcl
# ## set designtopgroup [add_wave_group "Design Top Signals"]
# ## set coutputgroup [add_wave_group "C Outputs" -into $designtopgroup]
# ## set layer18_out_group [add_wave_group layer18_out(axis) -into $coutputgroup]
# ## add_wave /apatb_myproject_top/AESL_inst_myproject/layer18_out_V_data_4_V_TREADY -into $layer18_out_group -color #ffff00 -radix hex
# ## add_wave /apatb_myproject_top/AESL_inst_myproject/layer18_out_V_data_4_V_TVALID -into $layer18_out_group -color #ffff00 -radix hex
# ## add_wave /apatb_myproject_top/AESL_inst_myproject/layer18_out_V_data_3_V_TREADY -into $layer18_out_group -color #ffff00 -radix hex
# ## add_wave /apatb_myproject_top/AESL_inst_myproject/layer18_out_V_data_3_V_TVALID -into $layer18_out_group -color #ffff00 -radix hex
# ## add_wave /apatb_myproject_top/AESL_inst_myproject/layer18_out_V_data_2_V_TREADY -into $layer18_out_group -color #ffff00 -radix hex
# ## add_wave /apatb_myproject_top/AESL_inst_myproject/layer18_out_V_data_2_V_TVALID -into $layer18_out_group -color #ffff00 -radix hex
# ## add_wave /apatb_myproject_top/AESL_inst_myproject/layer18_out_V_data_1_V_TREADY -into $layer18_out_group -color #ffff00 -radix hex
# ## add_wave /apatb_myproject_top/AESL_inst_myproject/layer18_out_V_data_1_V_TVALID -into $layer18_out_group -color #ffff00 -radix hex
# ## add_wave /apatb_myproject_top/AESL_inst_myproject/layer18_out_V_data_0_V_TREADY -into $layer18_out_group -color #ffff00 -radix hex
# ## add_wave /apatb_myproject_top/AESL_inst_myproject/layer18_out_V_data_0_V_TVALID -into $layer18_out_group -color #ffff00 -radix hex
# ## add_wave /apatb_myproject_top/AESL_inst_myproject/layer18_out_V_data_4_V_TDATA -into $layer18_out_group -radix hex
# ## add_wave /apatb_myproject_top/AESL_inst_myproject/layer18_out_V_data_3_V_TDATA -into $layer18_out_group -radix hex
# ## add_wave /apatb_myproject_top/AESL_inst_myproject/layer18_out_V_data_2_V_TDATA -into $layer18_out_group -radix hex
# ## add_wave /apatb_myproject_top/AESL_inst_myproject/layer18_out_V_data_1_V_TDATA -into $layer18_out_group -radix hex
# ## add_wave /apatb_myproject_top/AESL_inst_myproject/layer18_out_V_data_0_V_TDATA -into $layer18_out_group -radix hex
# ## set cinputgroup [add_wave_group "C Inputs" -into $designtopgroup]
# ## set input_1_group [add_wave_group input_1(axis) -into $cinputgroup]
# ## add_wave /apatb_myproject_top/AESL_inst_myproject/input_1_V_data_2_V_TREADY -into $input_1_group -color #ffff00 -radix hex
# ## add_wave /apatb_myproject_top/AESL_inst_myproject/input_1_V_data_2_V_TVALID -into $input_1_group -color #ffff00 -radix hex
# ## add_wave /apatb_myproject_top/AESL_inst_myproject/input_1_V_data_1_V_TREADY -into $input_1_group -color #ffff00 -radix hex
# ## add_wave /apatb_myproject_top/AESL_inst_myproject/input_1_V_data_1_V_TVALID -into $input_1_group -color #ffff00 -radix hex
# ## add_wave /apatb_myproject_top/AESL_inst_myproject/input_1_V_data_0_V_TREADY -into $input_1_group -color #ffff00 -radix hex
# ## add_wave /apatb_myproject_top/AESL_inst_myproject/input_1_V_data_0_V_TVALID -into $input_1_group -color #ffff00 -radix hex
# ## add_wave /apatb_myproject_top/AESL_inst_myproject/input_1_V_data_2_V_TDATA -into $input_1_group -radix hex
# ## add_wave /apatb_myproject_top/AESL_inst_myproject/input_1_V_data_1_V_TDATA -into $input_1_group -radix hex
# ## add_wave /apatb_myproject_top/AESL_inst_myproject/input_1_V_data_0_V_TDATA -into $input_1_group -radix hex
# ## set blocksiggroup [add_wave_group "Block-level IO Handshake" -into $designtopgroup]
# ## add_wave /apatb_myproject_top/AESL_inst_myproject/ap_start -into $blocksiggroup
# ## add_wave /apatb_myproject_top/AESL_inst_myproject/ap_done -into $blocksiggroup
# ## add_wave /apatb_myproject_top/AESL_inst_myproject/ap_ready -into $blocksiggroup
# ## add_wave /apatb_myproject_top/AESL_inst_myproject/ap_idle -into $blocksiggroup
# ## set resetgroup [add_wave_group "Reset" -into $designtopgroup]
# ## add_wave /apatb_myproject_top/AESL_inst_myproject/ap_rst_n -into $resetgroup
# ## set clockgroup [add_wave_group "Clock" -into $designtopgroup]
# ## add_wave /apatb_myproject_top/AESL_inst_myproject/ap_clk -into $clockgroup
# ## set testbenchgroup [add_wave_group "Test Bench Signals"]
# ## set tbinternalsiggroup [add_wave_group "Internal Signals" -into $testbenchgroup]
# ## set tb_simstatus_group [add_wave_group "Simulation Status" -into $tbinternalsiggroup]
# ## set tb_portdepth_group [add_wave_group "Port Depth" -into $tbinternalsiggroup]
# ## add_wave /apatb_myproject_top/AUTOTB_TRANSACTION_NUM -into $tb_simstatus_group -radix hex
# ## add_wave /apatb_myproject_top/ready_cnt -into $tb_simstatus_group -radix hex
# ## add_wave /apatb_myproject_top/done_cnt -into $tb_simstatus_group -radix hex
# ## add_wave /apatb_myproject_top/LENGTH_input_1_V_data_0_V -into $tb_portdepth_group -radix hex
# ## add_wave /apatb_myproject_top/LENGTH_input_1_V_data_1_V -into $tb_portdepth_group -radix hex
# ## add_wave /apatb_myproject_top/LENGTH_input_1_V_data_2_V -into $tb_portdepth_group -radix hex
# ## add_wave /apatb_myproject_top/LENGTH_layer18_out_V_data_0_V -into $tb_portdepth_group -radix hex
# ## add_wave /apatb_myproject_top/LENGTH_layer18_out_V_data_1_V -into $tb_portdepth_group -radix hex
# ## add_wave /apatb_myproject_top/LENGTH_layer18_out_V_data_2_V -into $tb_portdepth_group -radix hex
# ## add_wave /apatb_myproject_top/LENGTH_layer18_out_V_data_3_V -into $tb_portdepth_group -radix hex
# ## add_wave /apatb_myproject_top/LENGTH_layer18_out_V_data_4_V -into $tb_portdepth_group -radix hex
# ## set tbcoutputgroup [add_wave_group "C Outputs" -into $testbenchgroup]
# ## set tb_layer18_out_group [add_wave_group layer18_out(axis) -into $tbcoutputgroup]
# ## add_wave /apatb_myproject_top/layer18_out_V_data_4_V_TREADY -into $tb_layer18_out_group -color #ffff00 -radix hex
# ## add_wave /apatb_myproject_top/layer18_out_V_data_4_V_TVALID -into $tb_layer18_out_group -color #ffff00 -radix hex
# ## add_wave /apatb_myproject_top/layer18_out_V_data_3_V_TREADY -into $tb_layer18_out_group -color #ffff00 -radix hex
# ## add_wave /apatb_myproject_top/layer18_out_V_data_3_V_TVALID -into $tb_layer18_out_group -color #ffff00 -radix hex
# ## add_wave /apatb_myproject_top/layer18_out_V_data_2_V_TREADY -into $tb_layer18_out_group -color #ffff00 -radix hex
# ## add_wave /apatb_myproject_top/layer18_out_V_data_2_V_TVALID -into $tb_layer18_out_group -color #ffff00 -radix hex
# ## add_wave /apatb_myproject_top/layer18_out_V_data_1_V_TREADY -into $tb_layer18_out_group -color #ffff00 -radix hex
# ## add_wave /apatb_myproject_top/layer18_out_V_data_1_V_TVALID -into $tb_layer18_out_group -color #ffff00 -radix hex
# ## add_wave /apatb_myproject_top/layer18_out_V_data_0_V_TREADY -into $tb_layer18_out_group -color #ffff00 -radix hex
# ## add_wave /apatb_myproject_top/layer18_out_V_data_0_V_TVALID -into $tb_layer18_out_group -color #ffff00 -radix hex
# ## add_wave /apatb_myproject_top/layer18_out_V_data_4_V_TDATA -into $tb_layer18_out_group -radix hex
# ## add_wave /apatb_myproject_top/layer18_out_V_data_3_V_TDATA -into $tb_layer18_out_group -radix hex
# ## add_wave /apatb_myproject_top/layer18_out_V_data_2_V_TDATA -into $tb_layer18_out_group -radix hex
# ## add_wave /apatb_myproject_top/layer18_out_V_data_1_V_TDATA -into $tb_layer18_out_group -radix hex
# ## add_wave /apatb_myproject_top/layer18_out_V_data_0_V_TDATA -into $tb_layer18_out_group -radix hex
# ## set tbcinputgroup [add_wave_group "C Inputs" -into $testbenchgroup]
# ## set tb_input_1_group [add_wave_group input_1(axis) -into $tbcinputgroup]
# ## add_wave /apatb_myproject_top/input_1_V_data_2_V_TREADY -into $tb_input_1_group -color #ffff00 -radix hex
# ## add_wave /apatb_myproject_top/input_1_V_data_2_V_TVALID -into $tb_input_1_group -color #ffff00 -radix hex
# ## add_wave /apatb_myproject_top/input_1_V_data_1_V_TREADY -into $tb_input_1_group -color #ffff00 -radix hex
# ## add_wave /apatb_myproject_top/input_1_V_data_1_V_TVALID -into $tb_input_1_group -color #ffff00 -radix hex
# ## add_wave /apatb_myproject_top/input_1_V_data_0_V_TREADY -into $tb_input_1_group -color #ffff00 -radix hex
# ## add_wave /apatb_myproject_top/input_1_V_data_0_V_TVALID -into $tb_input_1_group -color #ffff00 -radix hex
# ## add_wave /apatb_myproject_top/input_1_V_data_2_V_TDATA -into $tb_input_1_group -radix hex
# ## add_wave /apatb_myproject_top/input_1_V_data_1_V_TDATA -into $tb_input_1_group -radix hex
# ## add_wave /apatb_myproject_top/input_1_V_data_0_V_TDATA -into $tb_input_1_group -radix hex
# ## save_wave_config myproject.wcfg
# ## run all
# ////////////////////////////////////////////////////////////////////////////////////
# // Inter-Transaction Progress: Completed Transaction / Total Transaction
# // Intra-Transaction Progress: Measured Latency / Latency Estimation * 100%
# //
# // RTL Simulation : "Inter-Transaction Progress" ["Intra-Transaction Progress"] @ "Simulation Time"
# ////////////////////////////////////////////////////////////////////////////////////
# // RTL Simulation : 0 / 1 [0.00%] @ "113000"
# // RTL Simulation : 1 / 1 [100.00%] @ "1412158000"
# ////////////////////////////////////////////////////////////////////////////////////
# $finish called at time : 1412177500 ps : File "/home/webphy/Desktop/dnn_processor/hls4ml/deploy/qmodel_handmade_model_fifo_opt/hls4ml_prj/myproject_prj/solution1/sim/verilog/myproject.autotb.v" Line 527
# run: Time (s): cpu = 00:00:00.43 ; elapsed = 00:00:32 . Memory (MB): peak = 2065.594 ; gain = 0.000 ; free physical = 6716 ; free virtual = 36454
# ## quit
# INFO: [Common 17-206] Exiting xsim at Tue Feb  6 12:06:07 2024...
# INFO: [COSIM 212-316] Starting C post checking ...
# INFO: Unable to open input/predictions file, using default input.
# -0.015625 -0.0859375 0.078125 -0.0390625 0.0546875
# INFO: Saved inference results to file: tb_data/rtl_cosim_results.log
# INFO:
# Report time       : ter 06 fev 2024 12:05:21 -03.
# Solution          : solution1.
# Simulation tool   : xsim.
#
# +----------+----------+-----------------------------------------------+-----------------------------------------------+
# |          |          |                    Latency                    |                    Interval                   |
# +   RTL    +  Status  +-----------------------------------------------+-----------------------------------------------+
# |          |          |      min      |      avg      |      max      |      min      |      avg      |      max      |
# +----------+----------+-----------------------------------------------+-----------------------------------------------+
# |      VHDL|        NA|             NA|             NA|             NA|             NA|             NA|             NA|
# |   Verilog|      Pass|             NA|             NA|             NA|             NA|             NA|             NA|
# +----------+----------+-----------------------------------------------+-----------------------------------------------+
#
# ***** C/RTL SIMULATION COMPLETED IN 0h0m58s *****
# INFO: [HLS 200-112] Total elapsed time: 141.26 seconds; peak allocated memory: 806.223 MB.
# INFO: [Common 17-206] Exiting vivado_hls at Tue Feb  6 12:06:08 2024...
# Vivado synthesis report not found.
# Implementation report not found.
# Timing report not found.
# {'CSimResults': [['-0.015625',
#    '-0.0859375',
#    '0.078125',
#    '-0.0390625',
#    '0.0546875']],
#  'CosimResults': [['-0.015625',
#    '-0.0859375',
#    '0.078125',
#    '-0.0390625',
#    '0.0546875']],
#  'CSynthesisReport': {'TargetClockPeriod': '5.00',
#   'EstimatedClockPeriod': '5.827',
#   'BestLatency': '3293171',
#   'WorstLatency': '3293578',
#   'IntervalMin': '81922',
#   'IntervalMax': '3293186',
#   'BRAM_18K': '57',
#   'DSP': '0',
#   'FF': '20398',
#   'LUT': '41675',
#   'URAM': '0',
#   'AvailableBRAM_18K': '280',
#   'AvailableDSP': '220',
#   'AvailableFF': '106400',
#   'AvailableLUT': '53200',
#   'AvailableURAM': '0'},
#  'CosimReport': {'RTL': 'Verilog',
#   'Status': 'Pass',
#   'LatencyMin': 282407,
#   'LatencyMax': 282407,
#   'IntervalMin': 0,
#   'IntervalMax': 0,
#   'LatencyAvg': 282407.0,
#   'IntervalAvg': 0.0}}

# %%
hls4ml.report.read_vivado_report(f"deploy/qmodel_{trial_id}_fifo_opt/hls4ml_prj")
# Out:
# Found 1 solution(s) in deploy/qmodel_handmade_model_fifo_opt/hls4ml_prj/myproject_prj.
# Reports for solution "solution1":
#
# C SIMULATION RESULT:
# INFO: [SIM 2] *************** CSIM start ***************
# INFO: [SIM 4] CSIM will launch GCC as the compiler.
#    Compiling ../../../../myproject_test.cpp in debug mode
#    Compiling ../../../../firmware/myproject.cpp in debug mode
#    Generating csim.exe
# INFO: Unable to open input/predictions file, using default input.
# -0.015625 -0.0859375 0.078125 -0.0390625 0.0546875
# INFO: Saved inference results to file: tb_data/csim_results.log
# INFO: [SIM 1] CSim done with 0 errors.
# INFO: [SIM 3] *************** CSIM finish ***************
#
# SYNTHESIS REPORT:
# ================================================================
# == Vivado HLS Report for 'myproject'
# ================================================================
# * Date:           Tue Feb  6 12:05:05 2024
#
# * Version:        2020.1 (Build 2897737 on Wed May 27 20:21:37 MDT 2020)
# * Project:        myproject_prj
# * Solution:       solution1
# * Product family: zynq
# * Target device:  xc7z020-clg400-1
#
#
# ================================================================
# == Performance Estimates
# ================================================================
# + Timing:
#     * Summary:
#     +--------+---------+----------+------------+
#     |  Clock |  Target | Estimated| Uncertainty|
#     +--------+---------+----------+------------+
#     |ap_clk  | 5.00 ns | 5.827 ns |   0.62 ns  |
#     +--------+---------+----------+------------+
#
# + Latency:
#     * Summary:
#     +---------+---------+-----------+-----------+-------+---------+----------+
#     |  Latency (cycles) |   Latency (absolute)  |     Interval    | Pipeline |
#     |   min   |   max   |    min    |    max    |  min  |   max   |   Type   |
#     +---------+---------+-----------+-----------+-------+---------+----------+
#     |  3293171|  3293578| 19.189 ms | 19.192 ms |  81922|  3293186| dataflow |
#     +---------+---------+-----------+-----------+-------+---------+----------+
#
#     + Detail:
#         * Instance:
#         +-------------------------------------------------------------------------+------------------------------------------------------------------------+---------+---------+-----------+-----------+-------+---------+----------+
#         |                                                                         |                                                                        |  Latency (cycles) |   Latency (absolute)  |     Interval    | Pipeline |
#         |                                 Instance                                |                                 Module                                 |   min   |   max   |    min    |    max    |  min  |   max   |   Type   |
#         +-------------------------------------------------------------------------+------------------------------------------------------------------------+---------+---------+-----------+-----------+-------+---------+----------+
#         |dense_array_ap_fixed_5u_array_ap_fixed_8_1_5_3_0_5u_config13_U0          |dense_array_ap_fixed_5u_array_ap_fixed_8_1_5_3_0_5u_config13_s          |     5857|     5858| 34.129 us | 34.135 us |   5857|     5858|   none   |
#         |conv_2d_cl_array_ap_ufixed_4u_array_ap_fixed_8_1_5_3_0_16u_config6_U0    |conv_2d_cl_array_ap_ufixed_4u_array_ap_fixed_8_1_5_3_0_16u_config6_s    |     5121|   599041| 29.840 us |  3.491 ms |   5121|   599041|   none   |
#         |conv_2d_cl_array_ap_ufixed_3u_array_ap_fixed_8_1_5_3_0_4u_config3_U0     |conv_2d_cl_array_ap_ufixed_3u_array_ap_fixed_8_1_5_3_0_4u_config3_s     |    81921|  3293185|  0.477 ms | 19.189 ms |  81921|  3293185|   none   |
#         |pointwise_conv_2d_cl_array_array_ap_fixed_8_1_5_3_0_5u_config19_U0       |pointwise_conv_2d_cl_array_array_ap_fixed_8_1_5_3_0_5u_config19_s       |    19350|    19350|  0.113 ms |  0.113 ms |  19350|    19350|   none   |
#         |relu_array_ap_fixed_16u_array_ap_ufixed_8_0_4_0_0_16u_relu_config8_U0    |relu_array_ap_fixed_16u_array_ap_ufixed_8_0_4_0_0_16u_relu_config8_s    |      228|      228|  1.329 us |  1.329 us |    228|      228|   none   |
#         |normalize_array_ap_fixed_16u_array_ap_fixed_8_1_5_3_0_16u_config16_U0    |normalize_array_ap_fixed_16u_array_ap_fixed_8_1_5_3_0_16u_config16_s    |      451|      451|  2.628 us |  2.628 us |    451|      451|   none   |
#         |linear_array_ap_fixed_5u_array_ap_fixed_4_1_4_0_0_5u_linear_config11_U0  |linear_array_ap_fixed_5u_array_ap_fixed_4_1_4_0_0_5u_linear_config11_s  |      229|      229|  1.334 us |  1.334 us |    229|      229|   none   |
#         |relu_array_ap_fixed_4u_array_ap_ufixed_8_0_4_0_0_4u_relu_config5_U0      |relu_array_ap_fixed_4u_array_ap_ufixed_8_0_4_0_0_4u_relu_config5_s      |     1027|     1027|  5.984 us |  5.984 us |   1027|     1027|   none   |
#         |normalize_array_ap_fixed_5u_array_ap_fixed_8_1_5_3_0_5u_config18_U0      |normalize_array_ap_fixed_5u_array_ap_fixed_8_1_5_3_0_5u_config18_s      |        1|        1|  5.827 ns |  5.827 ns |      2|        2| function |
#         |normalize_array_ap_fixed_5u_array_ap_fixed_8_1_5_3_0_5u_config17_U0      |normalize_array_ap_fixed_5u_array_ap_fixed_8_1_5_3_0_5u_config17_s      |      451|      451|  2.628 us |  2.628 us |    451|      451|   none   |
#         |relu_array_ap_fixed_3u_array_ap_ufixed_8_0_4_0_0_3u_relu_config2_U0      |relu_array_ap_fixed_3u_array_ap_ufixed_8_0_4_0_0_3u_relu_config2_s      |    16386|    16386| 95.481 us | 95.481 us |  16386|    16386|   none   |
#         |normalize_array_ap_fixed_4u_array_ap_fixed_8_1_5_3_0_4u_config15_U0      |normalize_array_ap_fixed_4u_array_ap_fixed_8_1_5_3_0_4u_config15_s      |     2049|     2049| 11.940 us | 11.940 us |   2049|     2049|   none   |
#         +-------------------------------------------------------------------------+------------------------------------------------------------------------+---------+---------+-----------+-----------+-------+---------+----------+
#
#         * Loop:
#         N/A
#
#
#
# ================================================================
# == Utilization Estimates
# ================================================================
# * Summary:
# +-----------------+---------+-------+--------+-------+-----+
# |       Name      | BRAM_18K| DSP48E|   FF   |  LUT  | URAM|
# +-----------------+---------+-------+--------+-------+-----+
# |DSP              |        -|      -|       -|      -|    -|
# |Expression       |        -|      -|       0|      2|    -|
# |FIFO             |       48|      -|    1346|   4732|    -|
# |Instance         |        9|      0|   19052|  36941|    -|
# |Memory           |        -|      -|       -|      -|    -|
# |Multiplexer      |        -|      -|       -|      -|    -|
# |Register         |        -|      -|       -|      -|    -|
# +-----------------+---------+-------+--------+-------+-----+
# |Total            |       57|      0|   20398|  41675|    0|
# +-----------------+---------+-------+--------+-------+-----+
# |Available        |      280|    220|  106400|  53200|    0|
# +-----------------+---------+-------+--------+-------+-----+
# |Utilization (%)  |       20|      0|      19|     78|    0|
# +-----------------+---------+-------+--------+-------+-----+
#
# + Detail:
#     * Instance:
#     +-------------------------------------------------------------------------+------------------------------------------------------------------------+---------+-------+-------+-------+-----+
#     |                                 Instance                                |                                 Module                                 | BRAM_18K| DSP48E|   FF  |  LUT  | URAM|
#     +-------------------------------------------------------------------------+------------------------------------------------------------------------+---------+-------+-------+-------+-----+
#     |conv_2d_cl_array_ap_ufixed_3u_array_ap_fixed_8_1_5_3_0_4u_config3_U0     |conv_2d_cl_array_ap_ufixed_3u_array_ap_fixed_8_1_5_3_0_4u_config3_s     |        1|      0|   2076|   2617|    0|
#     |conv_2d_cl_array_ap_ufixed_4u_array_ap_fixed_8_1_5_3_0_16u_config6_U0    |conv_2d_cl_array_ap_ufixed_4u_array_ap_fixed_8_1_5_3_0_16u_config6_s    |        2|      0|   1871|   2745|    0|
#     |dense_array_ap_fixed_5u_array_ap_fixed_8_1_5_3_0_5u_config13_U0          |dense_array_ap_fixed_5u_array_ap_fixed_8_1_5_3_0_5u_config13_s          |        6|      0|  13915|  27965|    0|
#     |linear_array_ap_fixed_5u_array_ap_fixed_4_1_4_0_0_5u_linear_config11_U0  |linear_array_ap_fixed_5u_array_ap_fixed_4_1_4_0_0_5u_linear_config11_s  |        0|      0|    147|    400|    0|
#     |normalize_array_ap_fixed_16u_array_ap_fixed_8_1_5_3_0_16u_config16_U0    |normalize_array_ap_fixed_16u_array_ap_fixed_8_1_5_3_0_16u_config16_s    |        0|      0|    147|    552|    0|
#     |normalize_array_ap_fixed_4u_array_ap_fixed_8_1_5_3_0_4u_config15_U0      |normalize_array_ap_fixed_4u_array_ap_fixed_8_1_5_3_0_4u_config15_s      |        0|      0|     55|    206|    0|
#     |normalize_array_ap_fixed_5u_array_ap_fixed_8_1_5_3_0_5u_config17_U0      |normalize_array_ap_fixed_5u_array_ap_fixed_8_1_5_3_0_5u_config17_s      |        0|      0|     61|    237|    0|
#     |normalize_array_ap_fixed_5u_array_ap_fixed_8_1_5_3_0_5u_config18_U0      |normalize_array_ap_fixed_5u_array_ap_fixed_8_1_5_3_0_5u_config18_s      |        0|      0|      3|    185|    0|
#     |pointwise_conv_2d_cl_array_array_ap_fixed_8_1_5_3_0_5u_config19_U0       |pointwise_conv_2d_cl_array_array_ap_fixed_8_1_5_3_0_5u_config19_s       |        0|      0|    514|    854|    0|
#     |relu_array_ap_fixed_16u_array_ap_ufixed_8_0_4_0_0_16u_relu_config8_U0    |relu_array_ap_fixed_16u_array_ap_ufixed_8_0_4_0_0_16u_relu_config8_s    |        0|      0|    162|    700|    0|
#     |relu_array_ap_fixed_3u_array_ap_ufixed_8_0_4_0_0_3u_relu_config2_U0      |relu_array_ap_fixed_3u_array_ap_ufixed_8_0_4_0_0_3u_relu_config2_s      |        0|      0|     44|    224|    0|
#     |relu_array_ap_fixed_4u_array_ap_ufixed_8_0_4_0_0_4u_relu_config5_U0      |relu_array_ap_fixed_4u_array_ap_ufixed_8_0_4_0_0_4u_relu_config5_s      |        0|      0|     57|    256|    0|
#     +-------------------------------------------------------------------------+------------------------------------------------------------------------+---------+-------+-------+-------+-----+
#     |Total                                                                    |                                                                        |        9|      0|  19052|  36941|    0|
#     +-------------------------------------------------------------------------+------------------------------------------------------------------------+---------+-------+-------+-------+-----+
#
# CO-SIMULATION RESULT:
# Report time       : ter 06 fev 2024 12:05:21 -03.
# Solution          : solution1.
# Simulation tool   : xsim.
#
# +----------+----------+-----------------------------------------------+-----------------------------------------------+
# |          |          |                    Latency                    |                    Interval                   |
# +   RTL    +  Status  +-----------------------------------------------+-----------------------------------------------+
# |          |          |      min      |      avg      |      max      |      min      |      avg      |      max      |
# +----------+----------+-----------------------------------------------+-----------------------------------------------+
# |      VHDL|        NA|             NA|             NA|             NA|             NA|             NA|             NA|
# |   Verilog|      Pass|             NA|             NA|             NA|             NA|             NA|             NA|
# +----------+----------+-----------------------------------------------+-----------------------------------------------+

# %% [markdown]
# # FIFO depth optimization for PYNQ

# %%
hls_model = hls4ml.converters.convert_from_keras_model(
    qkeras_model,
    hls_config=config,
    output_dir=f"deploy/qmodel_{trial_id}_fifo_opt_pynq/hls4ml_prj",
    part="xc7z020clg400-1",
    io_type="io_stream",
    backend='VivadoAccelerator',
    board='pynq-z2'
)
# Out:
# Interpreting Model
# Topology:
# Layer name: input_1, layer type: InputLayer, input shapes: [[None, 128, 128, 3]], output shape: [None, 128, 128, 3]
# Layer name: q_activation, layer type: Activation, input shapes: [[None, 128, 128, 3]], output shape: [None, 128, 128, 3]
# Layer name: q_conv2d, layer type: QConv2D, input shapes: [[None, 128, 128, 3]], output shape: [None, 32, 32, 4]
# Layer name: q_activation_1, layer type: Activation, input shapes: [[None, 32, 32, 4]], output shape: [None, 32, 32, 4]
# Layer name: q_conv2d_1, layer type: QConv2D, input shapes: [[None, 32, 32, 4]], output shape: [None, 15, 15, 16]
# Layer name: q_activation_2, layer type: Activation, input shapes: [[None, 15, 15, 16]], output shape: [None, 15, 15, 16]
# Layer name: q_conv2d_2, layer type: QConv2D, input shapes: [[None, 15, 15, 16]], output shape: [None, 15, 15, 5]
# Layer name: q_activation_3, layer type: Activation, input shapes: [[None, 15, 15, 5]], output shape: [None, 15, 15, 5]
# Layer name: flatten, layer type: Reshape, input shapes: [[None, 15, 15, 5]], output shape: [None, 1125]
# Layer name: q_dense, layer type: QDense, input shapes: [[None, 1125]], output shape: [None, 5]
# Creating HLS model
# WARNING: Strategy for layer input_1 set to "Resource", while pipeline style set to "pipeline".
# WARNING: Strategy for layer q_activation set to "Resource", while pipeline style set to "pipeline".
# WARNING: Strategy for layer q_conv2d set to "Resource", while pipeline style set to "pipeline".
# WARNING: Strategy for layer q_conv2d_linear set to "Resource", while pipeline style set to "pipeline".
# WARNING: Strategy for layer q_activation_1 set to "Resource", while pipeline style set to "pipeline".
# WARNING: Strategy for layer q_conv2d_1 set to "Resource", while pipeline style set to "pipeline".
# WARNING: Strategy for layer q_conv2d_1_linear set to "Resource", while pipeline style set to "pipeline".
# WARNING: Strategy for layer q_activation_2 set to "Resource", while pipeline style set to "pipeline".
# WARNING: Strategy for layer q_conv2d_2 set to "Resource", while pipeline style set to "pipeline".
# WARNING: Strategy for layer q_conv2d_2_linear set to "Resource", while pipeline style set to "pipeline".
# WARNING: Strategy for layer q_activation_3 set to "Resource", while pipeline style set to "pipeline".
# WARNING: Strategy for layer flatten set to "Resource", while pipeline style set to "pipeline".
# WARNING: Strategy for layer q_dense set to "Resource", while pipeline style set to "pipeline".
# WARNING: Strategy for layer q_dense_linear set to "Resource", while pipeline style set to "pipeline".
# WARNING: Changing pipeline style to "dataflow".
# WARNING: Invalid ReuseFactor=9000 in layer "q_conv2d".Using ReuseFactor=192 instead. Valid ReuseFactor(s): 1,2,3,4,6,8,12,16,24,48,96,192.
# WARNING: Invalid ReuseFactor=9000 in layer "q_conv2d_1".Using ReuseFactor=576 instead. Valid ReuseFactor(s): 1,2,3,4,6,9,12,18,36,72,144,288,576.
# WARNING: Invalid ReuseFactor=9000 in layer "q_conv2d_2".Using ReuseFactor=80 instead. Valid ReuseFactor(s): 1,2,4,8,16,80.
# WARNING: Invalid ReuseFactor=9000 in layer "q_dense".Using ReuseFactor=5625 instead. Valid ReuseFactor(s): 1,3,5,9,15,25,45,75,125,225,375,1125,5625.
# WARNING: Config parameter "trace" overwrites an existing attribute in layer "q_conv2d_2" (PointwiseConv2D)
# WARNING: Config parameter "precision" overwrites an existing attribute in layer "q_conv2d_2" (PointwiseConv2D)
# WARNING: Config parameter "strategy" overwrites an existing attribute in layer "q_conv2d_2" (PointwiseConv2D)
# Writing HLS project
# Done
#
# ****** Vivado(TM) HLS - High-Level Synthesis from C, C++ and SystemC v2020.1 (64-bit)
#   **** SW Build 2902540 on Wed May 27 19:54:35 MDT 2020
#   **** IP Build 2902112 on Wed May 27 22:43:36 MDT 2020
#     ** Copyright 1986-2020 Xilinx, Inc. All Rights Reserved.
#
# source /opt/Xilinx/Vivado/2020.1/scripts/vivado_hls/hls.tcl -notrace
# INFO: [HLS 200-10] Running '/opt/Xilinx/Vivado/2020.1/bin/unwrapped/lnx64.o/vivado_hls'
# INFO: [HLS 200-10] For user 'webphy' on host 'wesley-XPS-8950' (Linux_x86_64 version 6.5.0-15-generic) on Tue Feb 06 12:06:09 -03 2024
# INFO: [HLS 200-10] On os Ubuntu 22.04.3 LTS
# INFO: [HLS 200-10] In directory '/home/webphy/Desktop/dnn_processor/hls4ml/deploy/qmodel_handmade_model_fifo_opt_pynq/hls4ml_prj'
# Sourcing Tcl script 'build_prj.tcl'
# INFO: [HLS 200-10] Creating and opening project '/home/webphy/Desktop/dnn_processor/hls4ml/deploy/qmodel_handmade_model_fifo_opt_pynq/hls4ml_prj/myproject_prj'.
# INFO: [HLS 200-10] Adding design file 'firmware/myproject_axi.cpp' to the project
# INFO: [HLS 200-10] Adding design file 'firmware/myproject.cpp' to the project
# INFO: [HLS 200-10] Adding test bench file 'myproject_test.cpp' to the project
# INFO: [HLS 200-10] Adding test bench file 'firmware/weights' to the project
# INFO: [HLS 200-10] Adding test bench file 'tb_data' to the project
# INFO: [HLS 200-10] Creating and opening solution '/home/webphy/Desktop/dnn_processor/hls4ml/deploy/qmodel_handmade_model_fifo_opt_pynq/hls4ml_prj/myproject_prj/solution1'.
# INFO: [XFORM 203-101] Allowed max sub elements number after partition is 4096.
# INFO: [XFORM 203-1161] The maximum of name length is set into 80.
# INFO: [HLS 200-10] Setting target device to 'xc7z020-clg400-1'
# INFO: [SYN 201-201] Setting up clock 'default' with a period of 5ns.
# INFO: [SYN 201-201] Setting up clock 'default' with an uncertainty of 0.625ns.
# ***** C SIMULATION *****
# INFO: [SIM 211-2] *************** CSIM start ***************
# INFO: [SIM 211-4] CSIM will launch GCC as the compiler.
#    Compiling ../../../../myproject_test.cpp in debug mode
#    Compiling ../../../../firmware/myproject.cpp in debug mode
#    Compiling ../../../../firmware/myproject_axi.cpp in debug mode
#    Generating csim.exe
# INFO: Unable to open input/predictions file, using default input.
# { data: -0.015625, last: 0 }
#  { data: -0.0859375, last: 0 }
#  { data: 0.078125, last: 0 }
#  { data: -0.0390625, last: 0 }
#  { data: 0.0546875, last: 1 }
#
# INFO: Saved inference results to file: tb_data/csim_results.log
# INFO: [SIM 211-1] CSim done with 0 errors.
# INFO: [SIM 211-3] *************** CSIM finish ***************
# ***** C SIMULATION COMPLETED IN 0h0m3s *****
# ***** C/RTL SYNTHESIS *****
# INFO: [SCHED 204-61] Option 'relax_ii_for_timing' is enabled, will increase II to preserve clock frequency constraints.
# INFO: [HLS 200-10] Analyzing design file 'firmware/myproject.cpp' ...
# WARNING: [HLS 200-40] In file included from firmware/myproject.cpp:1:
# In file included from firmware/myproject.cpp:4:
# In file included from firmware/parameters.h:15:
# In file included from firmware/nnet_utils/nnet_conv2d_stream.h:7:
# firmware/nnet_utils/nnet_conv_stream.h:19:10: warning: comparison of unsigned expression < 0 is always false [-Wtautological-compare]
#  if (idx < K - S) {
#      ~~~ ^ ~~~~~
# firmware/nnet_utils/nnet_conv_stream.h:64:20: note: in instantiation of function template specialization 'nnet::scale_index_K_gte_S<4, 4, 128>' requested here
#             return scale_index_K_gte_S<K, S, W>(idx);
#                    ^
# firmware/nnet_utils/nnet_conv2d_stream.h:15:89: note: in instantiation of member function 'nnet::scale_index_regular<4, 4, 128>::scale_index' requested here
#                                                                   CONFIG_T::in_height>::scale_index(h_idx);
#                                                                                         ^
# firmware/nnet_utils/nnet_conv2d_stream.h:59:13: note: in instantiation of function template specialization 'nnet::compute_scaled_indices_2d<nnet::array<ap_ufixed<8, 0, 4, 0, 0>, 3>, config3>' requested here
#             compute_scaled_indices_2d<data_T, CONFIG_T>(i_ih, i_iw, pixel_idx);
#             ^
# firmware/nnet_utils/nnet_conv2d_stream.h:106:9: note: in instantiation of function template specialization 'nnet::conv_2d_encoded_cl<nnet::array<ap_ufixed<8, 0, 4, 0, 0>, 3>, nnet::array<ap_fixed<8, 1, 5, 3, 0>, 4>, config3>' requested here
#         conv_2d_encoded_cl<data_T, res_T, CONFIG_T>(data, res, weights, biases);
#         ^
# firmware/myproject.cpp:51:2: note: in instantiation of function template specialization 'nnet::conv_2d_cl<nnet::array<ap_ufixed<8, 0, 4, 0, 0>, 3>, nnet::array<ap_fixed<8, 1, 5, 3, 0>, 4>, config3>' requested here
#  nnet::conv_2d_cl<layer2_t, layer3_t, config3>(layer2_out, layer3_out, w3, b3);
#  ^
# In file included from firmware/myproject.cpp:1:
# In file included from firmware/myproject.cpp:4:
# In file included from firmware/parameters.h:15:
# In file included from firmware/nnet_utils/nnet_conv2d_stream.h:7:
# firmware/nnet_utils/nnet_conv_stream.h:40:10: warning: comparison of unsigned expression < 0 is always false [-Wtautological-compare]
#  if (idx < S - K) {
#      ~~~ ^ ~~~~~
# firmware/nnet_utils/nnet_conv_stream.h:66:20: note: in instantiation of function template specialization 'nnet::scale_index_K_lt_S<4, 4, 128>' requested here
#             return scale_index_K_lt_S<K, S, W>(idx);
#                    ^
# firmware/nnet_utils/nnet_conv2d_stream.h:15:89: note: in instantiation of member function 'nnet::scale_index_regular<4, 4, 128>::scale_index' requested here
#                                                                   CONFIG_T::in_height>::scale_index(h_idx);
#                                                                                         ^
# firmware/nnet_utils/nnet_conv2d_stream.h:59:13: note: in instantiation of function template specialization 'nnet::compute_scaled_indices_2d<nnet::array<ap_ufixed<8, 0, 4, 0, 0>, 3>, config3>' requested here
#             compute_scaled_indices_2d<data_T, CONFIG_T>(i_ih, i_iw, pixel_idx);
#             ^
# firmware/nnet_utils/nnet_conv2d_stream.h:106:9: note: in instantiation of function template specialization 'nnet::conv_2d_encoded_cl<nnet::array<ap_ufixed<8, 0, 4, 0, 0>, 3>, nnet::array<ap_fixed<8, 1, 5, 3, 0>, 4>, config3>' requested here
#         conv_2d_encoded_cl<data_T, res_T, CONFIG_T>(data, res, weights, biases);
#         ^
# firmware/myproject.cpp:51:2: note: in instantiation of function template specialization 'nnet::conv_2d_cl<nnet::array<ap_ufixed<8, 0, 4, 0, 0>, 3>, nnet::array<ap_fixed<8, 1, 5, 3, 0>, 4>, config3>' requested here
#  nnet::conv_2d_cl<layer2_t, layer3_t, config3>(layer2_out, layer3_out, w3, b3);
#  ^
# 2 warnings generated.
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/myproject.cpp:51:72
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/myproject.cpp:51:76
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/myproject.cpp:55:74
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/myproject.cpp:55:79
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/myproject.cpp:63:72
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/myproject.cpp:63:76
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/myproject.cpp:67:74
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/myproject.cpp:67:79
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/myproject.cpp:75:85
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/myproject.cpp:75:90
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/myproject.cpp:79:76
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/myproject.cpp:79:81
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/myproject.cpp:88:72
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/myproject.cpp:88:77
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/myproject.cpp:90:78
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/myproject.cpp:90:83
# WARNING: [HLS 200-471] Dataflow form checks found 16 issue(s) in file firmware/myproject.cpp
# INFO: [HLS 200-10] Analyzing design file 'firmware/myproject_axi.cpp' ...
# WARNING: [HLS 214-114] Since the only kind of statements allowed in a canonical dataflow region are variable declarations and function calls, the compiler may not be able to correctly handle the region: firmware/myproject_axi.cpp:17:2
# WARNING: [HLS 214-114] Since the only kind of statements allowed in a canonical dataflow region are variable declarations and function calls, the compiler may not be able to correctly handle the region: firmware/myproject_axi.cpp:29:5
# WARNING: [HLS 200-471] Dataflow form checks found 2 issue(s) in file firmware/myproject_axi.cpp
# INFO: [HLS 200-111] Finished Linking Time (s): cpu = 00:00:20 ; elapsed = 00:00:21 . Memory (MB): peak = 1647.832 ; gain = 1193.191 ; free physical = 7489 ; free virtual = 37282
# INFO: [HLS 200-111] Finished Checking Pragmas Time (s): cpu = 00:00:20 ; elapsed = 00:00:21 . Memory (MB): peak = 1647.832 ; gain = 1193.191 ; free physical = 7491 ; free virtual = 37284
# INFO: [HLS 200-10] Starting code transformations ...
# INFO: [HLS 200-489] Unrolling loop 'MultLoop' (firmware/nnet_utils/nnet_dense_resource.h:136) in function 'void nnet::dense_resource_rf_gt_nin_rem0<ap_fixed<4, 1, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config13>(FORWARD_REFERENCE*, FORWARD_REFERENCE*, FORWARD_REFERENCE::weight_t*, FORWARD_REFERENCE::bias_t*)' completely with a factor of 1.
# INFO: [HLS 200-489] Unrolling loop 'MultLoop' (firmware/nnet_utils/nnet_dense_resource.h:136) in function 'void nnet::dense_resource_rf_gt_nin_rem0<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config19_mult>(FORWARD_REFERENCE*, FORWARD_REFERENCE*, FORWARD_REFERENCE::weight_t*, FORWARD_REFERENCE::bias_t*)' completely with a factor of 1.
# INFO: [HLS 200-489] Unrolling loop 'MultLoop' (firmware/nnet_utils/nnet_dense_resource.h:136) in function 'void nnet::dense_resource_rf_gt_nin_rem0<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config6_mult>(FORWARD_REFERENCE*, FORWARD_REFERENCE*, FORWARD_REFERENCE::weight_t*, FORWARD_REFERENCE::bias_t*)' completely with a factor of 1.
# INFO: [HLS 200-489] Unrolling loop 'MultLoop' (firmware/nnet_utils/nnet_dense_resource.h:136) in function 'void nnet::dense_resource_rf_gt_nin_rem0<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config3_mult>(FORWARD_REFERENCE*, FORWARD_REFERENCE*, FORWARD_REFERENCE::weight_t*, FORWARD_REFERENCE::bias_t*)' completely with a factor of 1.
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 3u>::operator[]' into 'myproject_axi' (firmware/myproject_axi.cpp:21).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 3u>::operator[]' into 'nnet::relu<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 3u>, nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 3u>, relu_config2>' (firmware/nnet_utils/nnet_activation_stream.h:52).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 3u>::operator[]' into 'nnet::relu<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 3u>, nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 3u>, relu_config2>' (firmware/nnet_utils/nnet_activation_stream.h:51).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 3u>::operator[].1' into 'nnet::relu<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 3u>, nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 3u>, relu_config2>' (firmware/nnet_utils/nnet_activation_stream.h:54).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 3u>::operator[].1' into 'nnet::relu<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 3u>, nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 3u>, relu_config2>' (firmware/nnet_utils/nnet_activation_stream.h:52).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 3u>::operator[]' into 'nnet::shift_line_buffer<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 3u>, config3>' (firmware/nnet_utils/nnet_conv_stream.h:237).
# INFO: [XFORM 203-603] Inlining function 'nnet::kernel_shift_2d<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 3u>, config3>' into 'nnet::shift_line_buffer<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 3u>, config3>' (firmware/nnet_utils/nnet_conv_stream.h:252).
# INFO: [XFORM 203-603] Inlining function 'nnet::product::mult<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0> >::product' into 'nnet::dense_resource_rf_gt_nin_rem0<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config3_mult>' (firmware/nnet_utils/nnet_dense_resource.h:139).
# INFO: [XFORM 203-603] Inlining function 'nnet::product::mult<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0> >::product' into 'nnet::dense_resource_rf_gt_nin_rem0<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config6_mult>' (firmware/nnet_utils/nnet_dense_resource.h:139).
# INFO: [XFORM 203-603] Inlining function 'nnet::product::mult<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0> >::product' into 'nnet::dense_resource_rf_gt_nin_rem0<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config19_mult>' (firmware/nnet_utils/nnet_dense_resource.h:139).
# INFO: [XFORM 203-603] Inlining function 'nnet::dense_resource_rf_gt_nin_rem0<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config3_mult>' into 'nnet::dense_resource<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config3_mult>' (firmware/nnet_utils/nnet_dense_resource.h:255).
# INFO: [XFORM 203-603] Inlining function 'nnet::cast<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config3_mult>' into 'nnet::dense_resource<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config3_mult>' (firmware/nnet_utils/nnet_dense_resource.h:158->firmware/nnet_utils/nnet_dense_resource.h:255).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 4u>::operator[]' into 'nnet::compute_output_buffer_2d<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 3u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 4u>, config3>' (firmware/nnet_utils/nnet_conv_stream.h:305).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 4u>::operator[]' into 'nnet::relu<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 4u>, nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 4u>, relu_config5>' (firmware/nnet_utils/nnet_activation_stream.h:52).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 4u>::operator[]' into 'nnet::relu<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 4u>, nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 4u>, relu_config5>' (firmware/nnet_utils/nnet_activation_stream.h:51).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 4u>::operator[]' into 'nnet::normalize<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 4u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 4u>, config15>' (firmware/nnet_utils/nnet_batchnorm_stream.h:42).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 4u>::operator[]' into 'nnet::normalize<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 4u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 4u>, config15>' (firmware/nnet_utils/nnet_batchnorm_stream.h:41).
# INFO: [XFORM 203-603] Inlining function 'nnet::conv_2d_buffer_cl<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 3u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 4u>, config3>' into 'nnet::conv_2d_cl<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 3u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 4u>, config3>' (firmware/nnet_utils/nnet_conv2d_stream.h:103).
# INFO: [XFORM 203-603] Inlining function 'nnet::product::weight_exponential<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, exponent_scale15_t>::product' into 'nnet::normalize<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 4u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 4u>, config15>' (firmware/nnet_utils/nnet_batchnorm_stream.h:42).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 4u>::operator[].1' into 'nnet::relu<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 4u>, nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 4u>, relu_config5>' (firmware/nnet_utils/nnet_activation_stream.h:54).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 4u>::operator[].1' into 'nnet::relu<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 4u>, nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 4u>, relu_config5>' (firmware/nnet_utils/nnet_activation_stream.h:52).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 4u>::operator[]' into 'nnet::shift_line_buffer<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 4u>, config6>' (firmware/nnet_utils/nnet_conv_stream.h:237).
# INFO: [XFORM 203-603] Inlining function 'nnet::kernel_shift_2d<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 4u>, config6>' into 'nnet::shift_line_buffer<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 4u>, config6>' (firmware/nnet_utils/nnet_conv_stream.h:252).
# INFO: [XFORM 203-603] Inlining function 'nnet::dense_resource_rf_gt_nin_rem0<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config6_mult>' into 'nnet::dense_resource<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config6_mult>' (firmware/nnet_utils/nnet_dense_resource.h:255).
# INFO: [XFORM 203-603] Inlining function 'nnet::cast<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config6_mult>' into 'nnet::dense_resource<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config6_mult>' (firmware/nnet_utils/nnet_dense_resource.h:158->firmware/nnet_utils/nnet_dense_resource.h:255).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>::operator[]' into 'nnet::compute_output_buffer_2d<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 4u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config6>' (firmware/nnet_utils/nnet_conv_stream.h:305).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>::operator[]' into 'nnet::relu<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>, relu_config8>' (firmware/nnet_utils/nnet_activation_stream.h:52).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>::operator[]' into 'nnet::relu<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>, relu_config8>' (firmware/nnet_utils/nnet_activation_stream.h:51).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>::operator[]' into 'nnet::normalize<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config16>' (firmware/nnet_utils/nnet_batchnorm_stream.h:42).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>::operator[]' into 'nnet::normalize<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config16>' (firmware/nnet_utils/nnet_batchnorm_stream.h:41).
# INFO: [XFORM 203-603] Inlining function 'nnet::conv_2d_buffer_cl<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 4u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config6>' into 'nnet::conv_2d_cl<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 4u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config6>' (firmware/nnet_utils/nnet_conv2d_stream.h:103).
# INFO: [XFORM 203-603] Inlining function 'nnet::product::weight_exponential<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, exponent_scale16_t>::product' into 'nnet::normalize<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config16>' (firmware/nnet_utils/nnet_batchnorm_stream.h:42).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>::operator[].1' into 'nnet::relu<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>, relu_config8>' (firmware/nnet_utils/nnet_activation_stream.h:54).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>::operator[].1' into 'nnet::relu<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>, relu_config8>' (firmware/nnet_utils/nnet_activation_stream.h:52).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>::operator[]' into 'nnet::pointwise_mult_buffer<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config19>' (firmware/nnet_utils/nnet_sepconv_stream.h:153).
# INFO: [XFORM 203-603] Inlining function 'nnet::dense_resource_rf_gt_nin_rem0<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config19_mult>' into 'nnet::dense_resource<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config19_mult>' (firmware/nnet_utils/nnet_dense_resource.h:255).
# INFO: [XFORM 203-603] Inlining function 'nnet::cast<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config19_mult>' into 'nnet::dense_resource<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config19_mult>' (firmware/nnet_utils/nnet_dense_resource.h:158->firmware/nnet_utils/nnet_dense_resource.h:255).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>::operator[]' into 'myproject_axi' (firmware/myproject_axi.cpp:33).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>::operator[]' into 'nnet::pointwise_mult_buffer<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config19>' (firmware/nnet_utils/nnet_sepconv_stream.h:168).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>::operator[]' into 'nnet::normalize<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config18>' (firmware/nnet_utils/nnet_batchnorm_stream.h:42).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>::operator[]' into 'nnet::normalize<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config18>' (firmware/nnet_utils/nnet_batchnorm_stream.h:41).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>::operator[]' into 'nnet::dense<nnet::array<ap_fixed<4, 1, (ap_q_mode)4, (ap_o_mode)0, 0>, 5u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config13>' (firmware/nnet_utils/nnet_dense_stream.h:60).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>::operator[]' into 'nnet::linear<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, nnet::array<ap_fixed<4, 1, (ap_q_mode)4, (ap_o_mode)0, 0>, 5u>, linear_config11>' (firmware/nnet_utils/nnet_activation_stream.h:29).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>::operator[]' into 'nnet::normalize<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config17>' (firmware/nnet_utils/nnet_batchnorm_stream.h:42).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>::operator[]' into 'nnet::normalize<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config17>' (firmware/nnet_utils/nnet_batchnorm_stream.h:41).
# INFO: [XFORM 203-603] Inlining function 'nnet::dense_resource<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config19_mult>' into 'nnet::pointwise_mult_buffer<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config19>' (firmware/nnet_utils/nnet_sepconv_stream.h:161).
# INFO: [XFORM 203-603] Inlining function 'nnet::pointwise_mult_buffer<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config19>' into 'nnet::pointwise_conv_2d_cl<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config19>' (firmware/nnet_utils/nnet_sepconv2d_stream.h:113).
# INFO: [XFORM 203-603] Inlining function 'nnet::product::weight_exponential<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, exponent_scale17_t>::product' into 'nnet::normalize<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config17>' (firmware/nnet_utils/nnet_batchnorm_stream.h:42).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<4, 1, (ap_q_mode)4, (ap_o_mode)0, 0>, 5u>::operator[]' into 'nnet::dense<nnet::array<ap_fixed<4, 1, (ap_q_mode)4, (ap_o_mode)0, 0>, 5u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config13>' (firmware/nnet_utils/nnet_dense_stream.h:44).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<4, 1, (ap_q_mode)4, (ap_o_mode)0, 0>, 5u>::operator[]' into 'nnet::linear<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, nnet::array<ap_fixed<4, 1, (ap_q_mode)4, (ap_o_mode)0, 0>, 5u>, linear_config11>' (firmware/nnet_utils/nnet_activation_stream.h:29).
# INFO: [XFORM 203-603] Inlining function 'nnet::product::mult<ap_fixed<4, 1, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0> >::product' into 'nnet::dense_resource_rf_gt_nin_rem0<ap_fixed<4, 1, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config13>' (firmware/nnet_utils/nnet_dense_resource.h:139).
# INFO: [XFORM 203-603] Inlining function 'nnet::dense_resource_rf_gt_nin_rem0<ap_fixed<4, 1, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config13>' into 'nnet::dense_resource<ap_fixed<4, 1, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config13>' (firmware/nnet_utils/nnet_dense_resource.h:255).
# INFO: [XFORM 203-603] Inlining function 'nnet::cast<ap_fixed<4, 1, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config13>' into 'nnet::dense_resource<ap_fixed<4, 1, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config13>' (firmware/nnet_utils/nnet_dense_resource.h:158->firmware/nnet_utils/nnet_dense_resource.h:255).
# INFO: [XFORM 203-603] Inlining function 'nnet::dense_resource<ap_fixed<4, 1, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config13>' into 'nnet::dense_wrapper<ap_fixed<4, 1, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config13>' (firmware/nnet_utils/nnet_dense_stream.h:21).
# INFO: [XFORM 203-603] Inlining function 'nnet::product::weight_exponential<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, exponent_scale18_t>::product' into 'nnet::normalize<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config18>' (firmware/nnet_utils/nnet_batchnorm_stream.h:42).
# INFO: [HLS 200-111] Finished Standard Transforms Time (s): cpu = 00:00:23 ; elapsed = 00:00:24 . Memory (MB): peak = 1647.832 ; gain = 1193.191 ; free physical = 7195 ; free virtual = 36997
# INFO: [HLS 200-10] Checking synthesizability ...
# WARNING: [SYNCHK 200-23] firmware/myproject_axi.cpp:33: variable-indexed range selection may cause suboptimal QoR.
# INFO: [SYNCHK 200-10] 0 error(s), 1 warning(s).
# INFO: [HLS 200-111] Finished Checking Synthesizability Time (s): cpu = 00:00:24 ; elapsed = 00:00:25 . Memory (MB): peak = 1647.832 ; gain = 1193.191 ; free physical = 7207 ; free virtual = 37011
# WARNING: [XFORM 203-803] Cannot specify interface mode 'axis' on argument 'data.V.data.V' . This interface directive will be discarded. Please apply it on an argument of top module.
# WARNING: [XFORM 203-803] Cannot specify interface mode 'axis' on argument 'res.V.data.V' . This interface directive will be discarded. Please apply it on an argument of top module.
# WARNING: [XFORM 203-803] Cannot specify interface mode 'axis' (firmware/myproject.cpp:12:1) on argument 'input_1.V.data.V' (firmware/myproject.cpp:7). This interface directive will be discarded. Please apply it on an argument of top module.
# WARNING: [XFORM 203-803] Cannot specify interface mode 'axis' (firmware/myproject.cpp:12:94) on argument 'layer18_out.V.data.V' (firmware/myproject.cpp:8). This interface directive will be discarded. Please apply it on an argument of top module.
# WARNING: [XFORM 203-1103] Ignored data pack directive on non-struct variable 'out.data' (firmware/myproject_axi.cpp:3).
# WARNING: [XFORM 203-1103] Ignored data pack directive on non-struct variable 'in.data' (firmware/myproject_axi.cpp:3).
# INFO: [XFORM 203-1101] Packing variable 'out_data.data.V' (firmware/nnet_utils/nnet_activation_stream.h:45) into a 32-bit variable.
# INFO: [XFORM 203-1101] Packing variable 'out_data.data.V' (firmware/nnet_utils/nnet_activation_stream.h:45) into a 24-bit variable.
# INFO: [XFORM 203-1101] Packing variable 'out_data.data.V' (firmware/nnet_utils/nnet_activation_stream.h:45) into a 128-bit variable.
# INFO: [XFORM 203-1101] Packing variable 'res_pack.data.V' (firmware/nnet_utils/nnet_sepconv_stream.h:147) into a 40-bit variable.
# INFO: [XFORM 203-1101] Packing variable 'out_data.data.V' (firmware/nnet_utils/nnet_batchnorm_stream.h:29) into a 40-bit variable.
# INFO: [XFORM 203-1101] Packing variable 'out_data.data.V' (firmware/nnet_utils/nnet_batchnorm_stream.h:29) into a 40-bit variable.
# INFO: [XFORM 203-1101] Packing variable 'out_data.data.V' (firmware/nnet_utils/nnet_batchnorm_stream.h:29) into a 32-bit variable.
# INFO: [XFORM 203-1101] Packing variable 'out_data.data.V' (firmware/nnet_utils/nnet_batchnorm_stream.h:29) into a 128-bit variable.
# INFO: [XFORM 203-1101] Packing variable 'out_data.data.V' (firmware/nnet_utils/nnet_activation_stream.h:23) into a 20-bit variable.
# INFO: [XFORM 203-1101] Packing variable 'res_pack.data.V' (firmware/nnet_utils/nnet_dense_stream.h:55) into a 40-bit variable.
# INFO: [XFORM 203-1101] Packing variable 'ctype.data.V' (firmware/myproject_axi.cpp:18) into a 24-bit variable.
# INFO: [XFORM 203-1101] Packing variable 'res_pack.data.V' (firmware/nnet_utils/nnet_conv_stream.h:282) into a 128-bit variable.
# INFO: [XFORM 203-1101] Packing variable 'res_pack.data.V' (firmware/nnet_utils/nnet_conv_stream.h:282) into a 32-bit variable.
# INFO: [XFORM 203-502] Unrolling all sub-loops inside loop 'ReLUActLoop' (firmware/nnet_utils/nnet_activation_stream.h:41) in function 'nnet::relu<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 4u>, nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 4u>, relu_config5>' for pipelining.
# INFO: [XFORM 203-502] Unrolling all sub-loops inside loop 'ReLUActLoop' (firmware/nnet_utils/nnet_activation_stream.h:41) in function 'nnet::relu<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 3u>, nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 3u>, relu_config2>' for pipelining.
# INFO: [XFORM 203-502] Unrolling all sub-loops inside loop 'ReLUActLoop' (firmware/nnet_utils/nnet_activation_stream.h:41) in function 'nnet::relu<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>, relu_config8>' for pipelining.
# INFO: [XFORM 203-502] Unrolling all loops for pipelining in function 'nnet::normalize<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config18>' (firmware/nnet_utils/nnet_batchnorm_stream.h:18:43).
# INFO: [XFORM 203-502] Unrolling all sub-loops inside loop 'BatchNormLoop' (firmware/nnet_utils/nnet_batchnorm_stream.h:25) in function 'nnet::normalize<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config17>' for pipelining.
# INFO: [XFORM 203-502] Unrolling all sub-loops inside loop 'BatchNormLoop' (firmware/nnet_utils/nnet_batchnorm_stream.h:25) in function 'nnet::normalize<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 4u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 4u>, config15>' for pipelining.
# INFO: [XFORM 203-502] Unrolling all sub-loops inside loop 'BatchNormLoop' (firmware/nnet_utils/nnet_batchnorm_stream.h:25) in function 'nnet::normalize<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config16>' for pipelining.
# INFO: [XFORM 203-502] Unrolling all sub-loops inside loop 'LinearActLoop' (firmware/nnet_utils/nnet_activation_stream.h:19) in function 'nnet::linear<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, nnet::array<ap_fixed<4, 1, (ap_q_mode)4, (ap_o_mode)0, 0>, 5u>, linear_config11>' for pipelining.
# INFO: [XFORM 203-502] Unrolling all sub-loops inside loop 'DataPrepare' (firmware/nnet_utils/nnet_dense_stream.h:36) in function 'nnet::dense<nnet::array<ap_fixed<4, 1, (ap_q_mode)4, (ap_o_mode)0, 0>, 5u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config13>' for pipelining.
# INFO: [XFORM 203-502] Unrolling all loops for pipelining in function 'nnet::shift_line_buffer<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 4u>, config6>' (firmware/nnet_utils/nnet_conv_stream.h:194:62).
# WARNING: [XFORM 203-505] Ignored pipeline directive for loop 'KernelShiftWidth' (firmware/nnet_utils/nnet_conv_stream.h:194) because its parent loop or function is pipelined.
# INFO: [XFORM 203-502] Unrolling all loops for pipelining in function 'nnet::shift_line_buffer<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 3u>, config3>' (firmware/nnet_utils/nnet_conv_stream.h:194:62).
# WARNING: [XFORM 203-505] Ignored pipeline directive for loop 'KernelShiftWidth' (firmware/nnet_utils/nnet_conv_stream.h:194) because its parent loop or function is pipelined.
# INFO: [HLS 200-489] Unrolling loop 'ReLUPackLoop' (firmware/nnet_utils/nnet_activation_stream.h:49) in function 'nnet::relu<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 4u>, nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 4u>, relu_config5>' completely with a factor of 4.
# INFO: [HLS 200-489] Unrolling loop 'ReLUPackLoop' (firmware/nnet_utils/nnet_activation_stream.h:49) in function 'nnet::relu<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 3u>, nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 3u>, relu_config2>' completely with a factor of 3.
# INFO: [HLS 200-489] Unrolling loop 'ReLUPackLoop' (firmware/nnet_utils/nnet_activation_stream.h:49) in function 'nnet::relu<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>, relu_config8>' completely with a factor of 16.
# INFO: [HLS 200-489] Unrolling loop 'InitData' (firmware/nnet_utils/nnet_sepconv_stream.h:151) in function 'nnet::pointwise_conv_2d_cl<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config19>' completely with a factor of 16.
# INFO: [HLS 200-489] Unrolling loop 'InitAccum' (firmware/nnet_utils/nnet_dense_resource.h:108) in function 'nnet::pointwise_conv_2d_cl<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config19>' completely with a factor of 5.
# INFO: [HLS 200-489] Unrolling loop 'Result' (firmware/nnet_utils/nnet_dense_resource.h:156) in function 'nnet::pointwise_conv_2d_cl<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config19>' completely with a factor of 5.
# INFO: [HLS 200-489] Unrolling loop 'CastLoop' (firmware/nnet_utils/nnet_sepconv_stream.h:166) in function 'nnet::pointwise_conv_2d_cl<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 16u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config19>' completely with a factor of 5.
# INFO: [HLS 200-489] Unrolling loop 'BatchNormpack' (firmware/nnet_utils/nnet_batchnorm_stream.h:33) in function 'nnet::normalize<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config18>' completely with a factor of 5.
# INFO: [HLS 200-489] Unrolling loop 'BatchNormpack' (firmware/nnet_utils/nnet_batchnorm_stream.h:33) in function 'nnet::normalize<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config17>' completely with a factor of 5.
# INFO: [HLS 200-489] Unrolling loop 'BatchNormpack' (firmware/nnet_utils/nnet_batchnorm_stream.h:33) in function 'nnet::normalize<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 4u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 4u>, config15>' completely with a factor of 4.
# INFO: [HLS 200-489] Unrolling loop 'BatchNormpack' (firmware/nnet_utils/nnet_batchnorm_stream.h:33) in function 'nnet::normalize<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config16>' completely with a factor of 16.
# INFO: [HLS 200-489] Unrolling loop 'LinearPackLoop' (firmware/nnet_utils/nnet_activation_stream.h:27) in function 'nnet::linear<nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, nnet::array<ap_fixed<4, 1, (ap_q_mode)4, (ap_o_mode)0, 0>, 5u>, linear_config11>' completely with a factor of 5.
# INFO: [HLS 200-489] Unrolling loop 'DataPack' (firmware/nnet_utils/nnet_dense_stream.h:42) in function 'nnet::dense<nnet::array<ap_fixed<4, 1, (ap_q_mode)4, (ap_o_mode)0, 0>, 5u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config13>' completely with a factor of 5.
# INFO: [HLS 200-489] Unrolling loop 'ResPack' (firmware/nnet_utils/nnet_dense_stream.h:58) in function 'nnet::dense<nnet::array<ap_fixed<4, 1, (ap_q_mode)4, (ap_o_mode)0, 0>, 5u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 5u>, config13>' completely with a factor of 5.
# INFO: [HLS 200-489] Unrolling loop 'InitAccum' (firmware/nnet_utils/nnet_dense_resource.h:108) in function 'nnet::dense_wrapper<ap_fixed<4, 1, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config13>' completely with a factor of 5.
# INFO: [HLS 200-489] Unrolling loop 'Result' (firmware/nnet_utils/nnet_dense_resource.h:156) in function 'nnet::dense_wrapper<ap_fixed<4, 1, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config13>' completely with a factor of 5.
# INFO: [HLS 200-489] Unrolling loop 'CastLoop' (firmware/nnet_utils/nnet_conv_stream.h:303) in function 'nnet::compute_output_buffer_2d<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 4u>, nnet::array<ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, 16u>, config6>' completely with a factor of 16.
# INFO: [HLS 200-489] Unrolling loop 'InitAccum' (firmware/nnet_utils/nnet_dense_resource.h:108) in function 'nnet::dense_resource<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config6_mult>' completely with a factor of 16.
# INFO: [HLS 200-489] Unrolling loop 'Result' (firmware/nnet_utils/nnet_dense_resource.h:156) in function 'nnet::dense_resource<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>, config6_mult>' completely with a factor of 16.
# INFO: [HLS 200-489] Unrolling loop 'UpdateBuffer' (firmware/nnet_utils/nnet_conv_stream.h:233) in function 'nnet::shift_line_buffer<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 4u>, config6>' completely with a factor of 4.
# INFO: [HLS 200-489] Unrolling loop 'LineBufferDataIn' (firmware/nnet_utils/nnet_conv_stream.h:241) in function 'nnet::shift_line_buffer<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 4u>, config6>' completely with a factor of 4.
# INFO: [HLS 200-489] Unrolling loop 'LineBufferShift' (firmware/nnet_utils/nnet_conv_stream.h:244) in function 'nnet::shift_line_buffer<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 4u>, config6>' completely with a factor of 2.
# INFO: [HLS 200-489] Unrolling loop 'KernelShiftWidth' (firmware/nnet_utils/nnet_conv_stream.h:194) in function 'nnet::shift_line_buffer<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 4u>, config6>' completely with a factor of 2.
# INFO: [HLS 200-489] Unrolling loop 'KernelShiftHeight' (firmware/nnet_utils/nnet_conv_stream.h:197) in function 'nnet::shift_line_buffer<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 4u>, config6>' completely with a factor of 3.
# INFO: [HLS 200-489] Unrolling loop 'KernelShiftChannel' (firmware/nnet_utils/nnet_conv_stream.h:199) in function 'nnet::shift_line_buffer<nnet::array<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, 4u>, config6>' completely with a factor of 4.
# ...
# Compiling module xil_defaultlib.start_for_pointwise_conv_2d_cl_a...
# Compiling module xil_defaultlib.start_for_normalize_array_ap_fix...
# Compiling module xil_defaultlib.start_for_normalize_array_ap_fix...
# Compiling module xil_defaultlib.start_for_linear_array_ap_fixed_...
# Compiling module xil_defaultlib.start_for_linear_array_ap_fixed_...
# Compiling module xil_defaultlib.start_for_dense_array_ap_fixed_5...
# Compiling module xil_defaultlib.start_for_dense_array_ap_fixed_5...
# Compiling module xil_defaultlib.start_for_normalize_array_ap_fix...
# Compiling module xil_defaultlib.start_for_normalize_array_ap_fix...
# Compiling module xil_defaultlib.myproject
# Compiling module xil_defaultlib.Block_myproject_axi_exit45_proc
# Compiling module xil_defaultlib.myproject_axi_lshr_32ns_32ns_32_...
# Compiling module xil_defaultlib.myproject_axi_shl_64ns_32ns_64_2...
# Compiling module xil_defaultlib.Loop_2_proc
# Compiling module xil_defaultlib.fifo_w8_d16384_A
# Compiling module xil_defaultlib.fifo_w1_d2_A_shiftReg
# Compiling module xil_defaultlib.fifo_w1_d2_A
# Compiling module xil_defaultlib.fifo_w8_d1_A_shiftReg
# Compiling module xil_defaultlib.fifo_w8_d1_A
# Compiling module xil_defaultlib.fifo_w8_d2_A_shiftReg
# Compiling module xil_defaultlib.fifo_w8_d2_A
# Compiling module xil_defaultlib.start_for_myproject_U0_shiftReg
# Compiling module xil_defaultlib.start_for_myproject_U0
# Compiling module xil_defaultlib.start_for_Block_myproject_axi_ex...
# Compiling module xil_defaultlib.start_for_Block_myproject_axi_ex...
# Compiling module xil_defaultlib.myproject_axi
# Compiling module xil_defaultlib.fifo(DEPTH=49152,WIDTH=32)
# Compiling module xil_defaultlib.fifo(DEPTH=49152,WIDTH=1)
# Compiling module xil_defaultlib.AESL_axi_s_in_r
# Compiling module xil_defaultlib.fifo(DEPTH=5,WIDTH=32)
# Compiling module xil_defaultlib.fifo(DEPTH=5,WIDTH=1)
# Compiling module xil_defaultlib.AESL_axi_s_out_r
# Compiling module xil_defaultlib.AESL_deadlock_detect_unit(PROC_N...
# Compiling module xil_defaultlib.AESL_deadlock_detect_unit(PROC_N...
# Compiling module xil_defaultlib.AESL_deadlock_detect_unit(PROC_N...
# Compiling module xil_defaultlib.AESL_deadlock_detect_unit(PROC_N...
# Compiling module xil_defaultlib.AESL_deadlock_detect_unit(PROC_N...
# Compiling module xil_defaultlib.AESL_deadlock_detect_unit(PROC_N...
# Compiling module xil_defaultlib.AESL_deadlock_detect_unit(PROC_N...
# Compiling module xil_defaultlib.AESL_deadlock_detect_unit(PROC_N...
# Compiling module xil_defaultlib.AESL_deadlock_detect_unit(PROC_N...
# Compiling module xil_defaultlib.AESL_deadlock_detect_unit(PROC_N...
# Compiling module xil_defaultlib.AESL_deadlock_detect_unit(PROC_N...
# Compiling module xil_defaultlib.AESL_deadlock_detect_unit(PROC_N...
# Compiling module xil_defaultlib.AESL_deadlock_detect_unit(PROC_N...
# Compiling module xil_defaultlib.AESL_deadlock_detect_unit(PROC_N...
# Compiling module xil_defaultlib.AESL_deadlock_detect_unit(PROC_N...
# Compiling module xil_defaultlib.AESL_deadlock_report_unit(PROC_N...
# Compiling module xil_defaultlib.AESL_deadlock_detector_1
# Compiling module xil_defaultlib.apatb_myproject_axi_top
# Compiling module work.glbl
# Built simulation snapshot myproject_axi
#
# ****** Webtalk v2020.1 (64-bit)
#   **** SW Build 2902540 on Wed May 27 19:54:35 MDT 2020
#   **** IP Build 2902112 on Wed May 27 22:43:36 MDT 2020
#     ** Copyright 1986-2020 Xilinx, Inc. All Rights Reserved.
#
# source /home/webphy/Desktop/dnn_processor/hls4ml/deploy/qmodel_handmade_model_fifo_opt_pynq/hls4ml_prj/myproject_prj/solution1/sim/verilog/xsim.dir/myproject_axi/webtalk/xsim_webtalk.tcl -notrace
# INFO: [Common 17-206] Exiting Webtalk at Tue Feb  6 12:08:17 2024...
#
# ****** xsim v2020.1 (64-bit)
#   **** SW Build 2902540 on Wed May 27 19:54:35 MDT 2020
#   **** IP Build 2902112 on Wed May 27 22:43:36 MDT 2020
#     ** Copyright 1986-2020 Xilinx, Inc. All Rights Reserved.
#
# source xsim.dir/myproject_axi/xsim_script.tcl
# # xsim {myproject_axi} -autoloadwcfg -tclbatch {myproject_axi.tcl}
# Vivado Simulator 2020.1
# Time resolution is 1 ps
# source myproject_axi.tcl
# ## source "../../../../project.tcl"
# ### variable project_name
# ### set project_name "myproject"
# ### variable backend
# ### set backend "vivadoaccelerator"
# ### variable part
# ### set part "xc7z020clg400-1"
# ### variable clock_period
# ### set clock_period 5
# ### variable clock_uncertainty
# ### set clock_uncertainty 12.5%
# ### variable version
# ### set version "1.0.0"
# ### set bit_width_hls_output 32
# ### set bit_width_hls_input 32
# ## if {[string equal "$backend" "vivadoaccelerator"]} {
# ##                     current_scope [get_scopes -regex "/apatb_${project_name}_axi_top/AESL_inst_${project_name}_axi/${project_name}_U0.*"]
# ##                     set scopes [get_scopes -regexp {layer(\d*)_.*data_0_V_U.*}]
# ##                     append scopes { }
# ##                     current_scope "/apatb_${project_name}_axi_top/AESL_inst_${project_name}_axi"
# ##                     append scopes [get_scopes -regexp {(in_local_V_data.*_0_.*)}]
# ##                     append scopes { }
# ##                     append scopes [get_scopes -regexp {(out_local_V_data.*_0_.*)}]
# ##                 } else {
# ##                     current_scope [get_scopes -regex "/apatb_${project_name}_top/AESL_inst_${project_name}"]
# ##                     set scopes [get_scopes -regexp {layer(\d*)_.*data_0_V_U.*}]
# ##                 }
# ## open_vcd fifo_opt.vcd
# ## foreach scope $scopes {
# ##                     current_scope $scope
# ##                     if {[catch [get_objects usedw]] == 0} {
# ##                         puts "$scope skipped"
# ##                         continue
# ##                     }
# ##                     set usedw [get_objects usedw]
# ##                     set depth [get_objects DEPTH]
# ##                     add_wave $usedw
# ##                     log_vcd $usedw
# ##                     log_wave $usedw
# ##                     add_wave $depth
# ##                     log_vcd $depth
# ##                     log_wave $depth
# ##                 }
# WARNING: [Simtcl 6-168] No object found for the given pattern.
# /apatb_myproject_axi_top/AESL_inst_myproject_axi/out_local_V_data_0_V_U skipped
# ## set designtopgroup [add_wave_group "Design Top Signals"]
# ## set coutputgroup [add_wave_group "C Outputs" -into $designtopgroup]
# ## set out_group [add_wave_group out(axis) -into $coutputgroup]
# ## add_wave /apatb_myproject_axi_top/AESL_inst_myproject_axi/out_r_TREADY -into $out_group -color #ffff00 -radix hex
# ## add_wave /apatb_myproject_axi_top/AESL_inst_myproject_axi/out_r_TVALID -into $out_group -color #ffff00 -radix hex
# ## add_wave /apatb_myproject_axi_top/AESL_inst_myproject_axi/out_r_TLAST -into $out_group -color #ffff00 -radix hex
# ## add_wave /apatb_myproject_axi_top/AESL_inst_myproject_axi/out_r_TDATA -into $out_group -radix hex
# ## set cinputgroup [add_wave_group "C Inputs" -into $designtopgroup]
# ## set in_group [add_wave_group in(axis) -into $cinputgroup]
# ## add_wave /apatb_myproject_axi_top/AESL_inst_myproject_axi/in_r_TREADY -into $in_group -color #ffff00 -radix hex
# ## add_wave /apatb_myproject_axi_top/AESL_inst_myproject_axi/in_r_TVALID -into $in_group -color #ffff00 -radix hex
# ## add_wave /apatb_myproject_axi_top/AESL_inst_myproject_axi/in_r_TLAST -into $in_group -color #ffff00 -radix hex
# ## add_wave /apatb_myproject_axi_top/AESL_inst_myproject_axi/in_r_TDATA -into $in_group -radix hex
# ## set resetgroup [add_wave_group "Reset" -into $designtopgroup]
# ## add_wave /apatb_myproject_axi_top/AESL_inst_myproject_axi/ap_rst_n -into $resetgroup
# ## set clockgroup [add_wave_group "Clock" -into $designtopgroup]
# ## add_wave /apatb_myproject_axi_top/AESL_inst_myproject_axi/ap_clk -into $clockgroup
# ## set testbenchgroup [add_wave_group "Test Bench Signals"]
# ## set tbinternalsiggroup [add_wave_group "Internal Signals" -into $testbenchgroup]
# ## set tb_simstatus_group [add_wave_group "Simulation Status" -into $tbinternalsiggroup]
# ## set tb_portdepth_group [add_wave_group "Port Depth" -into $tbinternalsiggroup]
# ## add_wave /apatb_myproject_axi_top/AUTOTB_TRANSACTION_NUM -into $tb_simstatus_group -radix hex
# ## add_wave /apatb_myproject_axi_top/ready_cnt -into $tb_simstatus_group -radix hex
# ## add_wave /apatb_myproject_axi_top/done_cnt -into $tb_simstatus_group -radix hex
# ## add_wave /apatb_myproject_axi_top/ap_c_n_tvin_trans_num_in_data -into $tb_simstatus_group -radix hex
# ## add_wave /apatb_myproject_axi_top/ap_c_n_tvin_trans_num_in_last_V -into $tb_simstatus_group -radix hex
# ## add_wave /apatb_myproject_axi_top/ap_c_n_tvout_trans_num_out_data -into $tb_simstatus_group -radix hex
# ## add_wave /apatb_myproject_axi_top/ap_c_n_tvout_trans_num_out_last_V -into $tb_simstatus_group -radix hex
# ## add_wave /apatb_myproject_axi_top/LENGTH_in_data -into $tb_portdepth_group -radix hex
# ## add_wave /apatb_myproject_axi_top/LENGTH_in_last_V -into $tb_portdepth_group -radix hex
# ## add_wave /apatb_myproject_axi_top/LENGTH_out_data -into $tb_portdepth_group -radix hex
# ## add_wave /apatb_myproject_axi_top/LENGTH_out_last_V -into $tb_portdepth_group -radix hex
# ## set tbcoutputgroup [add_wave_group "C Outputs" -into $testbenchgroup]
# ## set tb_out_group [add_wave_group out(axis) -into $tbcoutputgroup]
# ## add_wave /apatb_myproject_axi_top/out_r_TREADY -into $tb_out_group -color #ffff00 -radix hex
# ## add_wave /apatb_myproject_axi_top/out_r_TVALID -into $tb_out_group -color #ffff00 -radix hex
# ## add_wave /apatb_myproject_axi_top/out_r_TLAST -into $tb_out_group -color #ffff00 -radix hex
# ## add_wave /apatb_myproject_axi_top/out_r_TDATA -into $tb_out_group -radix hex
# ## set tbcinputgroup [add_wave_group "C Inputs" -into $testbenchgroup]
# ## set tb_in_group [add_wave_group in(axis) -into $tbcinputgroup]
# ## add_wave /apatb_myproject_axi_top/in_r_TREADY -into $tb_in_group -color #ffff00 -radix hex
# ## add_wave /apatb_myproject_axi_top/in_r_TVALID -into $tb_in_group -color #ffff00 -radix hex
# ## add_wave /apatb_myproject_axi_top/in_r_TLAST -into $tb_in_group -color #ffff00 -radix hex
# ## add_wave /apatb_myproject_axi_top/in_r_TDATA -into $tb_in_group -radix hex
# ## save_wave_config myproject_axi.wcfg
# ## run all
# ////////////////////////////////////////////////////////////////////////////////////
# // Inter-Transaction Progress: Completed Transaction / Total Transaction
# // Intra-Transaction Progress: Measured Latency / Latency Estimation * 100%
# //
# // RTL Simulation : "Inter-Transaction Progress" ["Intra-Transaction Progress"] @ "Simulation Time"
# ////////////////////////////////////////////////////////////////////////////////////
# // RTL Simulation : 0 / 1 [0.00%] @ "113000"
# // RTL Simulation : 1 / 1 [100.00%] @ "2130323000"
# ////////////////////////////////////////////////////////////////////////////////////
# $finish called at time : 2130342500 ps : File "/home/webphy/Desktop/dnn_processor/hls4ml/deploy/qmodel_handmade_model_fifo_opt_pynq/hls4ml_prj/myproject_prj/solution1/sim/verilog/myproject_axi.autotb.v" Line 218
# run: Time (s): cpu = 00:00:00.58 ; elapsed = 00:01:03 . Memory (MB): peak = 2065.594 ; gain = 0.000 ; free physical = 6160 ; free virtual = 36321
# ## flush_vcd
# ## close_vcd
# ## quit
# INFO: [Common 17-206] Exiting xsim at Tue Feb  6 12:09:25 2024...
# INFO: [COSIM 212-316] Starting C post checking ...
# INFO: Unable to open input/predictions file, using default input.
# { data: -0.015625, last: 0 }
#  { data: -0.0859375, last: 0 }
#  { data: 0.078125, last: 0 }
#  { data: -0.0390625, last: 0 }
#  { data: 0.0546875, last: 1 }
#
# INFO: Saved inference results to file: tb_data/rtl_cosim_results.log
# INFO:
# Report time       : ter 06 fev 2024 12:08:07 -03.
# Solution          : solution1.
# Simulation tool   : xsim.
#
# +----------+----------+-----------------------------------------------+-----------------------------------------------+
# |          |          |                    Latency                    |                    Interval                   |
# +   RTL    +  Status  +-----------------------------------------------+-----------------------------------------------+
# |          |          |      min      |      avg      |      max      |      min      |      avg      |      max      |
# +----------+----------+-----------------------------------------------+-----------------------------------------------+
# |      VHDL|        NA|             NA|             NA|             NA|             NA|             NA|             NA|
# |   Verilog|      Pass|             NA|             NA|             NA|             NA|             NA|             NA|
# +----------+----------+-----------------------------------------------+-----------------------------------------------+
#
# ***** C/RTL SIMULATION COMPLETED IN 0h1m42s *****
# INFO: [HLS 200-112] Total elapsed time: 196.31 seconds; peak allocated memory: 872.751 MB.
# INFO: [Common 17-206] Exiting vivado_hls at Tue Feb  6 12:09:25 2024...
# Vivado synthesis report not found.
# Implementation report not found.
# Timing report not found.
# Vivado synthesis report not found.
# Implementation report not found.
# Timing report not found.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 hls_model = hls4ml.converters.convert_from_keras_model(
#       2     qkeras_model,
#       3     hls_config=config,
#       4     output_dir=f"deploy/qmodel_{trial_id}_fifo_opt_pynq/hls4ml_prj",
#       5     part="xc7z020clg400-1",
#       6     io_type="io_stream",
#       7     backend='VivadoAccelerator',
#       8     board='pynq-z2'
#       9 )
#
# File ~/Desktop/dnn_processor/.venv/lib/python3.10/site-packages/hls4ml/converters/__init__.py:234, in convert_from_keras_model(model, output_dir, project_name, input_data_tb, output_data_tb, backend, hls_config, **kwargs)
#     230 config['HLSConfig']['Model'] = _check_model_config(model_config)
#     232 _check_hls_config(config, hls_config)
# --> 234 return keras_to_hls(config)
#
# File ~/Desktop/dnn_processor/.venv/lib/python3.10/site-packages/hls4ml/converters/keras_to_hls.py:335, in keras_to_hls(config)
#     333 layer_list, input_layers, output_layers, _ = parse_keras_model(model_arch, reader)
#     334 print('Creating HLS model')
# --> 335 hls_model = ModelGraph(config, layer_list, input_layers, output_layers)
#     336 return hls_model
#
# File ~/Desktop/dnn_processor/.venv/lib/python3.10/site-packages/hls4ml/model/graph.py:362, in ModelGraph.__init__(self, config, layer_list, inputs, outputs)
#     359 self._make_graph(layer_list)
#     361 for flow in self.config.flows:
# --> 362     self.apply_flow(flow)
#
# File ~/Desktop/dnn_processor/.venv/lib/python3.10/site-packages/hls4ml/model/graph.py:424, in ModelGraph.apply_flow(self, flow, reapply)
#     421         return
#     423 self._applied_flows.append(applied_flows)
# --> 424 self._apply_sub_flow(flow, applied_flows)
#
# File ~/Desktop/dnn_processor/.venv/lib/python3.10/site-packages/hls4ml/model/graph.py:436, in ModelGraph._apply_sub_flow(self, flow_name, applied_flows)
#     433         self._apply_sub_flow(sub_flow, applied_flows)
#     435 if len(flow.optimizers) > 0:
# --> 436     applied_passes = optimize_model(self, flow.optimizers)
#     437 else:
#     438     applied_passes = set()
#
# File ~/Desktop/dnn_processor/.venv/lib/python3.10/site-packages/hls4ml/model/optimizer/optimizer.py:312, in optimize_model(model, passes)
#     310 for opt_name, opt in optimizers.items():
#     311     if isinstance(opt, ModelOptimizerPass) and opt_name not in applied_passes:
# --> 312         res = opt.transform(model)
#     313         if res:
#     314             applied_passes.add(opt_name)
#
# File ~/Desktop/dnn_processor/.venv/lib/python3.10/site-packages/hls4ml/backends/vivado/passes/fifo_depth_optimization.py:93, in FifoDepthOptimization.transform(self, model)
#      91 for i in range(n_elem):
#      92     name = data['children'][0]['children'][0]['children'][i]['name']
# ---> 93     data_p = data['children'][0]['children'][0]['children'][i]['children'][0]['data']
#      94     depth = data['children'][0]['children'][0]['children'][i]['children'][1]['data']
#      95     populate_values(self.values, name, data_p, depth)
#
# KeyError: 'data'

# %%
hls_model.compile()
# Out:
# Writing HLS project
# Done

# %%
hls_model.build(
    reset=False, csim=True, synth=True, cosim=True, export=True, bitfile=True
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 hls_model.build(
#       2     reset=False, csim=True, synth=True, cosim=True, export=True, bitfile=True
#       3 )
#
# File ~/Desktop/dnn_processor/.venv/lib/python3.10/site-packages/hls4ml/model/graph.py:871, in ModelGraph.build(self, **kwargs)
#     867 if not os.path.exists(self.config.get_output_dir()):
#     868     # Assume the project wasn't written before
#     869     self.write()
# --> 871 return self.config.backend.build(self, **kwargs)
#
# TypeError: VivadoBackend.build() got an unexpected keyword argument 'bitfile'

# %%
hls4ml.report.read_vivado_report(f"deploy/qmodel_{trial_id}_fifo_opt_pynq/hls4ml_prj")
